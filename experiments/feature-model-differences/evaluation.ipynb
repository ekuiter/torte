# %% [markdown]
# # Feature-model differences evaluation
#
# This notebook analyzes the `diff-with-clausy` results for three variants of the experiment:
#
# - `main`: release-to-release comparisons for the regular subject systems.
# - `commits`: BusyBox commit-level comparisons over the generated KConfig history.
# - `yearly`: yearly BusyBox comparisons, kept separate from the full commit history.
#
# The setup cell below loads all shared CSV inputs once. Large exact model counts are kept as strings to avoid precision loss, while ordinary counts and solution-share columns are left to pandas' numeric inference.

# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from pathlib import Path

# Global timeout used by Clausy. Completed runtimes are read from total_duration_shell,
# but total_duration is still the reliable timeout indicator: it is NaN when Clausy timed out.
TIMEOUT = 300.0 # seconds
RUNTIME_TICK_VALUES = [1e-3, 1e-2, 1e-1, 1, 10, 60]
RUNTIME_TICK_LABELS = ['1ms', '10ms', '0.1s', '1s', '10s', '1min']

def format_runtime_yaxis(ax):
    ax.yaxis.set_major_locator(ticker.FixedLocator(RUNTIME_TICK_VALUES))
    ax.yaxis.set_major_formatter(ticker.FixedFormatter(RUNTIME_TICK_LABELS))
    ax.yaxis.set_minor_locator(ticker.NullLocator())

# Color-blind friendly Okabe-Ito palette reused throughout the notebook.
# Keep semantic aliases here so all figures can share one visual language.
COLOR = {
    'orange': '#E69F00',
    'sky_blue': '#56B4E9',
    'bluish_green': '#009E73',
    'yellow': '#F0E442',
    'blue': '#0072B2',
    'vermillion': '#D55E00',
    'reddish_purple': '#CC79A7',
    'black': '#000000',
    'white': '#FFFFFF',
    'gray': '#999999',
    'light_gray': '#DDDDDD',
    'timeout': '#D62728',
}
COLOR_ORDER = [
    COLOR['blue'], COLOR['orange'], COLOR['bluish_green'], COLOR['vermillion'],
    COLOR['sky_blue'], COLOR['reddish_purple'], COLOR['yellow'], COLOR['gray'],
]
def color_cycle(n):
    return [COLOR_ORDER[i % len(COLOR_ORDER)] for i in range(n)]

# Keep exact #SAT/model counts as strings: some values exceed floating-point precision.
# Solution share columns are intentionally not listed here; pandas parses them as fractions.
big_int_cols = [
    'left_count', 'left_sliced_count', 'right_count', 'right_sliced_count',
    'common_solutions_count', 'removed_solutions_count', 'added_solutions_count'
]

# All input paths are relative to this notebook. The experiment has three passes:
# main: all systems, repeated three times for runtime stability;
# commits/yearly: BusyBox-only variants without repeated iterations.
stage_root = Path('../../stages-2026-06-10')
stage_paths = {name: stage_root / name for name in ['main', 'commits', 'yearly']}
paper_image_dir = Path('/Users/ek/git/paper-tse-2026-differencing/images')

# The main pass has more preparation stages than the commits/yearly passes.
diff_stage = {'main': '11_diff_with_clausy', 'commits': '8_diff_with_clausy', 'yearly': '8_diff_with_clausy'}

# Load shared metadata once. The overview table uses both dictionaries, and later timeline
# plots reuse the statistics table to map revisions back to dates.
_stats_by_exp = {
    name: pd.read_csv(stage_paths[name] / '3_read_statistics/output.csv')
    for name in stage_paths
}
_km_by_exp = {
    name: pd.read_csv(stage_paths[name] / '6_extract_kconfig_models/output.csv')
    for name in stage_paths
}

# KConfig extraction outputs include the extractor in the path; XML inputs do not.
# This helper derives the subject system name from either path shape.
def extract_system(formula):
    parts = formula.split('/')
    if parts[0].startswith('extract-kconfig-models-with-'):
        return parts[1]
    return parts[0]

# Load one diff result CSV and attach the derived system name. Large count columns stay
# as strings; all other numeric columns, including solution fractions, use pandas inference.
def _load_csv(path):
    df = pd.read_csv(path, dtype={c: str for c in big_int_cols})
    df['system'] = df['left_formula'].apply(extract_system)
    return df

# Combine all experiment passes into df_full. BusyBox commits/yearly are suffixed so they
# stay visible as distinct granularities instead of being merged into regular BusyBox.
df_main    = _load_csv(stage_paths['main'] / diff_stage['main'] / 'output.csv')
df_commits = _load_csv(stage_paths['commits'] / diff_stage['commits'] / 'output.csv')
df_commits['system'] = df_commits['system'] + '-commits'
df_yearly = _load_csv(stage_paths['yearly'] / diff_stage['yearly'] / 'output.csv')
df_yearly['system'] = df_yearly['system'] + '-yearly'
df_full = pd.concat([df_main, df_commits, df_yearly], ignore_index=True)

# Dry runs: clausy was never called (total_duration_shell == 0, total_duration is NaN).
# Exclude them entirely so they do not show up as spurious timeouts in any diagram.
n_dry = (df_full['total_duration'].isna() & (df_full['total_duration_shell'] == 0)).sum()
df_full = df_full[~(df_full['total_duration'].isna() & (df_full['total_duration_shell'] == 0))].reset_index(drop=True)

# Runtime plots use shell duration because it includes formula parsing. Timed-out rows
# stay NaN so boxplots can exclude them from distributions but still count them.
df_full['duration_s'] = np.where(df_full['total_duration'].notna(), df_full['total_duration_shell'] / 1e9, np.nan)

# This experiment always uses the same diff kind on both sides; keep only one to avoid redundant labels.
df_full['diff_kind'] = df_full['left_diff_kind'].astype(str)

systems = sorted(df_full['system'].unique())
n_total   = len(df_full)
n_timeout = df_full['duration_s'].isna().sum()
print(f"{n_total} rows, {n_timeout} timeouts (NaN in total_duration), {n_dry} dry runs excluded")
print(f"Systems: {systems}")
df_full
# Out:
# 72015 rows, 4505 timeouts (NaN in total_duration), 14535 dry runs excluded
# Systems: ['FinancialServices01', 'automotive2', 'axtls', 'buildroot', 'busybox', 'busybox-commits', 'busybox-yearly', 'embtoolkit', 'freetz-ng', 'l4re', 'linux', 'toybox', 'uclibc', 'uclibc-ng']
#        added_constraints  added_solutions  \
# 0                  775.0         0.999423
# 1                  775.0         0.999423
# 2                  775.0         0.999423
# 3                  775.0         0.999423
# 4                  775.0              NaN
# ...                  ...              ...
# 72010               19.0         0.283688
# 72011               19.0         0.283688
# 72012               19.0         0.283688
# 72013               19.0              NaN
# 72014               19.0              NaN
#
#                                    added_solutions_count  \
# 0                                                 744690
# 1                                                 744690
# ...

# %%
# Shared plotting helper for runtime boxplots.
# Input series may contain NaN values; those are timeout rows, not missing measurements.
def _format_bold_percent(rate, decimals=0):
    pct = f"{rate:.{decimals}%}".replace('%', r'\%')
    return f"$\\mathbf{{{pct}}}$"


def draw_boxes(ax, labels, series_list, colors=None, rot=0, title=None, xlabel=None, ylabel='Duration (s)', log_y=False, show_timeout_rate=False):
    # Exclude timeouts from the runtime distribution itself, but keep their counts so the
    # plot shows both completed-run performance and timeout frequency.
    valid_data = [s[s.notna()].values for s in series_list]
    timeouts   = [int(s.isna().sum()) for s in series_list]
    totals     = [len(s) for s in series_list]

    # Keep categories with only timeouts visible, but skip completely empty categories.
    valid = [(i, l, d, t, tot) for i, (l, d, t, tot) in
             enumerate(zip(labels, valid_data, timeouts, totals)) if tot > 0]
    if not valid:
        ax.set_visible(False)
        return

    # Rebuild positions after removing empty categories so labels, colors, and annotations
    # stay aligned even if a system lacks a particular configuration.
    positions   = list(range(1, len(valid) + 1))
    v_labels    = [v[1] for v in valid]
    v_data      = [v[2] for v in valid]
    v_timeouts  = [v[3] for v in valid]
    v_totals    = [v[4] for v in valid]

    has_data = [len(d) > 0 for d in v_data]
    bp_pos   = [p for p, h in zip(positions, has_data) if h]
    bp_data  = [d for d, h in zip(v_data, has_data) if h]

    # Draw boxes only for categories with at least one completed run. Timeout-only
    # categories still get an x-axis label and timeout annotation below.
    if bp_data:
        bp = ax.boxplot(bp_data, positions=bp_pos, patch_artist=True,
                        flierprops=dict(marker='o', markersize=3, alpha=0.4),
                        widths=0.6)
        if colors is None:
            colors = color_cycle(len(valid))
        for box, pos in zip(bp['boxes'], bp_pos):
            idx = positions.index(pos)
            c = colors[idx] if hasattr(colors, '__len__') else colors
            box.set_facecolor(c)
            box.set_alpha(0.7)

    # A logarithmic y-axis makes the many sub-second/small-second runs visible while still
    # keeping timeout-scale runs in the same plot.
    if log_y:
        positive_values = np.concatenate([d[d > 0] for d in v_data if len(d[d > 0]) > 0]) if any(len(d[d > 0]) > 0 for d in v_data) else np.array([0.001])
        ax.set_yscale('log')
        ax.set_ylim(bottom=max(positive_values.min() / 2, 1e-4), top=TIMEOUT * 1.6)
        format_runtime_yaxis(ax)
    else:
        y_lo, y_hi = ax.get_ylim()
        ax.set_ylim(top=max(y_hi, TIMEOUT * 1.2))
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.1f}'))

    # The timeout line makes it visually clear where Clausy stopped measuring completed runtime.
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7, label=f'timeout ({TIMEOUT}s)')
    ax.set_xticks(positions)
    ax.set_xticklabels(v_labels, rotation=rot, ha='right' if rot else 'center')
    ax.set_xlim(0.5, len(valid) + 0.5)
    ax.set_ylabel(ylabel)
    ax.grid(axis='y', linestyle='--', alpha=0.4, which='both')
    if title:
        ax.set_title(title, fontsize=10)
    if xlabel:
        ax.set_xlabel(xlabel)

    # Label each category with its total row count and timeout information. The red label
    # above the timeout line contains both absolute and relative timeout frequency.
    for pos, tot, nt in zip(positions, v_totals, v_timeouts):
        ax.text(pos, -0.12,
                f'n={tot}', transform=ax.get_xaxis_transform(),
                ha='center', va='top', fontsize=7, color=COLOR['gray'])
        if show_timeout_rate:
            rate = nt / tot if tot else 0
            ax.text(pos, -0.22,
                    f'to={rate:.1%}', transform=ax.get_xaxis_transform(),
                    ha='center', va='top', fontsize=7, color=COLOR['gray'])
        if nt > 0 or show_timeout_rate:
            timeout_label = f'{nt}' if not show_timeout_rate else f"{nt}\n({_format_bold_percent(nt / tot, 1)})"
            ax.text(pos, TIMEOUT * (1.08 if log_y else 1.05),
                    timeout_label, ha='center', va='bottom', fontsize=8,
                    color=COLOR['timeout'] if nt > 0 else COLOR['black'])

    ax.legend(fontsize=7, loc='upper right')

# %% [markdown]
# ### Median iteration selection

# %%
# Columns that identify one clausy configuration independently of repeated iterations.
# Do not include output or timing columns here: those are exactly what varies between runs.
_iteration_key = [
    'system', 'left_formula', 'right_formula', 'left_diff_kind', 'right_diff_kind',
    'method', 'engine', 'cnf_transform', 'negate'
]

# Only the main experiment was repeated three times. Commits/yearly rows have no iteration
# number and are added back unchanged after the main rows have been collapsed.
_main_iter = df_full[df_full['iteration'].notna()].copy()
_non_iter  = df_full[df_full['iteration'].isna()].copy()

# Collapse the repeated main iterations to one representative row per configuration.
# Completed rows are ranked by shell runtime within each configuration. Timeouts keep
# duration_s = NaN and are excluded from this runtime ranking.
_main_done = _main_iter[_main_iter['duration_s'].notna()].copy()
_main_done['_iteration_rank'] = (
    _main_done
    .groupby(_iteration_key, dropna=False)['duration_s']
    .rank(method='first')
)
_main_done['_iteration_count'] = (
    _main_done
    .groupby(_iteration_key, dropna=False)['duration_s']
    .transform('count')
)

# The representative completed run is the median completed runtime. With three completed
# iterations this is rank 2; with one or two completed iterations this keeps rank 1.
_main_done['_median_rank'] = ((_main_done['_iteration_count'] + 1) // 2).astype(int)
_main_median = (
    _main_done[_main_done['_iteration_rank'] == _main_done['_median_rank']]
    .drop(columns=['_iteration_rank', '_iteration_count', '_median_rank'])
    .copy()
)

# The ranking above cannot represent configurations where every repetition timed out.
# To keep timeout analyses complete, find configurations that exist among all main rows
# but have no completed row. This is a left outer join: missing _iteration_done means
# zero completed repetitions.
_main_groups = _main_iter.groupby(_iteration_key, dropna=False).size().reset_index(name='_iteration_total')
_main_done_groups = _main_done.groupby(_iteration_key, dropna=False).size().reset_index(name='_iteration_done')
_main_all_timeout_keys = (
    _main_groups
    .merge(_main_done_groups, on=_iteration_key, how='left')
    .query('_iteration_done.isna()')
    [_iteration_key]
)

# For each all-timeout configuration, keep one timeout row as the representative row.
# The inner join keeps only timeout rows belonging to all-timeout configurations; sorting
# by iteration makes the chosen representative deterministic.
_main_timeout = (
    _main_iter[_main_iter['duration_s'].isna()]
    .merge(_main_all_timeout_keys, on=_iteration_key, how='inner')
    .sort_values(_iteration_key + ['iteration'])
    .drop_duplicates(subset=_iteration_key, keep='first')
    .copy()
)

# Separately summarize how much the completed repetitions vary around their median.
# This powers the runtime-spread plot; all-timeout configurations are absent here because
# they have no completed runtime to compare.
_iteration_spread = (
    _main_done
    .groupby(_iteration_key, dropna=False)
    .agg(
        min_duration_s=('duration_s', 'min'),
        median_duration_s=('duration_s', 'median'),
        max_duration_s=('duration_s', 'max'),
        iterations=('duration_s', 'size'),
    )
    .reset_index()
)

# Absolute and relative distances from the median show whether repeated measurements are
# stable in seconds and relative to the scale of each configuration's runtime.
_iteration_spread['median_minus_min_s'] = _iteration_spread['median_duration_s'] - _iteration_spread['min_duration_s']
_iteration_spread['max_minus_median_s'] = _iteration_spread['max_duration_s'] - _iteration_spread['median_duration_s']
_iteration_spread['median_minus_min_rel'] = _iteration_spread['median_minus_min_s'] / _iteration_spread['median_duration_s']
_iteration_spread['max_minus_median_rel'] = _iteration_spread['max_minus_median_s'] / _iteration_spread['median_duration_s']

# After this cell, all analyses use df: median main iteration + representative main timeouts + all non-iterated passes.
df = pd.concat([_main_median, _main_timeout, _non_iter], ignore_index=True)
systems = sorted(df['system'].unique())

print(f"main rows before median selection: {len(_main_iter)}")
print(f"main rows after median selection:  {len(_main_median)}")
print(f"main all-timeout rows kept:       {len(_main_timeout)}")
print(f"non-iterated rows kept:           {len(_non_iter)}")
print(f"analysis rows in df:              {len(df)}")

df
# Out:
# main rows before median selection: 33255
# main rows after median selection:  9598
# main all-timeout rows kept:       1487
# non-iterated rows kept:           38760
# analysis rows in df:              49845
#        added_constraints  added_solutions  \
# 0                  775.0         0.999423
# 1                  775.0              NaN
# 2                  775.0              NaN
# 3                  775.0         0.047354
# 4                  775.0         0.047354
# ...                  ...              ...
# 49840               19.0         0.283688
# 49841               19.0         0.283688
# 49842               19.0         0.283688
# 49843               19.0              NaN
# 49844               19.0              NaN
#
#                                    added_solutions_count  \
# 0                                                 744690
# 1                                                      1
# 2                                                      1
# ...

# %% [markdown]
# ### Runtime spread across repeated iterations

# %%
# Visualize how stable the repeated main measurements are after median selection.
# Only configurations with at least two completed repetitions can show a spread; groups
# with one completed repetition or only timeouts are omitted from this diagnostic plot.
_spread = _iteration_spread[_iteration_spread['iterations'] >= 2].copy()

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
fig.suptitle('Runtime spread across repeated main iterations', fontsize=13)

if _spread.empty:
    for ax in axes:
        ax.set_visible(False)
else:
    # Absolute spread: how many seconds separate the median from the fastest/slowest run.
    axes[0].boxplot(
        [_spread['median_minus_min_s'].dropna(), _spread['max_minus_median_s'].dropna()],
        tick_labels=['median − min', 'max − median'],
        patch_artist=True,
        flierprops=dict(marker='o', markersize=2, alpha=0.35),
    )
    axes[0].set_ylabel('Seconds')
    axes[0].grid(axis='y', linestyle='--', alpha=0.4)

    # Relative spread: normalize by the median runtime so short and long runs are comparable.
    axes[1].boxplot(
        [_spread['median_minus_min_rel'].dropna() * 100, _spread['max_minus_median_rel'].dropna() * 100],
        tick_labels=['median − min', 'max − median'],
        patch_artist=True,
        flierprops=dict(marker='o', markersize=2, alpha=0.35),
    )
    axes[1].set_ylabel('% of median runtime')
    axes[1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%g %%'))
    axes[1].grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## System overview

# %%
import re as _re_ov

# Build fallback variable counts directly from the diff output. This is needed for XML
# systems, which may not have KConfig-model metadata in the regular statistics tables.
_diff_vars = df_full[['system', 'left_formula', 'right_formula',
                        'common_vars', 'removed_vars', 'added_vars']].copy()
_diff_vars = _diff_vars.drop_duplicates(['system', 'left_formula', 'right_formula'])
_diff_vars['left_vars']  = _diff_vars['common_vars'] + _diff_vars['removed_vars']
_diff_vars['right_vars'] = _diff_vars['common_vars'] + _diff_vars['added_vars']

# XML systems encode dates in filenames instead of revision metadata.
def _ov_xml_date(formula):
    m = _re_ov.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
    return m.group(1) if m else None

def _ov_model_file(formula):
    parts = str(formula).split('/')
    if parts and parts[0].startswith('extract-kconfig-models-with-'):
        return '/'.join(parts[1:])
    return str(formula)

# Format the observed period compactly for the LaTeX table.
def _fmt_period(date_min, date_max):
    n = round((date_max - date_min).days / 365.25)
    return f'{date_min.year}--{date_max.year} (\\num{{{n}}})'

_ov_sys = sorted(df_full['system'].unique())

_ov_rows = []
for sys in _ov_sys:
    # Pick the metadata source matching this pass. BusyBox commits/yearly are stored as
    # suffixed systems in df_full but as plain busybox in the stage metadata.
    exp       = 'commits' if sys.endswith('-commits') else 'yearly' if sys.endswith('-yearly') else 'main'
    base      = _re_ov.sub(r'-(commits|yearly)$', '', sys)
    stats_sub = _stats_by_exp[exp][_stats_by_exp[exp]['system'] == base]
    km_sub    = _km_by_exp[exp][_km_by_exp[exp]['system'] == base]

    if stats_sub.empty:
        # Fallback for XML systems: infer versions and dates from formulas, and infer
        # min/max variable counts from the diff columns.
        sys_df     = df_full[df_full['system'] == sys]
        _all_forms = pd.Series(pd.concat([sys_df['left_formula'], sys_df['right_formula']]).dropna().map(_ov_model_file).unique())
        n_vers     = len(_all_forms)
        _dates     = pd.to_datetime(
            pd.Series([_ov_xml_date(f) for f in _all_forms]), errors='coerce').dropna()
        if not _dates.empty:
            period = (_fmt_period(_dates.min(), _dates.max())
                      if len(_dates) >= 2 else str(_dates.min().year))
        else:
            period = 'N/A'
        _form_set = set(_all_forms.astype(str))
        dv = _diff_vars[_diff_vars['system'] == sys].copy()
        side_vars = pd.concat([
            dv[['left_formula', 'left_vars']].rename(columns={'left_formula': 'formula', 'left_vars': 'vars'}),
            dv[['right_formula', 'right_vars']].rename(columns={'right_formula': 'formula', 'right_vars': 'vars'}),
        ])
        side_vars['formula'] = side_vars['formula'].map(_ov_model_file)
        all_vars = side_vars.loc[side_vars['formula'].astype(str).isin(_form_set), 'vars'].dropna()
        var_min  = int(all_vars.min()) if not all_vars.empty else None
        var_max  = int(all_vars.max()) if not all_vars.empty else None
    else:
        # KConfig systems use read_statistics for versions/dates and extracted model
        # metadata for variable counts.
        _sys_df = df_full[df_full['system'] == sys]
        _all_forms = pd.Series(pd.concat([_sys_df['left_formula'], _sys_df['right_formula']]).dropna().map(_ov_model_file).unique())
        n_vers = len(_all_forms)
        _form_revs = _all_forms.astype(str).str.extract(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', expand=False).dropna().astype(str).unique()
        _dates = pd.to_datetime(
            stats_sub.loc[stats_sub['revision'].astype(str).isin(_form_revs), 'committer_date_readable'],
            errors='coerce'
        ).dropna()
        period = (_fmt_period(_dates.min(), _dates.max())
                  if not _dates.empty else 'N/A')
        _form_set = set(_all_forms.astype(str))
        _km_match = km_sub.copy()
        _km_match['_model_norm'] = _km_match['model_file'].map(_ov_model_file)
        vars = _km_match.loc[_km_match['_model_norm'].astype(str).isin(_form_set), 'model_variables'].dropna()
        var_min = int(vars.min()) if not vars.empty else None
        var_max = int(vars.max()) if not vars.empty else None

    _ov_rows.append((sys, n_vers, period, var_min, var_max))

# Emit the table as LaTeX so it can be copied directly into the paper.
lines = []
lines.append(r'\begin{table}[htbp]')
lines.append(r'\centering\small')
lines.append(r'\caption{Overview of subject systems.}')
lines.append(r'\label{tab:systems}')
lines.append(r'\begin{tabular}{l r r r r}')
lines.append(r'\toprule')
lines.append(r'System & Versions & Period & Variables (min) & Variables (max) \\')
lines.append(r'\midrule')
for sys, n_vers, period, var_min, var_max in _ov_rows:
    s_name = sys.replace('_', r'\_')
    s_fmin = f'\\num{{{var_min}}}' if var_min is not None else r'\multicolumn{1}{c}{N/A}'
    s_fmax = f'\\num{{{var_max}}}' if var_max is not None else r'\multicolumn{1}{c}{N/A}'
    lines.append(f'{s_name} & \\num{{{n_vers}}} & {period} & {s_fmin} & {s_fmax} \\\\')
lines.append(r'\bottomrule')
lines.append(r'\end{tabular}')
lines.append(r'\end{table}')
print('\n'.join(lines))
# Out:
# \begin{table}[htbp]
# \centering\small
# \caption{Overview of subject systems.}
# \label{tab:systems}
# \begin{tabular}{l r r r r}
# \toprule
# System & Versions & Period & Variables (min) & Variables (max) \\
# \midrule
# FinancialServices01 & \num{10} & 2017--2018 (\num{1}) & \num{557} & \num{774} \\
# automotive2 & \num{4} & N/A & \num{14010} & \num{18616} \\
# axtls & \num{31} & 2006--2019 (\num{13}) & \num{93} & \num{185} \\
# buildroot & \num{18} & 2009--2013 (\num{4}) & \num{1719} & \num{3806} \\
# busybox & \num{116} & 2004--2026 (\num{22}) & \num{282} & \num{1025} \\
# busybox-commits & \num{1272} & 2003--2024 (\num{21}) & \num{257} & \num{1025} \\
# busybox-yearly & \num{22} & 2003--2024 (\num{21}) & \num{263} & \num{1020} \\
# embtoolkit & \num{11} & 2012--2017 (\num{5}) & \num{2257} & \num{4231} \\
# freetz-ng & \num{12} & 2007--2018 (\num{11}) & \num{267} & \num{9912} \\
# l4re & \num{9} & 2017--2025 (\num{8}) & \num{232} & \num{591} \\
# ...

# %% [markdown]
# ### System overview: analyzed models only
#
# This duplicate uses only models that occur in at least one completed result row. Models that were part of the broader input universe but skipped completely are excluded, so the version count, period, and variable range describe the actually analyzed subset.

# %%
# Duplicate of the system overview restricted to models that actually contributed at least
# one result. This excludes models that were present in the broader candidate universe but were
# skipped completely before clausy produced any classification or solution-count output.
import re as _re_ov_an

_OV_RESULT_COLS = [
    'classification',
    'removed_solutions', 'common_solutions', 'added_solutions',
    'removed_solutions_count', 'common_solutions_count', 'added_solutions_count',
]
_OV_RESULT_COLS = [col for col in _OV_RESULT_COLS if col in df.columns]

_ov_an = df.copy()
if _OV_RESULT_COLS:
    _ov_an = _ov_an[_ov_an[_OV_RESULT_COLS].notna().any(axis=1)].copy()
else:
    # Defensive fallback: if the result columns ever change names, keep completed rows only.
    _ov_an = _ov_an[_ov_an['duration_s'].notna()].copy()

# Per-side variable counts are read from the same analyzed rows, so skipped models do not
# contribute to the min/max range.
_ov_an['left_vars'] = _ov_an['common_vars'] + _ov_an['removed_vars']
_ov_an['right_vars'] = _ov_an['common_vars'] + _ov_an['added_vars']

def _ov_an_fmt_period(date_min, date_max):
    n = round((date_max - date_min).days / 365.25)
    return f'{date_min.year}--{date_max.year} (\\num{{{n}}})'

def _ov_an_xml_date(formula):
    m = _re_ov_an.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
    return m.group(1) if m else None

def _ov_an_model_file(formula):
    parts = str(formula).split('/')
    if parts and parts[0].startswith('extract-kconfig-models-with-'):
        return '/'.join(parts[1:])
    return str(formula)

def _ov_an_model_revision(formula):
    fn = str(formula).split('/')[-1]
    m = _re_ov_an.match(r'\[([\d-]+)\](.+?)(?:\[.*?\])?\.model$', fn)
    if m:
        return m.group(2), pd.to_datetime(m.group(1), format='%Y-%m-%d-%H-%M-%S', errors='coerce')
    return None, pd.NaT

def _ov_an_formula_date(system, formula):
    xml_date = _ov_an_xml_date(formula)
    if xml_date:
        return pd.to_datetime(xml_date, errors='coerce')

    exp = 'commits' if system.endswith('-commits') else 'yearly' if system.endswith('-yearly') else 'main'
    base = _re_ov_an.sub(r'-(commits|yearly)$', '', system)
    revision, bracket_date = _ov_an_model_revision(formula)
    if revision is not None:
        stats_sub = _stats_by_exp[exp][_stats_by_exp[exp]['system'] == base]
        date_rows = stats_sub.loc[stats_sub['revision'].astype(str) == str(revision), 'committer_date_readable']
        if not date_rows.empty:
            return pd.to_datetime(date_rows.iloc[0], errors='coerce')
    return bracket_date

_ov_an_rows = []
for sys in sorted(_ov_an['system'].unique()):
    sys_df = _ov_an[_ov_an['system'] == sys]
    formulas = pd.Series(pd.concat([sys_df['left_formula'], sys_df['right_formula']]).dropna().map(_ov_an_model_file).unique())
    n_vers = len(formulas)

    dates = pd.to_datetime(pd.Series([_ov_an_formula_date(sys, formula) for formula in formulas]), errors='coerce').dropna()
    if not dates.empty:
        period = _ov_an_fmt_period(dates.min(), dates.max()) if len(dates) >= 2 else str(dates.min().year)
    else:
        period = 'N/A'

    exp = 'commits' if sys.endswith('-commits') else 'yearly' if sys.endswith('-yearly') else 'main'
    base = _re_ov_an.sub(r'-(commits|yearly)$', '', sys)
    km_sub = _km_by_exp[exp][_km_by_exp[exp]['system'] == base].copy()
    form_set = set(formulas.astype(str))

    if not km_sub.empty:
        km_sub['_model_norm'] = km_sub['model_file'].map(_ov_an_model_file)
        all_vars = km_sub.loc[km_sub['_model_norm'].astype(str).isin(form_set), 'model_variables'].dropna()
    else:
        side_vars = pd.concat([
            sys_df[['left_formula', 'left_vars']].rename(columns={'left_formula': 'formula', 'left_vars': 'vars'}),
            sys_df[['right_formula', 'right_vars']].rename(columns={'right_formula': 'formula', 'right_vars': 'vars'}),
        ])
        side_vars['formula'] = side_vars['formula'].map(_ov_an_model_file)
        side_vars = side_vars[side_vars['formula'].astype(str).isin(form_set)]
        all_vars = side_vars['vars'].dropna()

    var_min = int(all_vars.min()) if not all_vars.empty else None
    var_max = int(all_vars.max()) if not all_vars.empty else None
    _ov_an_rows.append((sys, n_vers, period, var_min, var_max))

lines = []
lines.append(r'\begin{table}[htbp]')
lines.append(r'\centering\small')
lines.append(r'\caption{Overview of analyzed subject-system models.}')
lines.append(r'\label{tab:systems-analyzed}')
lines.append(r'\begin{tabular}{l r r r r}')
lines.append(r'\toprule')
lines.append(r'System & Versions & Period & Variables (min) & Variables (max) \\')
lines.append(r'\midrule')
for sys, n_vers, period, var_min, var_max in _ov_an_rows:
    s_name = sys.replace('_', r'\_')
    s_fmin = f'\\num{{{var_min}}}' if var_min is not None else r'\multicolumn{1}{c}{N/A}'
    s_fmax = f'\\num{{{var_max}}}' if var_max is not None else r'\multicolumn{1}{c}{N/A}'
    lines.append(f'{s_name} & \\num{{{n_vers}}} & {period} & {s_fmin} & {s_fmax} \\\\')
lines.append(r'\bottomrule')
lines.append(r'\end{tabular}')
lines.append(r'\end{table}')
print('\n'.join(lines))
# Out:
# \begin{table}[htbp]
# \centering\small
# \caption{Overview of analyzed subject-system models.}
# \label{tab:systems-analyzed}
# \begin{tabular}{l r r r r}
# \toprule
# System & Versions & Period & Variables (min) & Variables (max) \\
# \midrule
# FinancialServices01 & \num{10} & 2017--2018 (\num{1}) & \num{557} & \num{774} \\
# automotive2 & \num{4} & N/A & \num{14010} & \num{18616} \\
# axtls & \num{31} & 2006--2019 (\num{13}) & \num{93} & \num{185} \\
# buildroot & \num{18} & 2009--2013 (\num{4}) & \num{1719} & \num{3806} \\
# busybox & \num{116} & 2004--2026 (\num{22}) & \num{282} & \num{1025} \\
# busybox-commits & \num{1272} & 2003--2024 (\num{21}) & \num{257} & \num{1025} \\
# busybox-yearly & \num{22} & 2003--2024 (\num{21}) & \num{263} & \num{1020} \\
# embtoolkit & \num{11} & 2012--2017 (\num{5}) & \num{2257} & \num{4231} \\
# freetz-ng & \num{12} & 2007--2018 (\num{11}) & \num{267} & \num{9912} \\
# l4re & \num{9} & 2017--2025 (\num{8}) & \num{232} & \num{591} \\
# ...

# %% [markdown]
# ## Factor coverage treemap
#
# This treemap visualizes the full `df_full` design before median iteration aggregation. This treemap visualizes only the `main` pass in `df_full`; the BusyBox `commits` and `yearly` passes are intentionally excluded so the factor structure of the main experiment is readable. Rectangles are subdivided by task, source, semantics, CNF transformation, and negation. Area is proportional to the number of rows.

# %%
# Dependency-free recursive treemap for factor coverage in df_full.
# The layout alternates horizontal/vertical splits and is intended as a design overview,
# not as a precise area-labeling substitute for the tables above.
def _tm_pass(row):
    if str(row['system']).endswith('-commits'):
        return 'commits'
    if str(row['system']).endswith('-yearly'):
        return 'yearly'
    return 'main'


def _tm_source(formula):
    first = str(formula).split('/')[0]
    if first == 'extract-kconfig-models-with-kconfigreader':
        return 'KConfigReader'
    if first == 'extract-kconfig-models-with-kclause':
        return 'KClause'
    return 'XML'


def _tm_task(row):
    if row['method'] in ['satisfy', 'satisfy-simplified']:
        return 'classify'
    if row['method'] == 'count':
        return 'quantify #SAT'
    if row['method'] == 'projected-count':
        return 'quantify #∃SAT'
    return row['method']


def _tm_layout(items, x, y, w, h, horizontal=True):
    total = sum(size for _, size in items)
    rects = []
    offset = 0
    for key, size in items:
        frac = size / total if total else 0
        if horizontal:
            rw = w * frac
            rects.append((key, x + offset, y, rw, h, size))
            offset += rw
        else:
            rh = h * frac
            rects.append((key, x, y + offset, w, rh, size))
            offset += rh
    return rects


def _tm_draw_level(ax, data, levels, x, y, w, h, depth=0, path=()):
    if not levels or data.empty:
        return
    level = levels[0]
    counts = data.groupby(level, dropna=False).size().sort_values(ascending=False)
    rects = _tm_layout(list(counts.items()), x, y, w, h, horizontal=(w >= h))
    colors = color_cycle(20)

    for idx, (key, rx, ry, rw, rh, size) in enumerate(rects):
        color = colors[(idx + depth * 4) % len(colors)]
        ax.add_patch(plt.Rectangle((rx, ry), rw, rh, facecolor=color, alpha=0.25 + 0.12 * (depth % 3), edgecolor=COLOR['white'], linewidth=1.2))

        # Label internal rectangles by factor value, and leaf rectangles by both value and size.
        area = rw * rh
        is_leaf = len(levels) == 1
        if area > 0.012 or (is_leaf and area > 0.002):
            label = f'{key}\n{size}' if is_leaf or depth <= 1 else str(key)
            ax.text(rx + rw * 0.02, ry + rh * 0.96, label,
                    ha='left', va='top', fontsize=max(5, 10 - depth), color=COLOR['black'])

        if len(levels) > 1 and area > 0.003:
            sub = data[data[level] == key]
            pad = min(rw, rh) * 0.07
            _tm_draw_level(ax, sub, levels[1:], rx + pad, ry + pad, max(rw - 2 * pad, 0), max(rh - 2 * pad, 0), depth + 1, path + (key,))


_tm_df = df_full.copy()
_tm_df['pass'] = _tm_df.apply(_tm_pass, axis=1)
_tm_df = _tm_df[_tm_df['pass'] == 'main'].copy()
_tm_df['source'] = _tm_df['left_formula'].apply(_tm_source)
_tm_df['task'] = _tm_df.apply(_tm_task, axis=1)

_tm_levels = ['task', 'source', 'diff_kind', 'cnf_transform', 'negate']
fig, ax = plt.subplots(figsize=(14, 7))
_tm_draw_level(ax, _tm_df, _tm_levels, 0, 0, 1, 1)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')
fig.suptitle('Factor coverage in df_full main pass', fontsize=14)
plt.tight_layout()
plt.show()

print(f'Main-pass rows shown: {len(_tm_df)}')
# Out:
# Main-pass rows shown: 33255

# %% [markdown]
# ## Paired runtime factor analysis
#
# The following cells replace the earlier per-system runtime plots with a paired factor analysis. The goal is to isolate one factor at a time, so every plotted runtime must have a matching counterpart where only the factor under study changes. This is important because the raw experiment table contains many algorithm configurations, and comparing all rows against all other rows would mix several effects at once.
#
# The unit of comparison is a **pair of rows**. A pair is formed by holding a set of blocking columns fixed and varying exactly one factor value. For example, a source pair compares KConfigReader with KClause for the same system, formula pair, semantics, method, engine, CNF transformation, and negation setting. The factor-specific `pair_cols` below define these blocking columns explicitly.
#
# The plots use `n` as the number of paired attempts represented by a box category. The box itself contains only completed runtimes, because timeouts have `duration_s = NaN`; timeout rows are still counted in `n`, printed as `to=...%`, and shown in red above the timeout line. Thus `n=739` with `306` timeouts means that the box is drawn from `433` completed runtimes and `306` timed-out paired attempts.
#
# We currently analyze four factors:
#
# - **Source:** KConfigReader vs. KClause. XML benchmark inputs are excluded for this factor because they do not have a KConfig extraction source.
# - **Semantics:** `false` vs. `slice`. This is only compared for the classify/SAT configurations and the ordinary quantification/#SAT configurations.
# - **CNF transformation:** distributive vs. Tseitin. This is only compared for classification, where both transformations are meaningful alternatives. Because this is the only comparison involving the distributive encoding, it is visualized separately.
# - **Negation:** `false` vs. `true`. This is only compared for ordinary #SAT quantification, where negation is an explicitly varied factor.
#
# BusyBox commits and yearly runs are excluded from all runtime factor analyses to avoid letting the much larger BusyBox histories dominate the distributions. The `method` and `engine` columns are not analyzed as factors here; they are only used as blocking columns when necessary to ensure that two paired rows really describe the same benchmark situation.

# %%
# Prepare paired observations for the isolatable runtime factors.
# A row is eligible for a factor only if the corresponding row with the other factor value exists.
# For example, a KClause runtime is used in the source comparison only if the same formula pair
# and algorithm configuration also exists for KConfigReader. This pairing step is where many
# raw rows are intentionally discarded: if the counterpart does not exist, the row cannot
# support an isolated factor comparison.

_FACTOR_EXCLUDED_SYSTEMS = {'busybox-commits', 'busybox-yearly'}
_factor_base = df[~df['system'].isin(_FACTOR_EXCLUDED_SYSTEMS)].copy()

# KConfig-derived formulas have an extractor directory as their first path component.
# XML benchmark formulas do not, so they are labeled separately and ignored only for source.
def _factor_source(formula):
    first = str(formula).split('/')[0]
    if first == 'extract-kconfig-models-with-kconfigreader':
        return 'KConfigReader'
    if first == 'extract-kconfig-models-with-kclause':
        return 'KClause'
    return 'XML'

# Strip the extractor directory so KConfigReader and KClause formulas can be paired.
def _factor_strip_source(formula):
    parts = str(formula).split('/')
    if parts[0].startswith('extract-kconfig-models-with-'):
        return '/'.join(parts[1:])
    return str(formula)

_factor_base['source'] = _factor_base['left_formula'].apply(_factor_source)
_factor_base['left_model'] = _factor_base['left_formula'].apply(_factor_strip_source)
_factor_base['right_model'] = _factor_base['right_formula'].apply(_factor_strip_source)
_factor_base['timeout'] = _factor_base['duration_s'].isna()

# Task labels are used only to restrict factor comparisons to meaningful configurations.
# projected-count is deliberately excluded from the diff-kind and negation comparisons below.
def _factor_task(row):
    if row['method'] in ['satisfy', 'satisfy-simplified']:
        return 'classify/SAT'
    if row['method'] == 'count':
        return 'quantify/#SAT'
    if row['method'] == 'projected-count':
        return 'quantify/#∃SAT'
    return row['method']

_factor_base['task'] = _factor_base.apply(_factor_task, axis=1)
_factor_base['task_group'] = np.where(_factor_base['task'].str.startswith('classify'), 'classify', 'quantify')

# Factor specifications.
# - value_col/values define the two factor values being compared.
# - filter restricts the data to configurations where that comparison is meaningful.
# - pair_cols are blocking columns: they must be equal on both sides of a pair.
# - context_cols are not used for pairing; they only build labels for diagnostic split plots.
_FACTOR_DEFS = [
    {
        'factor': 'source',
        'label': 'Source',
        'value_col': 'source',
        'values': ['KConfigReader', 'KClause'],
        'filter': lambda d: d[d['source'].isin(['KConfigReader', 'KClause'])],
        'pair_cols': ['system', 'left_model', 'right_model', 'diff_kind', 'method', 'engine', 'cnf_transform', 'negate'],
        'context_cols': ['task', 'diff_kind', 'cnf_transform', 'negate'],
    },
    {
        'factor': 'semantics',
        'label': 'Semantics',
        'value_col': 'diff_kind',
        'values': ['false', 'slice'],
        'filter': lambda d: d[d['task'].isin(['classify/SAT', 'quantify/#SAT'])],
        'pair_cols': ['system', 'source', 'left_model', 'right_model', 'method', 'engine', 'cnf_transform', 'negate'],
        'context_cols': ['task', 'source', 'cnf_transform', 'negate'],
    },
    {
        'factor': 'cnf',
        'label': 'CNF transformation',
        'value_col': 'cnf_transform',
        'values': ['dist', 'tseitin'],
        'filter': lambda d: d[d['task'] == 'classify/SAT'],
        'pair_cols': ['system', 'source', 'left_model', 'right_model', 'diff_kind', 'engine', 'negate'],
        'context_cols': ['source', 'diff_kind'],
    },
    {
        'factor': 'negation',
        'label': 'Negation',
        'value_col': 'negate',
        'values': [False, True],
        'filter': lambda d: d[d['task'] == 'quantify/#SAT'],
        'pair_cols': ['system', 'source', 'left_model', 'right_model', 'diff_kind', 'method', 'engine', 'cnf_transform'],
        'context_cols': ['source', 'diff_kind'],
    },
]

# Build a compact label for diagnostic plots from the display-only context columns.
# These labels do not participate in pairing; pairing is already fixed by pair_cols.
def _factor_context(row, context_cols):
    return ' | '.join(f'{col}={row[col]}' for col in context_cols)

def _paired_factor_observations(spec):
    # Apply the factor-specific eligibility filter first. For example, CNF comparisons keep
    # only classify rows, while negation comparisons keep only ordinary #SAT quantification.
    sub = spec['filter'](_factor_base).copy()

    # value_col is the one column allowed to differ inside a pair. values are the two values
    # we want to compare in this factor analysis, such as false/slice or dist/tseitin.
    value_col = spec['value_col']
    values = spec['values']

    # pair_cols define the blocking key. Rows with the same pair_cols describe the same
    # benchmark/configuration except for value_col, so they are legitimate counterparts.
    pair_cols = spec['pair_cols']

    # Timed-out rows have duration_s = NaN, so duration cannot be used to decide whether a
    # counterpart exists. Instead, attach a dummy presence value and pivot only that flag.
    # The resulting table has one row per blocking key and one column per factor value.
    present = (
        sub.assign(_present=1)
        .pivot_table(index=pair_cols, columns=value_col, values='_present', aggfunc='max')
    )

    # If one of the requested factor values is absent from the whole filtered dataset,
    # add an empty column so the all-values-present test below still works uniformly.
    for value in values:
        if value not in present.columns:
            present[value] = np.nan

    # Keep only blocking keys for which both factor values exist. The .loc[:, values]
    # form is intentional: for the original boolean negate column, [False, True] would
    # otherwise be interpreted by pandas as a boolean row mask rather than column labels.
    paired_keys = present[present.loc[:, values].notna().all(axis=1)].loc[:, values].reset_index()[pair_cols]

    # Give each comparable blocking key a stable pair id. Each id will later have exactly
    # one row per factor value after joining back to the original long table.
    paired_keys = paired_keys.reset_index(drop=True)
    paired_keys['_pair_id'] = [f"{spec['factor']}:{i}" for i in range(len(paired_keys))]

    # Join the comparable keys back to the original rows. This restores all measurements
    # and metadata while dropping rows whose counterpart is missing.
    paired = sub.merge(paired_keys, on=pair_cols, how='inner')

    # Keep only the two requested factor values. This matters if value_col contains other
    # values that were irrelevant to this particular factor comparison.
    paired = paired[paired[value_col].isin(values)].copy()

    # If duplicate rows exist for the same pair/value combination, keep one deterministic
    # representative. After median iteration selection this should normally be redundant,
    # but it protects the paired tables against accidental duplicate measurements.
    paired = paired.sort_values(pair_cols + [value_col]).drop_duplicates(pair_cols + [value_col], keep='first')

    # Add generic columns used by all downstream plots/statistics, independent of which
    # original column supplied the factor value.
    paired['factor'] = spec['factor']
    paired['factor_label'] = spec['label']
    paired['factor_value'] = paired[value_col]

    # Context labels are purely for diagnostic split plots. They make it easy to see, for
    # example, whether a factor effect appears only for one task/source/CNF combination.
    paired['context'] = paired.apply(lambda row: _factor_context(row, spec['context_cols']), axis=1)
    paired['context_short'] = paired['context'].str.replace('source=', '', regex=False)
    return paired


# Stack all factor-specific paired tables into one long table. A physical experiment row can
# appear multiple times here if it is useful for multiple factor comparisons; that is intended.
_factor_observations = pd.concat(
    [_paired_factor_observations(spec) for spec in _FACTOR_DEFS],
    ignore_index=True,
)

# Boolean factor values are valid original column names after pivoting, but pandas treats
# [False, True] as a boolean mask in ordinary column selection. Resolve by equality instead.
def _factor_column(table, value):
    for column in table.columns:
        if column == value:
            return table.loc[:, column]
    raise KeyError(value)

def _factor_timeout_unique_counts(sub, box_cols, key_cols):
    # Compare timeout sets across the boxes named by box_cols. For the isolated-factor plot,
    # this is usually two boxes (the two factor values). For the CNF/classification plot,
    # this is four boxes: dist/Closed, dist/Projection, tseitin/Closed, tseitin/Projection.
    # A timeout is counted as unique for one box only if the same underlying key did not time
    # out in any other box from the same comparison universe.
    timeout_sets = {}

    # First build one timeout set per box. groupby(box_cols) partitions the plotted data into
    # exactly the visual boxes whose labels will receive an only=... value.
    for box_key, box_sub in sub.groupby(box_cols, dropna=False):
        # pandas returns a scalar group key when there is only one grouping column, but a tuple
        # when there are several. Normalize to tuples so callers can always look up results in
        # the same shape, e.g., ('slice',) for one-column boxes or ('tseitin', 'slice') for two.
        if not isinstance(box_key, tuple):
            box_key = (box_key,)

        # Keep only timed-out rows for this box. Completed rows are irrelevant for uniqueness;
        # they still contribute to the separate all-timeout rate shown in the first label line.
        timed_out = box_sub[box_sub['timeout']]

        # Convert the identifying key columns to tuples so they can be stored in a set. The
        # key columns define what counts as the "same" underlying task across boxes.
        timeout_sets[box_key] = set(map(tuple, timed_out[key_cols].to_numpy()))

    result = {}
    for box_key, box_timeouts in timeout_sets.items():
        # Combine all timeout keys from every other box in the same comparison universe.
        # Subtracting this union leaves only the timeout keys that occurred exclusively in
        # the current box.
        other_timeouts = set().union(*(timeouts for other, timeouts in timeout_sets.items() if other != box_key))
        result[box_key] = {
            'exclusive': len(box_timeouts - other_timeouts),
        }
    return result


def _format_timeout_label(timeouts, timeout_rate, exclusive):
    # First line: all timeouts for this box relative to all attempts in this box.
    # Second line: absolute number of timeouts that occur only for this box.
    # Mathtext is used only around the percentage so the relative number is bold,
    # while the absolute count and uniq count remain normal weight.
    rate = f"{timeout_rate:.0%}".replace('%', r'\%')
    return f"{timeouts} ($\\mathbf{{{rate}}}$)\nuniq={exclusive['exclusive']}"


def _timeout_label_color(timeouts):
    return COLOR['timeout'] if timeouts > 0 else COLOR['black']


# Count comparable pairs, not rows. Each pair normally contributes two rows, one per value.
_factor_pair_counts = (
    _factor_observations
    .drop_duplicates(['factor', '_pair_id'])
    .groupby('factor')
    .size()
    .reindex([spec['factor'] for spec in _FACTOR_DEFS])
)

print('Comparable pairs per factor:')
print(_factor_pair_counts.to_string())
print(f"Runtime factor rows after excluding BusyBox commits/yearly: {len(_factor_base)}")
print(f"Paired factor observations: {len(_factor_observations)}")
# Out:
# Comparable pairs per factor:
# factor
# source       5355
# semantics    4434
# cnf          1478
# negation     2956
# Runtime factor rows after excluding BusyBox commits/yearly: 11085
# Paired factor observations: 28446

# %% [markdown]
# ### CNF transformation runtime
#
# This figure is intentionally separated from the other isolated-factor plot because it is the only view that contains `dist` encodings. It compares distributive vs. Tseitin only within the classification task, where both encodings are meaningful alternatives. The boxes are split by semantics (`false` vs. `slice`) because the timeout behavior differs strongly between these two cases. As everywhere in this section, `n` counts paired attempts, while the box shape uses only completed runtimes.

# %%
# CNF transformation is the only factor involving the distributive encoding.
# It gets its own figure because the remaining factor analysis intentionally excludes
# distributive rows.
def _draw_cross_split_factor_boxes(ax, sub, spec, split_col):
    # Draw the factor under study on the x-axis and split each factor value by one
    # additional context column. For the CNF figure, spec['values'] is ['dist', 'tseitin']
    # and split_col is 'diff_kind', so each x-axis group contains one Closed-World box
    # and one Projection box.
    values = spec['values']
    splits = sorted(sub[split_col].dropna().unique())
    if not splits:
        ax.set_visible(False)
        return

    # Colors encode the split dimension, not the x-axis factor value. This matters because
    # the viewer should compare dist vs. tseitin along the x-axis while reading the blue /
    # vermilion sub-boxes as the two semantic settings inside each CNF transformation.
    # The same binary contrast convention is used elsewhere: first split blue, second
    # split vermilion. Timeout annotations use COLOR['timeout'] instead.
    split_colors = {split: color for split, color in zip(splits, [COLOR['blue'], COLOR['vermillion']])}

    # Each factor value sits at an integer x-position. The split boxes are placed around
    # that position using symmetric offsets, so the two boxes still read as one grouped
    # category. group_width controls the total width of the group, box_width the width of
    # each individual split box.
    group_width = 0.8
    box_width = group_width / len(splits) * 0.85
    offsets = np.linspace(-group_width / 2 + box_width / 2, group_width / 2 - box_width / 2, len(splits))

    # Only completed runs can be drawn as boxplot data. We still keep timed-out attempts
    # in the category counts below, but they stay NaN in duration_s and therefore must not
    # influence quartiles or medians.
    positive_values = sub['duration_s'].dropna()
    positive_values = positive_values[positive_values > 0]

    # For the CNF/classification plot, the uniqueness universe is all four boxes:
    # dist/Closed, dist/Projection, tseitin/Closed, and tseitin/Projection. Thus, only=...
    # means unique to this exact box compared with the other three boxes, not merely unique
    # compared with the neighboring semantic box. The key omits both plotted dimensions
    # (factor_value and diff_kind). It also omits method because this figure treats all
    # four boxes as variants of the same underlying classify comparison for timeout
    # uniqueness; including method would split that comparison universe apart.
    box_timeout_uniques = _factor_timeout_unique_counts(
        sub,
        ['factor_value', split_col],
        ['system', 'source', 'left_model', 'right_model', 'engine', 'negate'],
    )

    for vi, value in enumerate(values):
        for si, split in enumerate(splits):
            # One plotted category is determined by both dimensions:
            #   value: the x-axis CNF transformation, e.g., dist or tseitin
            #   split: the semantic setting, e.g., false or slice
            # The series contains completed runtimes plus NaN timeout attempts.
            series = sub[(sub['factor_value'] == value) & (sub[split_col] == split)]['duration_s']
            if series.empty:
                continue

            # Separate completed runtimes from timeout attempts. The completed values form
            # the boxplot; timeout count/rate is rendered explicitly above the timeout line.
            completed = series.dropna().values
            timeouts = int(series.isna().sum())
            total = len(series)
            timeout_rate = timeouts / total if total else 0
            pos = vi + 1 + offsets[si]

            # Draw no box for timeout-only categories, because there is no completed-runtime
            # distribution. Those categories still get a timeout label, so they remain visible.
            if len(completed) > 0:
                bp = ax.boxplot(
                    [completed], positions=[pos], widths=box_width,
                    patch_artist=True,
                    flierprops=dict(marker='o', markersize=2, alpha=0.35),
                    medianprops=dict(color=COLOR['black'], linewidth=1.2),
                )
                bp['boxes'][0].set_facecolor(split_colors.get(split, COLOR['gray']))
                bp['boxes'][0].set_alpha(0.75)

                # The leftmost dist/false box corresponds to the original distributive
                # Closed-World setting used by Thüm's algorithm. Place the label just below
                # the drawn box using the box geometry, not a magic data percentile, so the
                # label follows the visual box even if the distribution changes.
                if value == 'dist' and split == 'false':
                    bp['boxes'][0].set_linestyle('--')
                    box_y = bp['boxes'][0].get_path().vertices[:, 1]
                    box_bottom, box_top = box_y.min(), box_y.max()
                    label_y = np.exp(np.log(box_bottom) - 0.16 * (np.log(box_top) - np.log(box_bottom)))
                    ax.text(pos + 0.035, label_y, "Thüm's  Algorithm",
                            ha='center', va='top', fontsize=10, color=COLOR['black'])

            # Show timeout count/rate plus the number of timeouts unique to this exact
            # box among the four CNF/semantics boxes.
            exclusive = box_timeout_uniques[(value, split)]
            ax.text(pos, TIMEOUT * 1.18, _format_timeout_label(timeouts, timeout_rate, exclusive),
                    ha='center', va='bottom', fontsize=9, color=_timeout_label_color(timeouts))

            # Show the number of paired attempts represented by this split box. This includes
            # completed runtimes and timeout attempts, matching the denominator of the timeout
            # percentage above. Keep it inside the plot area so the figure layout stays fixed.
            ax.text(pos, 0.03, f'n={total}', transform=ax.get_xaxis_transform(),
                    ha='center', va='bottom', fontsize=9, color=COLOR['gray'])

    # The horizontal line marks the configured timeout threshold. The y-axis is logarithmic
    # because completed runtimes span several orders of magnitude, while timeouts sit at
    # 300 seconds and should still be visible in the same figure.
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(bottom=max(positive_values.min() / 5, 1e-4) if not positive_values.empty else 1e-4,
                top=TIMEOUT * 12)

    # The x-axis labels are the CNF transformation values. Split labels are intentionally
    # moved to the legend so the x-axis remains about the factor under study.
    ax.set_xticks(range(1, len(values) + 1))
    ax.set_xticklabels(values, rotation=0, ha='center', fontsize=12)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)

    # Keep the log axis visually quiet: selected human-readable time ticks only.
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

    # Human-readable legend labels for the semantic split. The colors match split_colors,
    # and the timeout line is listed separately so timeout red never competes with factor
    # semantics.
    split_labels = {'false': 'Closed', 'slice': 'Projection'}
    semantic_handles = [
        plt.matplotlib.patches.Patch(
            facecolor=split_colors.get(split, COLOR['gray']),
            alpha=0.75,
            label=split_labels.get(split, split),
        )
        for split in splits
    ]
    # Vertical legend: only semantic colors are listed here. The timeout threshold is
    # already encoded by the dashed red line and the red timeout labels above the boxes.
    ax.legend(
        handles=semantic_handles, fontsize=10, loc='lower right',
        bbox_to_anchor=(1.0, 0.1),
        handletextpad=0.4, handlelength=1.8,
    )


# Select the already-paired CNF observations prepared above. No pairing or filtering happens
# in this cell; it only renders the CNF-specific paired observations as a publication figure.
_cnf_spec = next(spec for spec in _FACTOR_DEFS if spec['factor'] == 'cnf')
_cnf_sub = _factor_observations[_factor_observations['factor'] == 'cnf']

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(5.4, 2.8))
    _draw_cross_split_factor_boxes(ax, _cnf_sub, _cnf_spec, 'diff_kind')
    ax.set_title('CNF Transformation', fontsize=12)
    plt.tight_layout()
    fig.savefig(paper_image_dir / 'runtime-cnf-transformation.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# %% [markdown]
# ### Runtime by isolated paired factor without `dist` encoding
#
# This figure removes the `dist` encoding completely. It excludes the CNF-transformation factor and filters out all rows with `cnf_transform = dist` before plotting source, semantics, and negation. This makes the plot easier to interpret: every remaining comparison is a Tseitin-based comparison, and semantics is no longer split by CNF transformation.

# %%
# Isolated paired factors after removing every dist row.
# The previous figure answers the CNF-specific question (dist vs. tseitin). This figure
# answers the remaining factor questions on the Tseitin-only subset, so the distributional
# comparisons are not dominated by the special distributive encoding.
_isolated_factor_defs = [spec for spec in _FACTOR_DEFS if spec['factor'] != 'cnf']

# Remove both the CNF factor itself and every dist row from the remaining factors.
# This is stricter than merely hiding the CNF panel: source, semantics, and negation are
# all evaluated on the same Tseitin-only universe of observations.
_isolated_factor_observations = _factor_observations[
    (_factor_observations['factor'] != 'cnf') &
    (_factor_observations['cnf_transform'] != 'dist')
].copy()

# Short labels for the compact publication figure. These are display labels only; all
# filtering and pairing above still use the original factor values.
_isolated_value_labels = {
    'KConfigReader': 'KCR',
    'KClause': 'KClause',
    'false': 'Closed',
    'slice': 'Projection',
    False: 'No',
    True: 'Yes',
}

def _draw_isolated_factor_boxes(ax, sub, spec):
    # Draw one facet for one isolated factor. Unlike the CNF plot, there is no additional
    # split inside each x-axis value: each box is simply one of the two comparable values
    # from spec['values'], using the already-paired observations prepared earlier.
    values = list(spec['values'])
    if spec['factor'] == 'negation':
        values = list(reversed(values))

    # Build one runtime series per factor value. A series includes completed runtimes and
    # NaN timeout attempts. The NaNs must be preserved long enough to count timeouts, but
    # must not be passed to the boxplot because box quartiles should describe completed
    # runtimes only.
    series = [sub[sub['factor_value'] == value]['duration_s'] for value in values]

    # Positive completed runtimes determine the lower bound of the log-scale axis. Timeout
    # rows are NaN and excluded here; zero or negative values would be invalid on a log axis.
    positive_values = pd.concat([s.dropna() for s in series], ignore_index=True)
    positive_values = positive_values[positive_values > 0]

    # Use one neutral box color in this compact figure. The compared values are already
    # identified by their x-axis labels; using equal color avoids suggesting an additional
    # visual grouping across unrelated facets. Timeout information remains red.
    box_color = COLOR['gray']

    # Here the boxes are the two values of the factor shown in this facet. Since
    # _pair_id already aligns those two values, it is the correct counterpart key for
    # timeout uniqueness computation with the general helper.
    timeout_exclusives = _factor_timeout_unique_counts(sub, ['factor_value'], ['_pair_id'])

    for vi, (value, value_series) in enumerate(zip(values, series)):
        # Split the plotted category into completed observations and timeout metadata.
        # completed drives the box; timeouts/total drive the red annotation above 300s.
        completed = value_series.dropna().values
        timeouts = int(value_series.isna().sum())
        total = len(value_series)
        timeout_rate = timeouts / total if total else 0
        pos = vi + 1

        # Draw no box for timeout-only categories. Such categories have no completed-runtime
        # distribution, but they still remain visible via the timeout annotation below.
        if len(completed) > 0:
            bp = ax.boxplot(
                [completed], positions=[pos], widths=0.6,
                patch_artist=True,
                flierprops=dict(marker='o', markersize=2, alpha=0.35),
                medianprops=dict(color=COLOR['black'], linewidth=1.2),
            )
            bp['boxes'][0].set_facecolor(box_color)
            bp['boxes'][0].set_alpha(0.75)

        # Timeout labels have two lines: total timeouts for this value, then the subset
        # that occurred only for this value and not for its paired counterpart. The shared
        # timeouts are implicit because they are total minus only.
        exclusive = timeout_exclusives[(value,)]
        ax.text(pos, TIMEOUT * 1.18, _format_timeout_label(timeouts, timeout_rate, exclusive),
                ha='center', va='bottom', fontsize=9, color=_timeout_label_color(timeouts))

        # Show the number of paired attempts represented by this box. This includes both
        # completed runtimes and timeout attempts, matching the denominator of the timeout
        # percentage above. Put it inside the plot area near the lower y-limit so the figure
        # size and external layout do not change.
        ax.text(pos, 0.03, f'n={total}', transform=ax.get_xaxis_transform(),
                ha='center', va='bottom', fontsize=9, color=COLOR['gray'])

    # Draw the configured timeout threshold and use a logarithmic runtime axis. The upper
    # limit leaves extra space for the two-line timeout annotations above the 300s line; the lower limit adapts
    # to the smallest completed runtime in this facet.
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(bottom=max(positive_values.min() / 5, 1e-4) if not positive_values.empty else 1e-4,
                top=TIMEOUT * 9)

    # X labels are display-only abbreviations; the facet title names the factor being varied.
    ax.set_xticks(range(1, len(values) + 1))
    ax.set_xticklabels([_isolated_value_labels.get(value, value) for value in values], rotation=0, ha='center', fontsize=12)
    ax.set_title(spec['label'], fontsize=12)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)

    # Keep the log axis sparse and readable for the paper figure.
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    # One row of facets, one facet per remaining factor. sharey=True makes the runtime scale
    # directly comparable across source, semantics, and negation.
    fig, axes = plt.subplots(1, len(_isolated_factor_defs), figsize=(5.4, 2.8), sharey=True, squeeze=False)

    for ax, spec in zip(axes[0], _isolated_factor_defs):
        # Select the already-paired observations for this factor; no new pairing happens here.
        sub = _isolated_factor_observations[_isolated_factor_observations['factor'] == spec['factor']]
        _draw_isolated_factor_boxes(ax, sub, spec)

    # Shared y-axis: keep the scale and grid aligned, but only label the first facet to avoid
    # repeated axis text and reduce horizontal clutter between facets.
    for ax in axes[0][1:]:
        ax.set_ylabel('')
        ax.tick_params(axis='y', which='both', left=False, labelleft=False)

    # No legend is needed here: all boxes intentionally share one neutral color, and the
    # timeout threshold is labeled by its red line style in the surrounding text/figure caption.

    # Tighten facet spacing for the compact paper figure while preserving enough room for
    # timeout labels and horizontal x-axis labels.
    plt.tight_layout(w_pad=0.2)
    fig.subplots_adjust(wspace=0.05)
    fig.savefig(paper_image_dir / 'runtime-isolated-factors.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# %% [markdown]
# ### Runtime by engine within task
#
# This plot compares engines only within the same task facet: classification, ordinary `#SAT` quantification, and projected model counting. The x-axis shows the engines available for that task. Pairing is performed separately inside each facet, so ordinary `#SAT` and projected model counting are not compared to each other; they are different tasks. `satisfy-simplified` is excluded here because it belongs to the separate CNF-transformation/Thüm baseline figure.

# %%
# Engine-by-method runtime plot. The question here is whether different engines behave
# differently inside one task group. The three facets are separate tasks: classification,
# #SAT quantification, and projected model counting. Pairing is performed only within a
# facet; in particular, ordinary #SAT and projected model counting are not comparable to
# each other.

# Plot facets from left to right. The names are the raw method values in the CSV, not
# display labels. satisfy-simplified is intentionally absent because it is Thüm's
# distributive baseline and belongs to the separate CNF-transformation figure.
_ENGINE_METHOD_ORDER = ['satisfy', 'count', 'projected-count']

# Short facet titles for the three task groups. These labels are deliberately task-level
# labels, not engine labels, because each facet has its own independent pairing universe.
_ENGINE_METHOD_LABELS = {
    'satisfy': 'classify',
    'count': 'quantify$_\kappa$ (#SAT)',
    'projected-count': 'quantify$_\kappa$ (#$\exists$SAT)',
}

# Engine order within each facet. The projected-count engines are intentionally listed
# separately from ordinary #SAT engines because they solve a different task and must not be
# paired against d4/ganak from the count facet.
_ENGINE_ORDER = {
    'satisfy': ['kissat'],
    'count': ['d4', 'ganak'],
    'projected-count': ['d4-counting', 'd4-proj-ddnnf-compiler', 'ganak-pmc'],
}

# Display labels for engine names. Some raw engine identifiers encode implementation details
# that are useful in the CSV but too long for the compact x-axis.
_ENGINE_LABELS = {
    'd4-counting': 'd4',
    'd4-proj-ddnnf-compiler': 'pd4',
    'ganak-pmc': 'ganak',
}

# Blocking key for engine pairing within one method. engine is omitted because that is the
# factor being compared; method is omitted because this key is only used inside one method
# facet at a time. All remaining columns identify the same benchmark/configuration.
_ENGINE_PAIR_COLS = ['system', 'source', 'left_model', 'right_model', 'diff_kind', 'cnf_transform', 'negate']

def _paired_engine_observations(method):
    # Return the rows that are comparable across engines for one task facet. The function
    # intentionally receives a single method, not a list of methods, because every task facet
    # has its own comparison universe. This prevents ordinary #SAT and projected model
    # counting from being paired or interpreted as variants of the same task.
    #
    # Work on the same runtime-analysis base as the factor plots: BusyBox commits/yearly are
    # already excluded in _factor_base. This function is called separately per method/task,
    # so complete-pair filtering can only compare engines within that one task.
    # satisfy-simplified is deliberately not part of this plot because it corresponds to
    # Thüm's distributive baseline, which is handled in the separate CNF figure.
    # Start with exactly one raw method value. For example, method='count' is ordinary
    # #SAT quantification; method='projected-count' is projected model counting. They are
    # handled in separate calls.
    sub = _factor_base[_factor_base['method'] == method].copy()

    # Keep engines in the manually chosen plotting order, but drop engines absent from this
    # dataset. This lets the plotting code use the same configuration even if a future run
    # omits one engine.
    engines = [engine for engine in _ENGINE_ORDER[method] if engine in set(sub['engine'])]
    sub = sub[sub['engine'].isin(engines)].copy()

    if len(engines) <= 1:
        # With only one engine there is no pairing decision to make. Keep the rows so the
        # facet still reports the runtime distribution for that task. Timeout uniqueness is
        # handled later by the general helper, where a one-box universe means that all
        # timeouts in that box are unique within the facet.
        return sub, engines

    # Pair engines by the benchmark/configuration columns that should be identical across
    # engines. The engine column is the only dimension allowed to vary. This is what makes a
    # D4 runtime comparable to the corresponding Ganak runtime, instead of comparing unrelated
    # model pairs or semantic settings.
    # Build a presence table instead of pivoting runtimes. Runtime can be NaN for a timeout,
    # but a timeout is still a valid attempt and must count as present for pairing.
    present = (
        sub.assign(_present=1)
        .pivot_table(index=_ENGINE_PAIR_COLS, columns='engine', values='_present', aggfunc='max')
    )

    # Make the all-engines-present test robust even if an engine has no rows in this run.
    # Missing engines become all-NaN columns and therefore cannot pass the test below.
    for engine in engines:
        if engine not in present.columns:
            present[engine] = np.nan

    # Keep only benchmark/configuration keys for which every engine in this facet exists.
    # This is the actual paired-comparison step: a D4 run is shown only if the corresponding
    # Ganak run exists for the same model pair and configuration, and vice versa.
    paired_keys = present[present.loc[:, engines].notna().all(axis=1)].reset_index()[_ENGINE_PAIR_COLS]

    # Join the complete engine keys back to the long table and keep one deterministic row per
    # engine/key. After median-iteration selection this should normally be unique already.
    paired = sub.merge(paired_keys, on=_ENGINE_PAIR_COLS, how='inner')
    paired = paired.sort_values(_ENGINE_PAIR_COLS + ['engine']).drop_duplicates(_ENGINE_PAIR_COLS + ['engine'], keep='first')
    return paired, engines

def _draw_engine_method_boxes(ax, sub, method, engines):
    # Draw one task/method facet. This function assumes _paired_engine_observations already
    # removed unpaired engine rows for multi-engine facets, so every box in a facet describes
    # comparable attempts.
    #
    # Draw one method facet with engines on the x-axis. Boxes are neutral gray because color
    # is not encoding the engine here; the engine names are explicit x-axis labels. Timeout
    # text follows the same two-line convention as the previous runtime diagrams.
    # Completed positive runtimes determine the lower log-axis bound. Timeout attempts are
    # represented as NaN durations, so they are excluded from box quartiles and axis minima.
    positive_values = sub['duration_s'].dropna()
    positive_values = positive_values[positive_values > 0]

    # Use one neutral color for all engine boxes. The x-axis already identifies engines, and
    # using color here would suggest a cross-facet categorical encoding that does not exist.
    box_color = COLOR['gray']

    # Engine-unique timeouts compare all engine boxes in this facet. If a facet has only one
    # engine, the general helper correctly treats that engine's timeouts as unique within the
    # facet, which is what the only=... label should communicate.
    timeout_uniques = _factor_timeout_unique_counts(sub, ['engine'], _ENGINE_PAIR_COLS)

    for xi, engine in enumerate(engines, start=1):
        # One plotted box contains all paired attempts for one engine in this method facet.
        # The series includes NaN timeout attempts so total and timeout_rate use all attempts,
        # while completed contains only the values that can enter the boxplot.
        series = sub[sub['engine'] == engine]['duration_s']
        completed = series.dropna().values
        timeouts = int(series.isna().sum())
        total = len(series)
        timeout_rate = timeouts / total if total else 0

        # Timeout-only engines get no box because there is no completed-runtime distribution,
        # but they still get the timeout label and n=... label below.
        if len(completed) > 0:
            bp = ax.boxplot(
                [completed], positions=[xi], widths=0.6,
                patch_artist=True,
                flierprops=dict(marker='o', markersize=2, alpha=0.35),
                medianprops=dict(color=COLOR['black'], linewidth=1.2),
            )
            bp['boxes'][0].set_facecolor(box_color)
            bp['boxes'][0].set_alpha(0.75)

        # Two-line timeout label: first line is all timeouts for this engine; second line is
        # timeouts unique to this engine within the current facet. For a one-engine facet, all
        # timeouts are unique within that facet by definition.
        ax.text(xi, TIMEOUT * 1.18, _format_timeout_label(timeouts, timeout_rate, timeout_uniques[(engine,)]),
                ha='center', va='bottom', fontsize=9, color=_timeout_label_color(timeouts))

        # n counts all paired attempts for this engine, including completed runs and timeouts.
        ax.text(xi, 0.03, f'n={total}', transform=ax.get_xaxis_transform(),
                ha='center', va='bottom', fontsize=9, color=COLOR['gray'])

    # Match the publication-style runtime plots above: timeout threshold, logarithmic y-axis,
    # sparse major ticks, and enough top space for two-line timeout labels.
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(bottom=max(positive_values.min() / 8, 1e-4) if not positive_values.empty else 1e-4,
                top=TIMEOUT * 9)
    # Engine labels are intentionally short and horizontal to match the previous compact
    # figures. The facet title, not the x-axis, communicates the task/method.
    ax.set_xticks(range(1, len(engines) + 1))
    ax.set_xticklabels([_ENGINE_LABELS.get(engine, engine) for engine in engines], rotation=0, ha='center', fontsize=12)
    ax.set_title(_ENGINE_METHOD_LABELS[method], fontsize=12)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, axes = plt.subplots(
        1, len(_ENGINE_METHOD_ORDER), figsize=(5.4, 2.8), sharey=True, squeeze=False,
        gridspec_kw={'width_ratios': [0.65, 1.0, 1.45]},
    )

    for ax, method in zip(axes[0], _ENGINE_METHOD_ORDER):
        # Pair and draw each task independently. This is what prevents cross-task comparisons
        # such as ordinary #SAT vs. projected model counting.
        sub, engines = _paired_engine_observations(method)
        _draw_engine_method_boxes(ax, sub, method, engines)

    # Shared y-axis: keep the runtime scale aligned, but avoid repeating the y-axis labels
    # in every facet.
    for ax in axes[0][1:]:
        ax.set_ylabel('')
        ax.tick_params(axis='y', which='both', left=False, labelleft=False)

    # Tight spacing keeps the three facets visually connected while width_ratios gives the
    # one-engine and three-engine facets appropriate horizontal space.
    plt.tight_layout(w_pad=0.2)
    fig.subplots_adjust(wspace=0.05)
    fig.savefig(paper_image_dir / 'runtime-engines-by-method.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# %% [markdown]
# ### Factor runtime distributions by full comparison context
#
# This diagnostic plot restores the more detailed split by the other relevant factor values. It is intentionally verbose and should be read as a sanity check rather than as the main result: it shows whether an apparent factor effect is concentrated in a particular source/semantics/CNF/negation context. The x-axis labels omit the factor names to save space.

# %%
# Binary factor contrasts use the same visual rule in the diagnostic factor plots.
# Each factor definition stores its two comparable values in the order in which we want
# to read the contrast: the baseline/first value is blue and the alternative/second value
# is vermilion. This avoids maintaining a separate dictionary of individual value colors,
# which was easy to let drift out of sync across plots.
def _factor_value_color(spec, value):
    values = list(spec['values'])
    value_index = values.index(value)
    return [COLOR['blue'], COLOR['vermillion']][value_index % 2]


# Grouped diagnostic boxes: within each factor panel, each x-axis group is a display group
# such as task, engine, or comparison context. Within each group, we draw one box for
# each value of the factor under study.
def _draw_grouped_factor_boxes(ax, sub, spec, group_col, group_label):
    # This helper does not create pairs. It assumes sub already contains paired rows from
    # _factor_observations and only changes how those rows are grouped visually.
    groups = sorted(sub[group_col].dropna().unique())
    values = spec['values']
    if not groups:
        ax.set_visible(False)
        return

    # Each x-axis group occupies one integer position. The offsets place the two
    # factor-value boxes side by side around that group position. Pairing is not changed
    # here; this is purely a visual split of already-paired observations.
    group_width = 0.8
    box_width = group_width / len(values) * 0.85
    offsets = np.linspace(-group_width / 2 + box_width / 2, group_width / 2 - box_width / 2, len(values))

    # Positive completed runtimes define the lower bound of the logarithmic axis. Timeouts
    # are NaN and therefore intentionally ignored here.
    positive_values = sub['duration_s'].dropna()
    positive_values = positive_values[positive_values > 0]

    for vi, value in enumerate(values):
        for gi, group in enumerate(groups):
            # Full category for one factor value inside one display group. This series is
            # what the plot labels as n: completed runtimes plus timeout attempts.
            series = sub[(sub['factor_value'] == value) & (sub[group_col] == group)]['duration_s']
            if series.empty:
                continue

            # The boxplot itself can only use completed runtimes. Timed-out attempts remain
            # represented by the red timeout annotation above the timeout line.
            completed = series.dropna().values
            timeouts = int(series.isna().sum())
            total = len(series)
            timeout_rate = timeouts / total if total else 0
            pos = gi + 1 + offsets[vi]

            # Draw a box only if at least one run completed. The color is derived from
            # the value's position in spec['values'], not from the value name itself, so all
            # binary contrasts remain visually consistent: first value blue, second vermilion.
            # Categories with only timeouts still keep their red timeout label, but have no
            # completed-runtime distribution to draw.
            if len(completed) > 0:
                bp = ax.boxplot(
                    [completed], positions=[pos], widths=box_width,
                    patch_artist=True,
                    flierprops=dict(marker='o', markersize=2, alpha=0.35),
                    medianprops=dict(color=COLOR['black'], linewidth=1.2),
                )
                bp['boxes'][0].set_facecolor(_factor_value_color(spec, value))
                bp['boxes'][0].set_alpha(0.75)

            # Red labels encode timeout count and timeout rate for this category.
            ax.text(pos, TIMEOUT * 1.08, f"{timeouts}\n({_format_bold_percent(timeout_rate, 1)})",
                    ha='center', va='bottom', fontsize=6, color=_timeout_label_color(timeouts))

    # Draw the timeout threshold and use a log axis because completed runtimes span orders
    # of magnitude while the timeout line sits at 300 seconds.
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(bottom=max(positive_values.min() / 2, 1e-4) if not positive_values.empty else 1e-4,
                top=TIMEOUT * 1.6)

    # One x tick per display group, not per individual box. The colors/legend distinguish
    # the factor values within each group.
    ax.set_title(spec['label'], fontsize=10)
    ax.set_xticks(range(1, len(groups) + 1))
    ax.set_xticklabels(groups, rotation=25, ha='right', fontsize=8)
    ax.set_xlabel(group_label)
    ax.set_ylabel('Duration (s, log scale)')
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.4, which='both')


# Build one shared legend across all factor values that appear in any panel. Keep the
# corresponding spec with each value because color depends on the value's position inside
# that factor's ordered two-value contrast, not on a global value-to-color lookup table.
# This and the following diagnostic cells reuse these handles.
legend_entries = []
for spec in _FACTOR_DEFS:
    for value in spec['values']:
        if value not in [entry[1] for entry in legend_entries]:
            legend_entries.append((spec, value))
legend_handles = [
    plt.matplotlib.patches.Patch(facecolor=_factor_value_color(spec, value), alpha=0.75, label=value)
    for spec, value in legend_entries
]
legend_handles.append(plt.Line2D([0], [0], color=COLOR['timeout'], linestyle='--', label=f'timeout ({TIMEOUT}s)'))


# Full-context split: this is the most detailed diagnostic factor plot.
# The paired observations were already constructed above; this cell deliberately does not
# re-pair or filter anything. It only asks whether a factor contrast behaves differently
# under the other fixed comparison dimensions that made the pair comparable in the first
# place, such as source, semantics, CNF transformation, or negation.
fig, axes = plt.subplots(len(_FACTOR_DEFS), 1, figsize=(14, 3.8 * len(_FACTOR_DEFS)), sharey=True, squeeze=False)
fig.suptitle('Runtime by paired factor and full comparison context', fontsize=13)

for ax, spec in zip(axes[:, 0], _FACTOR_DEFS):
    # Select the already-paired rows for one factor. The context column was assembled
    # during paired-data preparation from spec['context_cols']; it contains exactly the
    # dimensions that are useful for reading this factor without changing the pairing key.
    sub = _factor_observations[_factor_observations['factor'] == spec['factor']].copy()

    # Drop the repeated "column=" prefixes to keep the x-axis readable. For example,
    # "source=KClause | diff_kind=false" becomes "KClause | false". This changes only
    # labels, not the grouping values or the underlying observations.
    sub['_context_without_names'] = sub['context_short'].str.replace(r'(^| \| )[^=|]+=', r'\1', regex=True)

    # Reuse the same grouped plotting helper as the task/engine plots. Colors still follow
    # the positional binary contrast rule: first factor value blue, second value vermilion.
    _draw_grouped_factor_boxes(ax, sub, spec, '_context_without_names', 'Comparison context')

# The handles were created once in the previous cell from the same factor definitions,
# so this plot keeps the exact same color legend instead of rebuilding another variant.
axes[0][0].legend(handles=legend_handles, fontsize=8, loc='upper right', bbox_to_anchor=(1.0, 1.0))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Aggregate runtime distribution
#
# Before reporting the paired statistical tests, this plot shows the overall runtime distribution of all runtime measurements that remain in scope for the main analysis. It deliberately removes generated commit/yearly histories and the distributive CNF encoding, matching the exclusions used for the later runtime analyses. Unlike the paired factor plots above, this is not a comparison plot: the first figure pools all remaining configurations into one box to show the global runtime scale and timeout frequency, and the second figure splits the same data by system.

# %%
# Aggregate runtime box plot for the analysis universe used before the statistical tests.
# This is intentionally not paired by factor value: every remaining measurement contributes
# once, so the plot summarizes the overall runtime scale after the global exclusions.
_runtime_all = df[
    (~df['system'].str.endswith('-commits')) &
    (~df['system'].str.endswith('-yearly')) &
    (df['cnf_transform'] != 'dist')
].copy()

# Completed runtimes define the boxplot. Timeout attempts are kept as NaN in duration_s,
# so they are counted separately and do not affect quartiles or whiskers.
_runtime_all_completed = _runtime_all['duration_s'].dropna()
_runtime_all_completed = _runtime_all_completed[_runtime_all_completed > 0]
_runtime_all_timeouts = int(_runtime_all['duration_s'].isna().sum())
_runtime_all_total = len(_runtime_all)
_runtime_all_timeout_rate = _runtime_all_timeouts / _runtime_all_total if _runtime_all_total else 0
_runtime_all_below_10s = int((_runtime_all['duration_s'] < 10).sum())
_runtime_all_below_10s_rate = _runtime_all_below_10s / _runtime_all_total if _runtime_all_total else 0
print(f'Computations below 10s: {_runtime_all_below_10s}/{_runtime_all_total} ({_runtime_all_below_10s_rate:.0%})')

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(2.0, 2.8))

    if len(_runtime_all_completed) > 0:
        bp = ax.boxplot(
            [_runtime_all_completed.values], positions=[1], widths=0.6,
            patch_artist=True,
            flierprops=dict(marker='o', markersize=2, alpha=0.35),
            medianprops=dict(color=COLOR['black'], linewidth=1.2),
        )
        bp['boxes'][0].set_facecolor(COLOR['gray'])
        bp['boxes'][0].set_alpha(0.75)

    # Keep the timeout reporting consistent with the other runtime plots: the red line marks
    # the 300s threshold and the red label gives count and rate among all pooled attempts.
    ax.text(1, TIMEOUT * 1.18, f"{_runtime_all_timeouts} ({_format_bold_percent(_runtime_all_timeout_rate)})",
            ha='center', va='bottom', fontsize=9, color=_timeout_label_color(_runtime_all_timeouts))

    ax.text(1, 0.03, f'n={_runtime_all_total}', transform=ax.get_xaxis_transform(),
            ha='center', va='bottom', fontsize=9, color=COLOR['gray'])
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(
        bottom=max(_runtime_all_completed.min() / 5, 1e-4) if len(_runtime_all_completed) else 1e-4,
        top=TIMEOUT * 9,
    )
    ax.set_xticks([1])
    ax.set_xticklabels(['all'], rotation=0, ha='center', fontsize=12)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

    plt.tight_layout()
    fig.savefig(paper_image_dir / 'runtime-all.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()


# System-wise version of the same aggregate distribution. This does not introduce another
# filter or pairing rule: it only facets the pooled analysis universe by system so we can see
# whether the global box above is dominated by one subject system.
_runtime_systems = sorted(_runtime_all['system'].unique())
_runtime_by_system = [_runtime_all.loc[_runtime_all['system'] == system, 'duration_s'] for system in _runtime_systems]
_runtime_completed_by_system = [series.dropna()[series.dropna() > 0] for series in _runtime_by_system]
_runtime_positive_system_values = pd.concat(_runtime_completed_by_system, ignore_index=True) if _runtime_completed_by_system else pd.Series(dtype=float)

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(max(5.4, 0.55 * len(_runtime_systems)), 2.8))

    # Draw boxes only for systems with at least one completed run; timeout-only systems still
    # remain visible through their timeout and n labels.
    for pos, (system, series, completed) in enumerate(zip(_runtime_systems, _runtime_by_system, _runtime_completed_by_system), start=1):
        timeouts = int(series.isna().sum())
        total = len(series)
        timeout_rate = timeouts / total if total else 0

        if len(completed) > 0:
            bp = ax.boxplot(
                [completed.values], positions=[pos], widths=0.55,
                patch_artist=True,
                flierprops=dict(marker='o', markersize=2, alpha=0.35),
                medianprops=dict(color=COLOR['black'], linewidth=1.2),
            )
            bp['boxes'][0].set_facecolor(COLOR['gray'])
            bp['boxes'][0].set_alpha(0.75)

        ax.text(pos, TIMEOUT * 1.18, f"{timeouts} ({_format_bold_percent(timeout_rate)})",
                ha='center', va='bottom', fontsize=8, color=_timeout_label_color(timeouts))
        ax.text(pos, 0.03, f'n={total}', transform=ax.get_xaxis_transform(),
                ha='center', va='bottom', fontsize=8, color=COLOR['gray'])

    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(
        bottom=max(_runtime_positive_system_values.min() / 5, 1e-4) if len(_runtime_positive_system_values) else 1e-4,
        top=TIMEOUT * 9,
    )
    ax.set_xticks(range(1, len(_runtime_systems) + 1))
    ax.set_xticklabels(_runtime_systems, rotation=30, ha='right', fontsize=9)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

    plt.tight_layout()
    fig.savefig(paper_image_dir / 'runtime-all-by-system.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()


# Collapse algorithm configurations to answer a different question: for each concrete
# difference instance, is there at least one non-kissat configuration that successfully
# counts it? Classification-only kissat rows are excluded entirely because they do not count
# solutions. The grouping key keeps only the subject system and compared model pair fixed,
# deliberately collapsing source/extractor, semantics, method, engine, and negation. If at
# least one counting configuration completes, the collapsed runtime is the fastest completed
# runtime; if all counting configurations time out, the collapsed row remains a timeout.
def _runtime_collapse_strip_source(formula):
    parts = str(formula).split('/')
    if parts[0].startswith('extract-kconfig-models-with-'):
        return '/'.join(parts[1:])
    return str(formula)

_runtime_counting = _runtime_all[_runtime_all['engine'] != 'kissat'].copy()
_runtime_counting['left_model'] = _runtime_counting['left_formula'].apply(_runtime_collapse_strip_source)
_runtime_counting['right_model'] = _runtime_counting['right_formula'].apply(_runtime_collapse_strip_source)

_runtime_collapse_key = ['system', 'left_model', 'right_model']
_runtime_collapsed_rows = []
for key_values, group in _runtime_counting.groupby(_runtime_collapse_key, dropna=False):
    completed = group['duration_s'].dropna()
    row = dict(zip(_runtime_collapse_key, key_values))
    row['duration_s'] = completed.min() if not completed.empty else np.nan
    row['attempts'] = len(group)
    _runtime_collapsed_rows.append(row)
_runtime_collapsed = pd.DataFrame(_runtime_collapsed_rows)

_runtime_collapsed_completed = _runtime_collapsed['duration_s'].dropna()
_runtime_collapsed_completed = _runtime_collapsed_completed[_runtime_collapsed_completed > 0]
_runtime_collapsed_timeouts = int(_runtime_collapsed['duration_s'].isna().sum())
_runtime_collapsed_total = len(_runtime_collapsed)
_runtime_collapsed_timeout_rate = _runtime_collapsed_timeouts / _runtime_collapsed_total if _runtime_collapsed_total else 0
print(
    f'Collapsed counting successes: '
    f'{_runtime_collapsed_total - _runtime_collapsed_timeouts}/{_runtime_collapsed_total} '
    f'({1 - _runtime_collapsed_timeout_rate:.0%})'
)

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(2.0, 2.8))

    if len(_runtime_collapsed_completed) > 0:
        bp = ax.boxplot(
            [_runtime_collapsed_completed.values], positions=[1], widths=0.6,
            patch_artist=True,
            flierprops=dict(marker='o', markersize=2, alpha=0.35),
            medianprops=dict(color=COLOR['black'], linewidth=1.2),
        )
        bp['boxes'][0].set_facecolor(COLOR['gray'])
        bp['boxes'][0].set_alpha(0.75)

    ax.text(1, TIMEOUT * 1.18, f"{_runtime_collapsed_timeouts} ({_format_bold_percent(_runtime_collapsed_timeout_rate)})",
            ha='center', va='bottom', fontsize=9, color=_timeout_label_color(_runtime_collapsed_timeouts))

    ax.text(1, 0.03, f'n={_runtime_collapsed_total}', transform=ax.get_xaxis_transform(),
            ha='center', va='bottom', fontsize=9, color=COLOR['gray'])
    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(
        bottom=max(_runtime_collapsed_completed.min() / 5, 1e-4) if len(_runtime_collapsed_completed) else 1e-4,
        top=TIMEOUT * 9,
    )
    ax.set_xticks([1])
    ax.set_xticklabels(['collapsed'], rotation=0, ha='center', fontsize=12)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

    plt.tight_layout()
    fig.savefig(paper_image_dir / 'runtime-collapsed-counting.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# System-wise view of the same collapsed data. A timeout here means no non-kissat counting
# configuration succeeded for that system/model-pair key across any source, semantics,
# method, engine, or negation setting.
_runtime_collapsed_systems = sorted(_runtime_collapsed['system'].unique())
_runtime_collapsed_by_system = [
    _runtime_collapsed.loc[_runtime_collapsed['system'] == system, 'duration_s']
    for system in _runtime_collapsed_systems
]
_runtime_collapsed_completed_by_system = [series.dropna()[series.dropna() > 0] for series in _runtime_collapsed_by_system]
_runtime_collapsed_positive_system_values = (
    pd.concat(_runtime_collapsed_completed_by_system, ignore_index=True)
    if _runtime_collapsed_completed_by_system else pd.Series(dtype=float)
)

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(max(5.4, 0.55 * len(_runtime_collapsed_systems)), 2.8))

    for pos, (system, series, completed) in enumerate(
        zip(_runtime_collapsed_systems, _runtime_collapsed_by_system, _runtime_collapsed_completed_by_system),
        start=1,
    ):
        timeouts = int(series.isna().sum())
        total = len(series)
        timeout_rate = timeouts / total if total else 0

        if len(completed) > 0:
            bp = ax.boxplot(
                [completed.values], positions=[pos], widths=0.55,
                patch_artist=True,
                flierprops=dict(marker='o', markersize=2, alpha=0.35),
                medianprops=dict(color=COLOR['black'], linewidth=1.2),
            )
            bp['boxes'][0].set_facecolor(COLOR['gray'])
            bp['boxes'][0].set_alpha(0.75)

        ax.text(pos, TIMEOUT * 1.18, f"{timeouts} ({_format_bold_percent(timeout_rate)})",
                ha='center', va='bottom', fontsize=8, color=_timeout_label_color(timeouts))
        ax.text(pos, 0.03, f'n={total}', transform=ax.get_xaxis_transform(),
                ha='center', va='bottom', fontsize=8, color=COLOR['gray'])

    ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.set_yscale('log')
    ax.set_ylim(
        bottom=max(_runtime_collapsed_positive_system_values.min() / 5, 1e-4) if len(_runtime_collapsed_positive_system_values) else 1e-4,
        top=TIMEOUT * 9,
    )
    ax.set_xticks(range(1, len(_runtime_collapsed_systems) + 1))
    ax.set_xticklabels(_runtime_collapsed_systems, rotation=30, ha='right', fontsize=9)
    ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=12)
    format_runtime_yaxis(ax)
    ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')

    plt.tight_layout()
    fig.savefig(paper_image_dir / 'runtime-collapsed-counting-by-system.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()
# Out:
# Computations below 10s: 7645/9607 (80%)
# Collapsed counting successes: 369/382 (97%)

# %% [markdown]
# ### Statistical tests
#
# The statistical tests use the same paired comparison units as the runtime diagrams. Each tested contrast compares two boxes that were explicitly constructed as counterparts of each other; unrelated task families are not tested against each other here.
#
# For every directly comparable box pair, the table reports two paired Wilcoxon signed-rank tests. The first test drops every pair in which at least one side timed out (`\no`). The second test keeps all pairs and replaces timed-out runtimes with the configured timeout bound of 300 seconds (`\yes`). We do not report unpaired tests for these contrasts because the paired benchmark construction gives the more appropriate test.
#
# The CNF transformation is tested once in aggregate and then in both visible directions of the CNF figure: `dist` vs. `tseitin` within each semantic split, and `Closed` vs. `Projection` within each CNF transformation. Context labels use the compact form `variable (split)`, for example `CNF (Closed)` or `Semantics (tseitin)`, so the first part names the varied factor and the parenthesized part names the split under which it is tested. The isolated factor figure tests source, semantics, and negation on the same Tseitin-only subset used in the plot. The engine figure tests engines only within a method facet; ordinary `#SAT` and projected `#∃SAT` remain separate because they are different tasks. The method comparisons are added separately: `classify` vs. `#SAT` is paired only for `negation=Yes`, and `#SAT` vs. `#∃SAT` is paired only for `Projection` with `negation=No`. For those method comparisons, engines are aggregated by taking the fastest completed engine for each method and benchmark key; if all engines time out, the aggregated method runtime remains a timeout.
#
# The p-value threshold follows the stricter convention used in the paper: a single star marks `p < .005`. Non-significant detailed rows are gray, but their context is kept black so the contrast remains findable. In non-significant rows, effect sizes are omitted because they should not be interpreted as evidence for a reliable direction.
#
# The Wilcoxon statistic itself is not shown in the table. Instead, significant rows report two paired effect-size summaries: the matched-pairs rank-biserial effect `RBC`, computed from signed ranks, and the median paired runtime `ratio`, computed as `factor A / factor B`. With this orientation, `RBC > 0` and `ratio < 1` both mean that factor A is faster; `RBC < 0` and `ratio > 1` both mean that factor B is faster. The faster factor is bolded and the slower factor is italicized only when both summaries agree on the direction. If a row is not significant at `p < .005`, the row is grayed and the effect sizes are omitted.
#
# Two LaTeX tables are emitted. The detailed table includes both timeout variants and the timeout marker column. The compact table keeps only the timeout-substitution rows (`\yes`), omits the timeout marker column, and drops the aggregate `CNF` row because the split-specific CNF rows are more informative in the compact presentation.

# %%
import itertools

try:
    from scipy import stats as _runtime_stats
except Exception:
    _runtime_stats = None

try:
    from IPython.display import display as _runtime_display
except Exception:
    def _runtime_display(table):
        print(table.to_string(index=False))

def _latex_label(value):
    # Labels used in the statistical table should follow the publication figures rather
    # than the raw CSV values. Keep this mapping local to the table so the analysis data
    # itself remains untouched.
    return {
        'KConfigReader': 'KCReader',
        'KClause': 'KClause',
        'false': 'Closed',
        'slice': 'Projection',
        'dist': 'dist',
        'tseitin': 'tseitin',
        False: 'No',
        True: 'Yes',
        'count': r'\#SAT',
        'projected-count': r'\#$\exists$SAT',
        'satisfy': 'classify',
        'd4': 'd4',
        'ganak': 'ganak',
        'd4-counting': 'd4',
        'd4-proj-ddnnf-compiler': 'pd4',
        'ganak-pmc': 'ganak',
    }.get(value, str(value))

def _wilcoxon_result(left, right):
    # Paired tests use Wilcoxon signed-rank because runtime measurements are skewed,
    # timeout-censored, and paired by construction. scipy returns W and the p-value, but W
    # is not very interpretable in the paper table, so we keep it only internally and report
    # two effect sizes instead:
    # - RBC: matched-pairs rank-biserial correlation from signed ranks;
    # - ratio: median paired runtime ratio factor A / factor B.
    # Positive RBC and ratio < 1 both mean factor A is faster; negative RBC and ratio > 1
    # both mean factor B is faster.
    if _runtime_stats is None or len(left) == 0 or len(right) == 0 or len(left) != len(right):
        return np.nan, np.nan, np.nan, np.nan
    left = np.asarray(left, dtype=float)
    right = np.asarray(right, dtype=float)
    diff = right - left
    nonzero = diff != 0
    nonzero_diff = diff[nonzero]
    if len(nonzero_diff) == 0:
        return 1.0, 0.0, 0.0, 1.0

    # Rank absolute non-zero differences, then compare the sum of positive and negative
    # signed ranks. scipy's rankdata handles ties by assigning average ranks, matching the
    # signed-rank test convention closely enough for this descriptive effect size.
    ranks = _runtime_stats.rankdata(np.abs(nonzero_diff), method='average')
    positive_rank_sum = ranks[nonzero_diff > 0].sum()
    negative_rank_sum = ranks[nonzero_diff < 0].sum()
    total_rank_sum = ranks.sum()
    rank_biserial = (positive_rank_sum - negative_rank_sum) / total_rank_sum

    valid_ratio = (left > 0) & (right > 0)
    paired_ratio = np.nanmedian(left[valid_ratio] / right[valid_ratio]) if valid_ratio.any() else np.nan

    try:
        result = _runtime_stats.wilcoxon(left, right, alternative='two-sided')
        return result.pvalue, result.statistic, rank_biserial, paired_ratio
    except ValueError:
        return np.nan, np.nan, rank_biserial, paired_ratio

def _append_test_row(rows, test_type, timeouts, context, factor_a, factor_b, p_value, statistic, rank_biserial, paired_ratio):
    # Store numerical values first. Formatting happens only after all rows exist. This keeps
    # the statistical computation separate from LaTeX concerns such as gray rows, bold/italic
    # factor names, significance stars, and S-column formatting.
    rows.append({
        'type': test_type,
        'timeouts': timeouts,
        'context': context,
        'factor A': factor_a,
        'factor B': factor_b,
        'p-value': p_value,
        'statistic': statistic,
        'r_rb': rank_biserial,
        'ratio': paired_ratio,
    })

def _add_paired_box_tests(rows, sub, value_col, left_value, right_value, pair_cols, context):
    # Add the paired tests used for any directly comparable pair of boxes. The no-timeout
    # row answers: among pairs where both sides finished, is one side systematically faster?
    # The timeout-substitution row answers: if every timeout is treated as the 300s timeout
    # bound, does the paired conclusion change? We intentionally do not add unpaired rows
    # because all contrasts in this table are pairable.
    values = [left_value, right_value]
    duration_wide = (
        sub[sub[value_col].isin(values)]
        .pivot_table(index=pair_cols, columns=value_col, values='duration_s', aggfunc='first')
        .reindex(columns=values)
    )

    complete_pairs = duration_wide.dropna(subset=values)
    completed_left = _factor_column(complete_pairs, left_value).values
    completed_right = _factor_column(complete_pairs, right_value).values
    p_value, statistic, rank_biserial, paired_ratio = _wilcoxon_result(completed_left, completed_right)
    _append_test_row(
        rows, 'paired w/o timeouts', r'\no', context,
        _latex_label(left_value), _latex_label(right_value), p_value, statistic, rank_biserial, paired_ratio,
    )

    filled_left = _factor_column(duration_wide, left_value).fillna(TIMEOUT).values
    filled_right = _factor_column(duration_wide, right_value).fillna(TIMEOUT).values
    p_value, statistic, rank_biserial, paired_ratio = _wilcoxon_result(filled_left, filled_right)
    _append_test_row(
        rows, 'paired w/ timeouts', r'\yes', context,
        _latex_label(left_value), _latex_label(right_value), p_value, statistic, rank_biserial, paired_ratio,
    )

def _fastest_method_observations(sub, pair_cols):
    # Method-level comparisons should not be confounded by a particular solver choice.
    # For each method and benchmark/configuration key, collapse all available engines to
    # one representative attempt: the fastest completed runtime. If every engine timed out,
    # keep the method present with duration_s = NaN so the timeout-substitution test still
    # treats it as a timeout rather than silently dropping the attempt.
    rows = []
    for key_values, group in sub.groupby(pair_cols + ['method'], dropna=False):
        if not isinstance(key_values, tuple):
            key_values = (key_values,)
        row = dict(zip(pair_cols + ['method'], key_values))
        completed = group['duration_s'].dropna()
        row['duration_s'] = completed.min() if not completed.empty else np.nan
        rows.append(row)
    return pd.DataFrame(rows)

def _formatted_p_value(p_value):
    # P-values span many orders of magnitude. We round each p-value to its nearest
    # power of ten and omit the leading 1\times, because the mantissa would add visual
    # noise without adding meaningful precision in this table.
    if pd.isna(p_value) or p_value <= 0:
        return ''
    exponent = int(np.round(np.log10(p_value)))
    return rf'$10^{{{exponent}}}$'

def _significance_star(p_value):
    # Exactly one star for p < .005. The table deliberately avoids the usual */**/*** scale
    # so the star is a binary marker for the paper's chosen alpha threshold.
    if pd.isna(p_value):
        return ''
    return '*' if p_value < 0.005 else ''

def _formatted_effect(value):
    # Keep two decimals and place effect sizes in math mode. This gives a proper math
    # minus sign without relying on numeric column parsing.
    if pd.isna(value):
        return ''
    return rf'${value:.2f}$'

def _latex_gray(value):
    # Gray nonsignificant rows by wrapping the already formatted cell content. The context
    # column is intentionally not grayed so a reader can still locate the contrast quickly.
    if value == '':
        return ''
    return rf'{{\color{{gray}} {value}}}'

def _format_statistical_table(table):
    # Formatting rules for the publication table:
    # - The context column is shared by the timeout variants, so only the first row of
    #   each consecutive group shows it. Factor labels are repeated in all rows so their
    #   bold formatting remains visible next to each p-value.
    # - The timeout column is the fourth column and contains only \no/\yes.
    # - P-values and effect sizes are emitted as plain math text in ordinary right-aligned
    #   numerical values align.
    # - Each row highlights the faster factor in bold and the inferior factor in italics.
    #   RBC > 0 and ratio < 1 both point to factor A; RBC < 0 and ratio > 1 both point
    #   to factor B. If the effect-size summaries disagree or are zero/unknown, neither
    #   factor is highlighted.
    # - Non-significant rows (p >= .005) are printed in gray except for the context column;
    #   their effect sizes are omitted. Significant p-values get one star.
    formatted_rows = []
    for _, group in table.groupby(['context', 'factor A', 'factor B'], sort=False):
        group = group.copy()

        for row_index, (_, row) in enumerate(group.iterrows()):
            factor_a = row['factor A']
            factor_b = row['factor B']
            rb_direction = np.sign(row['r_rb']) if not pd.isna(row['r_rb']) else 0
            ratio_direction = -np.sign(row['ratio'] - 1) if not pd.isna(row['ratio']) else 0
            if rb_direction > 0 and ratio_direction > 0:
                factor_a = rf'\textbf{{{factor_a}}}'
                factor_b = rf'\emph{{{factor_b}}}'
            elif rb_direction < 0 and ratio_direction < 0:
                factor_a = rf'\emph{{{factor_a}}}'
                factor_b = rf'\textbf{{{factor_b}}}'

            output_row = {
                'context': row['context'] if row_index == 0 else '',
                'factor A': factor_a,
                'factor B': factor_b,
                'timeouts': row['timeouts'],
                'p-value': _formatted_p_value(row['p-value']),
                'sig.': _significance_star(row['p-value']),
                'RBC': _formatted_effect(row['r_rb']),
                'ratio': _formatted_effect(row['ratio']),
            }
            if pd.isna(row['p-value']) or row['p-value'] >= 0.005:
                output_row = {
                    key: (
                        value if key == 'context'
                        else '' if key in ['RBC', 'ratio']
                        else _latex_gray(value) if key == 'p-value'
                        else _latex_gray(value)
                    )
                    for key, value in output_row.items()
                }
            formatted_rows.append(output_row)
    return pd.DataFrame(formatted_rows)

_runtime_test_rows = []

# CNF figure: the first runtime diagram has four boxes, arranged as two CNF
# transformations split by semantics. Test both directions visible in that rectangle:
# dist vs. Tseitin within each semantic split, and Closed vs. Projection inside
# each CNF transformation.
_cnf_tests = _factor_observations[_factor_observations['factor'] == 'cnf'].copy()

# Aggregate CNF comparison: compare dist vs. tseitin across both semantic settings before
# showing the split-specific tests. The same _pair_id still aligns each dist row with its
# matching tseitin row, because pairing was constructed separately for each semantic setting.
_add_paired_box_tests(
    _runtime_test_rows,
    _cnf_tests,
    'factor_value',
    'dist',
    'tseitin',
    ['_pair_id'],
    'CNF',
)

# Horizontal comparisons in the CNF figure: compare dist vs. Tseitin separately for
# Closed and Projection. These reuse _pair_id because _pair_id was created exactly
# to pair the two CNF transformation values for a fixed semantic setting.
for diff_kind in sorted(_cnf_tests['diff_kind'].dropna().unique()):
    split_sub = _cnf_tests[_cnf_tests['diff_kind'] == diff_kind]
    _add_paired_box_tests(
        _runtime_test_rows,
        split_sub,
        'factor_value',
        'dist',
        'tseitin',
        ['_pair_id'],
        f'CNF ({_latex_label(diff_kind)})',
    )

# Vertical comparisons in the CNF figure: compare the semantic split inside each CNF
# transformation. Here _pair_id is not appropriate because it pairs CNF values, not
# semantic values. Instead, pair by the underlying benchmark/configuration while keeping
# the CNF transformation fixed through factor_value.
for cnf_transform in ['dist', 'tseitin']:
    cnf_sub = _cnf_tests[_cnf_tests['factor_value'] == cnf_transform]
    _add_paired_box_tests(
        _runtime_test_rows,
        cnf_sub,
        'diff_kind',
        'false',
        'slice',
        ['system', 'source', 'left_model', 'right_model', 'engine', 'negate', 'factor_value'],
        f'Semantics ({_latex_label(cnf_transform)})',
    )

# Isolated factor figure: source, semantics, and negation are tested exactly on the
# Tseitin-only observations used in that figure. Define the subset here as well, rather
# than relying on variables from the plotting cell, so the statistical cell documents its
# own assumptions. Negation follows the displayed axis order (Yes before No), while the
# other factors keep their specification order.
_stat_isolated_factor_defs = [spec for spec in _FACTOR_DEFS if spec['factor'] != 'cnf']
_stat_isolated_factor_observations = _factor_observations[
    (_factor_observations['factor'] != 'cnf') &
    (_factor_observations['cnf_transform'] != 'dist')
].copy()
for spec in _stat_isolated_factor_defs:
    sub = _stat_isolated_factor_observations[_stat_isolated_factor_observations['factor'] == spec['factor']]
    values = list(spec['values'])
    if spec['factor'] == 'negation':
        values = list(reversed(values))
    _add_paired_box_tests(
        _runtime_test_rows,
        sub,
        'factor_value',
        values[0],
        values[1],
        ['_pair_id'],
        spec['label'],
    )

# Engine figure: engines are comparable only within one method facet. The classify facet has
# a single engine and therefore contributes no engine-vs-engine test. The #SAT facet gives
# one pair, and the projected-model-counting facet gives the three pairwise engine tests.
for method in _ENGINE_METHOD_ORDER:
    method_sub, engines = _paired_engine_observations(method)
    for left_engine, right_engine in itertools.combinations(engines, 2):
        pair_sub = method_sub[method_sub['engine'].isin([left_engine, right_engine])]
        _add_paired_box_tests(
            _runtime_test_rows,
            pair_sub,
            'engine',
            left_engine,
            right_engine,
            _ENGINE_PAIR_COLS,
            f'Engine ({_latex_label(method)})',
        )

# Method comparisons aggregate over engines by taking the fastest available engine per
# method and benchmark/configuration key. These are not arbitrary cross-task comparisons:
# classify vs. #SAT is only meaningful for negation=Yes, where both tasks ask about the
# same complemented difference, while #SAT vs. #∃SAT is only meaningful for Projection with
# negation=No. Distributive runs are excluded, matching the runtime-factor plots.
_METHOD_PAIR_COLS = ['system', 'source', 'left_model', 'right_model', 'diff_kind', 'cnf_transform', 'negate']

_classify_count_base = _factor_base[
    (_factor_base['cnf_transform'] != 'dist') &
    (_factor_base['negate'] == True) &
    (_factor_base['method'].isin(['satisfy', 'count']))
].copy()
_classify_count_fastest = _fastest_method_observations(_classify_count_base, _METHOD_PAIR_COLS)
_add_paired_box_tests(
    _runtime_test_rows,
    _classify_count_fastest,
    'method',
    'satisfy',
    'count',
    _METHOD_PAIR_COLS,
    'Method (negation=Yes)',
)

_count_projected_base = _factor_base[
    (_factor_base['cnf_transform'] != 'dist') &
    (_factor_base['negate'] == False) &
    (_factor_base['diff_kind'] == 'slice') &
    (_factor_base['method'].isin(['count', 'projected-count']))
].copy()
_count_projected_fastest = _fastest_method_observations(_count_projected_base, _METHOD_PAIR_COLS)
_add_paired_box_tests(
    _runtime_test_rows,
    _count_projected_fastest,
    'method',
    'count',
    'projected-count',
    _METHOD_PAIR_COLS,
    'Method (Projection)',
)

_runtime_test_table = pd.DataFrame(_runtime_test_rows)
_runtime_latex_table = _format_statistical_table(_runtime_test_table)

_runtime_display(_runtime_latex_table)

# The p-value and effect-size columns are ordinary right-aligned columns. They contain
# math-mode strings rather than raw numbers, because the table also includes styled cells
# dataframe header readable and rename only the LaTeX export copy.
_runtime_latex_export = _runtime_latex_table.rename(columns={
    'p-value': r'{p-value}',
    'RBC': '{RBC}',
    'ratio': r'{ratio}',
})
print(_runtime_latex_export.to_latex(
    index=False, escape=False,
    column_format=r'lllcrcrr',
))

# Compact table for the paper text: keep only timeout-substitution rows, preserve the
# context labels, omit the timeout indicator column, and drop the aggregate CNF row because
# the split-specific CNF rows are more informative here. Build this from the raw numerical
# table, not from the already display-formatted detailed table, so contexts are not blanked.
_runtime_test_table_compact = _runtime_test_table[
    (_runtime_test_table['timeouts'] == r'\yes') &
    (_runtime_test_table['context'] != 'CNF')
].copy()
_runtime_latex_table_compact = _format_statistical_table(_runtime_test_table_compact)
_runtime_latex_table_compact = _runtime_latex_table_compact.drop(columns=['timeouts', 'sig.'])
_runtime_latex_export_compact = _runtime_latex_table_compact.rename(columns={
    'p-value': r'{p-value}',
    'RBC': '{RBC}',
    'ratio': r'{ratio}',
})
_runtime_display(_runtime_latex_table_compact)
print(_runtime_latex_export_compact.to_latex(
    index=False, escape=False,
    column_format=r'llllrr',
))
# Out:
#                     context                      factor A  \
# 0                       CNF                 \textbf{dist}
# 1                                                    dist
# 2              CNF (Closed)  {\color{gray} \textbf{dist}}
# 3                                             \emph{dist}
# 4          CNF (Projection)                 \textbf{dist}
# 5                                           \textbf{dist}
# 6          Semantics (dist)               \textbf{Closed}
# 7                                                  Closed
# 8       Semantics (tseitin)               \textbf{Closed}
# 9                                         \textbf{Closed}
# 10                   Source               \emph{KCReader}
# 11                                        \emph{KCReader}
# 12                Semantics               \textbf{Closed}
# 13                                        \textbf{Closed}
# 14                 Negation                  \textbf{Yes}
# ...

# %% [markdown]
# ## Diffing time over time
#
# This figure shows how the runtime of feature-model differencing evolves over release time. The goal is not to compare every experimental configuration again, but to show whether the best visible runtime behavior changes as systems grow and age. Each facet corresponds to one reasoning task: `SAT`, `#SAT`, and `#∃SAT`. The `SAT` facet uses `kissat`; the `#SAT` and `#∃SAT` facets use the virtual-best runtime across their available solver engines.
#
# Several filters keep the figure compact and avoid duplicating the same feature-model difference many times. Generated `*-commits` and `*-yearly` histories are omitted so dense generated histories do not dominate the temporal view. Distributive CNF runs are omitted, matching the rest of the runtime analysis. Closed-world runs are omitted as well; every point uses Projection semantics. KConfigReader points are omitted to reduce overplotting, leaving KClause and XML inputs.
#
# Negation is treated as a runtime strategy, not as a displayed factor. For a fixed facet, system, extractor, formula pair, and release date, the two negation variants are collapsed to the fastest completed runtime. If both variants time out, the collapsed point remains a timeout. This prevents the same feature-model difference from being drawn twice while still preserving timeout information for the “last countable diff” marker.
#
# Colors identify systems, marker shapes identify the remaining input sources (`KClause` and XML), and an `x` marks the last completed point of a series if later revisions time out. The trend summaries and slope diagnostic are deliberately computed on the fuller runtime dataset: generated histories and distributive CNF runs are still excluded, but both semantics, all extractors, and both negation settings remain. Thus, the compact scatter plot is filtered for readability, while the trend/significance analysis still reflects all relevant non-distributive runtime measurements.

# %%
import re as _re
import matplotlib.dates as _mdates
from scipy import stats as _scipy_stats

def _extract_revision(formula):
    filename = formula.split('/')[-1]
    m = _re.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', filename)
    return m.group(1) if m else None

def _extract_extractor(formula):
    p = formula.split('/')[0]
    if p.startswith('extract-kconfig-models-with-'):
        return p.replace('extract-kconfig-models-with-', '')
    return 'xml'

def _extract_xml_date(formula):
    # Extract YYYY-MM-DD from XML filenames like Nieke2018-2017-05-22.xml
    filename = formula.split('/')[-1]
    m = _re.search(r'(\d{4}-\d{2}-\d{2})\.xml$', filename)
    return m.group(1) if m else None

# Start from the median-iteration runtime table used in the runtime analysis.
# Exclude generated histories, distributive CNF runs, and satisfy-simplified, because this
# figure focuses on the Tseitin/runtime-engine configurations shown in the engine plot.
_base = df[(df['method'] != 'satisfy-simplified') &
           (~df['system'].str.endswith('-commits')) &
           (~df['system'].str.endswith('-yearly')) &
           (df['cnf_transform'] != 'dist')].copy()
# duration_s is already prepared above from total_duration_shell and keeps timeouts as NaN.
# Generated commits/yearly histories are excluded above, so system names can be used directly.
_base['extractor']        = _base['left_formula'].apply(_extract_extractor)
_base['_right_rev'] = _base['right_formula'].apply(_extract_revision)
_base['_xml_date']  = _base['right_formula'].apply(_extract_xml_date)

# Keep one facet per reasoning task. The #SAT and #∃SAT facets use a virtual-best
# runtime over their available engines, so every plotted point is the fastest completed
# engine for the same model pair and configuration. If all engines time out, the point
# remains a timeout.
_FACET_ORDER = ['SAT', '#SAT', '#∃SAT']
_FACET_LABELS = {
    'SAT': 'classify',
    '#SAT': r'quantify$_\kappa$ (#SAT)',
    '#∃SAT': r'quantify$_\kappa$ (#$\exists$SAT)',
}
_FACET_METHODS = {
    'satisfy': 'SAT',
    'count': '#SAT',
    'projected-count': '#∃SAT',
}
_FACET_ENGINES = {
    'SAT': ['kissat'],
    '#SAT': ['d4', 'ganak'],
    '#∃SAT': ['d4-counting', 'd4-proj-ddnnf-compiler', 'ganak-pmc'],
}
_base['facet'] = _base['method'].map(_FACET_METHODS)
_base = _base[
    _base.apply(
        lambda row: pd.notna(row['facet']) and row['engine'] in _FACET_ENGINES[row['facet']],
        axis=1,
    )
].copy()

# Attach release dates. KConfig-derived models use Git revision dates from read_statistics;
# XML benchmark models do not have Git revisions, so their date is parsed from the filename.
_stats_lookup = _stats_by_exp['main'][['system', 'revision', 'committer_date_readable']].drop_duplicates(['system', 'revision'])
df_plot = _base.merge(
    _stats_lookup,
    left_on=['system', '_right_rev'],
    right_on=['system', 'revision'],
    how='left',
).drop(columns=['revision'])

# Fill missing Git dates for XML systems with the date encoded in the XML filename.
xml_mask = df_plot['committer_date_readable'].isna() & df_plot['_xml_date'].notna()
df_plot.loc[xml_mask, 'committer_date_readable'] = df_plot.loc[xml_mask, '_xml_date']

df_plot['right_time'] = pd.to_datetime(df_plot['committer_date_readable'], errors='coerce')
df_plot = df_plot[df_plot['right_time'].notna()]

# Collapse engines inside each reasoning task to a virtual-best runtime. This leaves SAT
# unchanged because kissat is the only configured SAT engine here, while #SAT uses the best
# of d4/ganak and #∃SAT uses the best of d4/pd4/ganak.
def _virtual_best_runtime_rows(data, key_cols):
    rows = []
    for key_values, group in data.groupby(key_cols, dropna=False):
        if not isinstance(key_values, tuple):
            key_values = (key_values,)
        row = dict(zip(key_cols, key_values))
        completed = group[group['duration_s'].notna()]
        if completed.empty:
            row['duration_s'] = np.nan
            row['best_engine'] = None
        else:
            best = completed.sort_values('duration_s').iloc[0]
            row['duration_s'] = best['duration_s']
            row['best_engine'] = best['engine']
        rows.append(row)
    return pd.DataFrame(rows)

_engine_collapse_key = [
    'facet', 'system', 'extractor', 'diff_kind', 'negate',
    'left_formula', 'right_formula', 'right_time',
]
df_plot = _virtual_best_runtime_rows(df_plot, _engine_collapse_key)

# Trend/significance analysis uses the full non-distributive, non-generated dataset. In
# particular, it does not inherit the compact plotting filters below: it keeps both
# semantics, all extractors, and both negation settings. This keeps the printed trend
# summaries and the slope diagnostic statistically aligned with the whole available runtime
# dataset while the scatter plot stays readable.
df_trend = df_plot.copy()
_trend_facets = [facet for facet in _FACET_ORDER if facet in set(df_trend['facet'])]
_all_trends = []
for facet in _trend_facets:
    facet_trend = df_trend[df_trend['facet'] == facet]
    for (system, extractor, negate, diff_kind), group in facet_trend.groupby(
        ['system', 'extractor', 'negate', 'diff_kind'], dropna=False
    ):
        done = group[group['duration_s'].notna()]
        if len(done) < 3:
            continue
        x_num = _mdates.date2num(done['right_time'].values)
        y_log = np.log10(done['duration_s'].values)
        valid = np.isfinite(y_log)
        if valid.sum() < 3:
            continue
        slope, _, r, p_val, _ = _scipy_stats.linregress(x_num[valid], y_log[valid])
        _all_trends.append({
            'facet': facet,
            'system': system,
            'extractor': extractor,
            'negate': negate,
            'semantics': diff_kind,
            'slope': slope,
            'r': r,
            'p': p_val,
            'significant': p_val < 0.005,
        })
_all_trends_df = pd.DataFrame(_all_trends)

# Print significant-trend diagnostics grouped by system, rather than by backend facet. The
# regressions above are still computed per backend/source/negation/semantics series; this
# block only changes how those existing trend records are summarized in the notebook output.
if not _all_trends_df.empty:
    _system_trend_summary = []
    for system, g in _all_trends_df.groupby('system'):
        n_trends = len(g)
        n_significant = g['significant'].sum()
        sig_g = g[g['significant']]
        sig_slope_per_year = sig_g['slope'] * 365.25
        _system_trend_summary.append({
            'system': system,
            'trends': n_trends,
            'significant': n_significant,
            'significant_share': n_significant / n_trends,
            'r_median': sig_g['r'].median(),
            'r_min': sig_g['r'].min(),
            'r_max': sig_g['r'].max(),
            'slope_per_year_median': sig_slope_per_year.median(),
            'slope_per_year_min': sig_slope_per_year.min(),
            'slope_per_year_max': sig_slope_per_year.max(),
        })

    _system_trend_summary = pd.DataFrame(_system_trend_summary)
    for sort_label, sort_column in [
        ('by significant/trends', 'significant_share'),
        ('by significant slope/year median', 'slope_per_year_median'),
    ]:
        print(f"\nSystem significant-trend statistics ordered {sort_label}:")
        for row in _system_trend_summary.sort_values(sort_column, ascending=False).itertuples(index=False):
            line = (f"[{row.system}] significant/trends={row.significant}/{row.trends} "
                    f"({100 * row.significant_share:.1f}%)")
            if row.significant > 0:
                line += (f", significant r median={row.r_median:.3f} "
                         f"[{row.r_min:.3f}, {row.r_max:.3f}], "
                         f"significant slope/year median={row.slope_per_year_median:.3f} "
                         f"[{row.slope_per_year_min:.3f}, {row.slope_per_year_max:.3f}]")
            print(line)

# Keep only Projection semantics in this temporal overview. Closed-world runs are omitted
# here so every facet shows one semantics rather than overlapping duplicate model pairs.
df_plot = df_plot[df_plot['diff_kind'] == 'slice'].copy()

# Keep KClause and XML inputs only; KConfigReader is omitted from this compact runtime
# evolution figure to reduce overplotting.
df_plot = df_plot[df_plot['extractor'] != 'kconfigreader'].copy()

# The same feature-model difference can appear twice for algorithms that support both
# negation settings. For this temporal overview, negation is a runtime strategy rather than
# a displayed factor, so collapse both variants to the fastest completed runtime. If both
# variants time out, keep one timeout row to preserve the last-countable-diff marker.
_negation_collapse_key = [
    'facet', 'system', 'extractor',
    'left_formula', 'right_formula', 'right_time',
]
_collapsed_rows = []
for key_values, group in df_plot.groupby(_negation_collapse_key, dropna=False):
    if not isinstance(key_values, tuple):
        key_values = (key_values,)
    row = dict(zip(_negation_collapse_key, key_values))
    completed = group[group['duration_s'].notna()]
    if completed.empty:
        row['duration_s'] = np.nan
        row['best_negate'] = None
    else:
        best = completed.sort_values('duration_s').iloc[0]
        row['duration_s'] = best['duration_s']
        row['best_negate'] = best['negate']
    _collapsed_rows.append(row)
df_plot = pd.DataFrame(_collapsed_rows)

# Plot encoding: facets are reasoning tasks; colors are systems; marker shapes are the
# remaining input sources. KConfigReader has been filtered out above, so only KClause and
# XML need markers.
facets     = [facet for facet in _FACET_ORDER if facet in set(df_plot['facet'])]
_systems    = sorted(df_plot['system'].unique())
_base_colors = dict(zip(_systems, color_cycle(len(_systems))))
sys_colors  = {s: _base_colors[s] for s in _systems}
marker_map = {'kclause': 'o', 'xml': 'D'}

n_cols = len(facets)
n_rows = 1

# A single compact row makes the three task facets comparable while keeping the saved PDF
# small enough for the paper column layout. Axes are shared so only the leftmost facet needs
# y-axis labels.
with plt.rc_context({'font.family': 'Helvetica', 'font.size': 13}):
    fig, axes = plt.subplots(
        n_rows, n_cols, figsize=(5.4, 2.87), sharex=True, sharey=True, squeeze=False,
    )

    for fi, facet in enumerate(facets):
        ax = axes[fi // n_cols][fi % n_cols]
        fsub = df_plot[df_plot['facet'] == facet]

        _trend_records = (
            _all_trends_df[_all_trends_df['facet'] == facet].to_dict('records')
            if not _all_trends_df.empty else []
        )

        for system in _systems:
            for extractor, marker in marker_map.items():
                s = fsub[(fsub['system'] == system) & (fsub['extractor'] == extractor)]
                completed = s[s['duration_s'].notna()]
                timed_out = s[s['duration_s'].isna()]
                if completed.empty:
                    continue
                color = sys_colors[system]

                ax.scatter(completed['right_time'], completed['duration_s'],
                           color=color, marker=marker, s=8, alpha=0.35, linewidths=0)

                # Mark the last completed revision if later revisions in this same
                # facet/system/source series time out. This gives a compact visual cue for where
                # a series stops being countable.
                if not timed_out.empty:
                    last_t = completed['right_time'].max()
                    if (timed_out['right_time'] > last_t).any():
                        last_pts = completed[completed['right_time'] == last_t]
                        ax.scatter(last_pts['right_time'], last_pts['duration_s'],
                                   color=color, marker='x', s=34, linewidths=1.15, zorder=5)

                # Trend statistics are computed above from df_trend, not from this compact
                # plotted subset. Keeping plotting and trend data separate avoids accidentally
                # limiting significance analysis to Projection/KClause/best-negation rows.

        # Use the same log-scale runtime axis style as the other runtime plots.
        ax.axhline(TIMEOUT, color=COLOR['timeout'], linestyle='--', linewidth=0.6, alpha=0.7)
        ax.set_yscale('log')
        format_runtime_yaxis(ax)
        ax.set_title(_FACET_LABELS.get(facet, facet), fontsize=13)
        ax.set_xlabel('')
        if fi == 0:
            ax.set_ylabel('Runtime ($\log_{10}$ s)', fontsize=13)
        else:
            ax.set_ylabel('')
            ax.tick_params(axis='y', which='both', left=False, labelleft=False)
        ax.grid(axis='y', linestyle='--', alpha=0.35, which='major')
        ax.set_xticks(pd.to_datetime(['2005-01-01', '2015-01-01', '2025-01-01']))
        ax.set_xticklabels(['2005', '2015', "'25"])
        ax.tick_params(axis='x', rotation=0, labelsize=13)
        ax.tick_params(axis='y', labelsize=13)

        _trends_df = pd.DataFrame(_trend_records)
        if not _trends_df.empty:
            n_sig = _trends_df['significant'].sum()
            print(f"[{facet}] {len(_trends_df)} trends, "
                  f"{n_sig} significant (p<0.005), "
                  f"r median={_trends_df['r'].median():.3f} "
                  f"[{_trends_df['r'].min():.3f}, {_trends_df['r'].max():.3f}]")

    for fi in range(len(facets), n_rows * n_cols):
        axes[fi // n_cols][fi % n_cols].set_visible(False)

    plt.tight_layout(w_pad=0.2)
    fig.subplots_adjust(wspace=0.05)
    fig.savefig(paper_image_dir / 'runtime-evolution.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# ── Slope boxplot (significant trends only) ───────────────────────────────────
# This diagnostic summarizes significant temporal trends from df_trend, i.e., from the
# full non-distributive, non-generated dataset. It intentionally does not reuse df_plot,
# because df_plot is filtered only for visual compactness.
if not _all_trends_df.empty:
    n_tot = len(_all_trends_df)
    n_sig = _all_trends_df['significant'].sum()
    print(f"\nOverall: {n_tot} trends computed, {n_sig} significant (p<0.005, "
          f"{100*n_sig/n_tot:.1f}%)")
    # Only significant trends in the boxplot
    _sig_df = _all_trends_df[_all_trends_df['significant']]
    # slope is in log10(s)/day — convert to log10(s)/year for readability
    _sig_df = _sig_df.copy()
    _sig_df['slope_per_year'] = _sig_df['slope'] * 365.25

    all_sig_slopes = _sig_df['slope_per_year'].dropna().values
    if len(all_sig_slopes) > 0:
        q1, median, q3 = np.percentile(all_sig_slopes, [25, 50, 75])
        n_pos = (all_sig_slopes > 0).sum()
        n_neg = (all_sig_slopes < 0).sum()
        n_zero = (all_sig_slopes == 0).sum()
        print(
            f"Significant slopes (all facets): n={len(all_sig_slopes)}, "
            f"positive={n_pos}, negative={n_neg}, zero={n_zero}, "
            f"median={median:.3f}, IQR=[{q1:.3f}, {q3:.3f}], "
            f"range=[{all_sig_slopes.min():.3f}, {all_sig_slopes.max():.3f}]"
        )

    fig2, ax2 = plt.subplots(figsize=(max(6, (len(facets) + 1) * 1.4), 4))
    slope_labels = ['all'] + [_FACET_LABELS.get(f, f) for f in facets]
    positions = np.arange(1, len(slope_labels) + 1)
    sig_vals  = [all_sig_slopes] + [
        _sig_df.loc[_sig_df['facet'] == f, 'slope_per_year'].values
        for f in facets
    ]

    bp = ax2.boxplot(sig_vals, positions=positions, widths=0.4, patch_artist=True,
                     medianprops=dict(color=COLOR['black'], linewidth=1.5),
                     boxprops=dict(facecolor=COLOR['sky_blue'], alpha=0.7),
                     flierprops=dict(marker='.', markersize=3, alpha=0.5))

    ax2.axhline(0, color=COLOR['light_gray'], linewidth=0.8)
    ax2.set_xticks(positions)
    ax2.set_xticklabels(slope_labels, rotation=20, ha='right', fontsize=11)
    ax2.set_ylabel("Slope (log₁₀ duration / year)", fontsize=7)
    ax2.set_title("Slope of significant trends (p<0.005) per facet", fontsize=8)
    ax2.grid(axis='y', linestyle='--', alpha=0.4)
    plt.tight_layout()
    plt.show()

    # The same significant-trend slopes, grouped by subject system instead of backend.
    system_labels = sorted(_sig_df['system'].dropna().unique())
    system_sig_vals = [
        _sig_df.loc[_sig_df['system'] == system, 'slope_per_year'].values
        for system in system_labels
    ]
    system_sig_pairs = [
        (system, vals) for system, vals in zip(system_labels, system_sig_vals)
        if len(vals) > 0
    ]

    if system_sig_pairs:
        system_labels, system_sig_vals = zip(*system_sig_pairs)
        fig3, ax3 = plt.subplots(figsize=(max(7, len(system_labels) * 0.8), 4))
        system_positions = np.arange(1, len(system_labels) + 1)
        ax3.boxplot(system_sig_vals, positions=system_positions, widths=0.45, patch_artist=True,
                    medianprops=dict(color=COLOR['black'], linewidth=1.5),
                    boxprops=dict(facecolor=COLOR['bluish_green'], alpha=0.7),
                    flierprops=dict(marker='.', markersize=3, alpha=0.5))
        ax3.axhline(0, color=COLOR['light_gray'], linewidth=0.8)
        ax3.set_xticks(system_positions)
        ax3.set_xticklabels(system_labels, rotation=35, ha='right', fontsize=9)
        ax3.set_ylabel("Slope (log₁₀ duration / year)", fontsize=7)
        ax3.set_title("Slope of significant trends (p<0.005) per system", fontsize=8)
        ax3.grid(axis='y', linestyle='--', alpha=0.4)
        plt.tight_layout()
        plt.show()
# Out:
# System significant-trend statistics ordered by significant/trends:
# [busybox] significant/trends=12/14 (85.7%), significant r median=0.639 [0.456, 0.829], significant slope/year median=0.026 [0.007, 0.085]
# [linux] significant/trends=9/12 (75.0%), significant r median=0.856 [0.784, 0.945], significant slope/year median=0.498 [0.269, 0.911]
# [toybox] significant/trends=10/14 (71.4%), significant r median=0.559 [0.469, 0.690], significant slope/year median=0.010 [0.006, 0.017]
# [axtls] significant/trends=9/14 (64.3%), significant r median=0.688 [-0.568, 0.791], significant slope/year median=0.008 [-0.017, 0.033]
# [uclibc] significant/trends=9/14 (64.3%), significant r median=0.824 [0.639, 0.948], significant slope/year median=0.022 [0.016, 0.040]
# [l4re] significant/trends=7/14 (50.0%), significant r median=0.907 [0.878, 0.947], significant slope/year median=0.051 [0.034, 0.273]
# ...

# %% [markdown]
# ## Timeout analysis

# %%
_dur_cols = [
    'left_sliced_duration',
    'right_sliced_duration',
    'left_count_duration',
    'left_sliced_count_duration',
    'right_count_duration',
    'right_sliced_count_duration',
    'tseitin_or_featureide_duration',
    'common_solutions_count_duration',
    'removed_solutions_count_duration',
    'added_solutions_count_duration',
]
_step_labels = {
    'left_sliced_duration':            'left slicing',
    'right_sliced_duration':           'right slicing',
    'left_count_duration':             'left counting',
    'left_sliced_count_duration':      'left counting',
    'right_count_duration':            'right counting',
    'right_sliced_count_duration':     'right counting',
    'tseitin_or_featureide_duration':  'CNF transform',
    'common_solutions_count_duration': 'common solutions',
    'removed_solutions_count_duration':'removed solutions',
    'added_solutions_count_duration':  'added solutions',
}

def _find_timeout_step(row):
    if pd.notna(row['total_duration']):
        return None
    for col in _dur_cols:
        if pd.isna(row[col]):
            return _step_labels[col]
    return 'unknown'

df['timeout_step'] = df.apply(_find_timeout_step, axis=1)

all_steps   = ['left slicing', 'right slicing', 'left counting', 'right counting',
               'CNF transform', 'common solutions', 'removed solutions', 'added solutions']
step_colors = dict(zip(all_steps, color_cycle(len(all_steps))))

# Include satisfy-simplified (dist CNF) alongside satisfy (tseitin)
_df_11b = df[~(df['total_duration'].isna() & (df['total_duration_shell'] == 0))].copy()
_df_11b['duration_s'] = np.where(_df_11b['total_duration'].notna(), _df_11b['total_duration_shell'] / 1e9, np.nan)
_df_11b['diff_kind']  = _df_11b['left_diff_kind'].astype(str)
_df_11b['timeout_step'] = _df_11b.apply(_find_timeout_step, axis=1)

def _method_label_11b(row):
    if row['method'] == 'satisfy-simplified':
        return 'satisfy (dist)'
    if row['method'] == 'satisfy':
        return 'satisfy (tseitin)'
    return row['method']

_df_11b['method_label'] = _df_11b.apply(_method_label_11b, axis=1)

tout_all_11b = _df_11b[_df_11b['timeout_step'].notna()]
_diff_kinds_11b = ['false', 'slice']
# columns per diff_kind: projected-count only exists in slice
_methods_11b = {
    'false': ['count', 'satisfy (tseitin)', 'satisfy (dist)'],
    'slice':  ['count', 'projected-count', 'satisfy (tseitin)'],
}
_all_methods_11b = ['count', 'projected-count', 'satisfy (tseitin)', 'satisfy (dist)']
n_cols_11b = max(len(v) for v in _methods_11b.values())

fig, axes = plt.subplots(len(_diff_kinds_11b), n_cols_11b,
                         figsize=(5.5 * n_cols_11b, 4 * len(_diff_kinds_11b)),
                         squeeze=False)
fig.suptitle('Timeout breakdown by diff kind, method, and engine (all systems combined)', fontsize=12)

y_max = 0
for ri, diff_kind in enumerate(_diff_kinds_11b):
    dm_tout   = tout_all_11b[tout_all_11b['diff_kind'] == diff_kind]
    dm_df     = _df_11b[_df_11b['diff_kind'] == diff_kind]
    col_slots = _methods_11b[diff_kind]

    for ci in range(n_cols_11b):
        ax = axes[ri][ci]
        if ci >= len(col_slots):
            ax.set_visible(False)
            continue
        method = col_slots[ci]
        sub             = dm_tout[dm_tout['method_label'] == method]
        present_engines = sorted(dm_df[dm_df['method_label'] == method]['engine'].unique())

        counts = (
            sub.groupby(['engine', 'timeout_step'])
            .size()
            .unstack(fill_value=0)
            .reindex(index=present_engines, columns=all_steps, fill_value=0)
        )
        counts = counts.loc[:, (counts > 0).any(axis=0)]

        x      = np.arange(len(present_engines))
        bottom = np.zeros(len(present_engines))
        for step in counts.columns:
            vals = counts[step].values
            ax.bar(x, vals, bottom=bottom, color=step_colors[step], alpha=0.85)
            for xi, (v, b) in enumerate(zip(vals, bottom)):
                if v > 0:
                    ax.text(xi, b + v / 2, str(v), ha='center', va='center',
                            fontsize=7, color=COLOR['white'], fontweight='bold')
            bottom += vals

        if bottom.size: y_max = max(y_max, bottom.max())
        ax.set_xticks(x)
        ax.set_xticklabels(present_engines, rotation=20, ha='right')
        ax.set_title(f'{diff_kind}  |  {method}', fontsize=10)
        ax.grid(axis='y', linestyle='--', alpha=0.4)

for row in axes:
    for ax in row:
        if ax.get_visible():
            ax.set_ylim(top=y_max * 1.1)
for ri in range(len(_diff_kinds_11b)):
    axes[ri][0].set_ylabel('Number of timeouts')

present_steps = [s for s in all_steps if s in tout_all_11b['timeout_step'].values]
handles = [
    plt.matplotlib.patches.Patch(facecolor=step_colors[s], alpha=0.85, label=s)
    for s in reversed(present_steps)
]
axes[0][-1].legend(handles=handles, fontsize=8, loc='upper right', bbox_to_anchor=(1.45, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correctness evaluation
#
# This check validates agreement only inside equivalence classes where the experiment should be semantically identical. Each class fixes the subject system, the extractor/source (`KClause`, `KConfigReader`, or `XML`), the stripped left/right model pair, and the semantics (`false`/Closed or `slice`/Projection). Consequently, this section deliberately does **not** compare Closed against Projection, and it deliberately does **not** compare KClause against KConfigReader.
#
# Within one such class, algorithmic configuration is allowed to vary: method, solver engine, CNF transformation, and negation. For every class with at least two completed outputs, we expect two kinds of agreement:
#
# - all available classifications must be identical across algorithm configurations;
# - all available exact solution-count triples `(removed_solutions_count, common_solutions_count, added_solutions_count)` must be identical across solvers and both negation values.
#
# Known historical exceptions:
#
# - `satisfy-simplified` rows in this archived CSV were produced by a clausy bug that was fixed in `00b52dfb31eebe0dd2b5f3a9eae8425fc94023fe`. Those rows are excluded from this correctness check.
# - The remaining solution-count inconsistency occurs only for `slice`/Projection KConfigReader cases when comparing ordinary model counting with projected model counting. This has been fixed in clausy commits `5a0c43e79ee619aa77517343c52a2c11e071cbbc` and `0cf77b1752dfe741d2ea13c1f4179356d080d539`.
#
# Timeouts and missing outputs are skipped for the corresponding value check, because they provide no classification or solution triple to compare. The cell prints compact totals first and then shows only the first few mismatch details, if any, so the notebook stays readable.

# %%
# Correctness checks are scoped to one benchmark and one semantics at a time.
# We intentionally do not compare KClause with KConfigReader, and we intentionally do not
# compare Closed/false semantics with Projection/slice semantics.
# BusyBox commit/yearly passes are excluded here; this check covers the regular main pass.
# satisfy-simplified is excluded because archived runs used a known-buggy clausy revision;
# the bug was fixed in clausy commit 00b52dfb31eebe0dd2b5f3a9eae8425fc94023fe.
# The remaining solution-count mismatches are the known slice/KConfigReader count vs.
# projected-count inconsistency, fixed in clausy commit 5a0c43e7/0cf77b17.
# After fixing all bugs, we get the following output: 
# Classification agreement: checked groups=227, mismatches=0
# Solution count agreement: checked groups=225, mismatches=0
_corr = df[~df['system'].isin(['busybox-commits', 'busybox-yearly'])].copy()
# _corr = _corr[_corr['method'] != 'satisfy-simplified'].copy()

# Reuse the source/model normalization from the paired runtime analysis above. df itself does
# not keep these helper columns, so we derive them here without duplicating the helper code.
_corr['source'] = _corr['left_formula'].apply(_factor_source)
_corr['left_model'] = _corr['left_formula'].apply(_factor_strip_source)
_corr['right_model'] = _corr['right_formula'].apply(_factor_strip_source)

# This is the semantic equivalence class. Everything outside this key is an implementation
# choice whose result should agree inside the class: method, engine, CNF transform, negation.
# diff_kind stays in the key because false/Closed and slice/Projection need not agree.
_correctness_key = ['system', 'source', 'left_model', 'right_model', 'diff_kind']
_correctness_config_cols = ['method', 'engine', 'cnf_transform', 'negate']
_solution_count_cols = ['removed_solutions_count', 'common_solutions_count', 'added_solutions_count']
_MAX_MISMATCH_SUMMARY = None  # None prints every mismatch group

def _solution_count_tuple(row):
    # Counts are loaded as strings because they can exceed floating-point precision.
    # Comparing these strings avoids false mismatches from rounded fraction columns.
    return tuple(str(row[col]) for col in _solution_count_cols)

def _short_model(path):
    return str(path).split('/')[-1]

def _short_count(value, limit=18):
    value = str(value)
    return value if len(value) <= limit else value[:limit - 1] + '...'

def _short_config(row):
    return f"{row['method']}/{row['engine']}/{row['cnf_transform']}/neg={row['negate']}"

def _brief_key(key_values):
    key = dict(zip(_correctness_key, key_values))
    return (f"{key['system']} | {key['source']} | {key['diff_kind']} | "
            f"{_short_model(key['left_model'])} -> {_short_model(key['right_model'])}")

def _summarize_value_configs(group, value_col, formatter=str):
    parts = []
    for value, value_group in group.groupby(value_col, dropna=False):
        configs = (
            value_group.sort_values(_correctness_config_cols)
            .drop_duplicates(_correctness_config_cols)
            .head(2)
            .apply(_short_config, axis=1)
            .tolist()
        )
        n_configs = value_group[_correctness_config_cols].drop_duplicates().shape[0]
        suffix = '' if n_configs <= 2 else ', ...'
        parts.append(f"{formatter(value)} ({len(value_group)} rows: {', '.join(configs)}{suffix})")
    return '; '.join(parts)

def _format_solution_tuple(value):
    removed, common, added = value
    return f"r={_short_count(removed)}, c={_short_count(common)}, a={_short_count(added)}f"

# 1) Classification agreement. Rows without a classification are typically timeouts or failed
# runs, so they are skipped for this value-level check. A group with fewer than two available
# classifications cannot demonstrate agreement or disagreement.
_class_rows = _corr.dropna(subset=['classification']).copy()
_class_groups_checked = 0
_class_mismatches = []
for key_values, group in _class_rows.groupby(_correctness_key, dropna=False):
    if len(group) < 2:
        continue
    _class_groups_checked += 1
    unique_classes = sorted(group['classification'].astype(str).unique())
    if len(unique_classes) > 1:
        _class_mismatches.append((key_values, group))

print(f"Classification agreement: checked groups={_class_groups_checked}, "
      f"mismatches={len(_class_mismatches)}")
_class_mismatches_to_show = _class_mismatches if _MAX_MISMATCH_SUMMARY is None else _class_mismatches[:_MAX_MISMATCH_SUMMARY]
for key_values, group in _class_mismatches_to_show:
    print(f"  {_brief_key(key_values)} :: "
          f"{_summarize_value_configs(group, 'classification')}")
if _MAX_MISMATCH_SUMMARY is not None and len(_class_mismatches) > _MAX_MISMATCH_SUMMARY:
    print(f"  ... {len(_class_mismatches) - _MAX_MISMATCH_SUMMARY} more classification mismatch groups")

# 2) Solution-composition agreement. Require all three exact count values to be present and
# compare the triple as one result. This checks removed/common/added agreement across solvers,
# algorithms, CNF encodings, and both negation values within the same semantic class.
_solution_rows = _corr.dropna(subset=_solution_count_cols).copy()
_solution_rows['_solution_count_tuple'] = _solution_rows.apply(_solution_count_tuple, axis=1)
_solution_groups_checked = 0
_solution_mismatches = []
for key_values, group in _solution_rows.groupby(_correctness_key, dropna=False):
    if len(group) < 2:
        continue
    _solution_groups_checked += 1
    if group['_solution_count_tuple'].nunique() > 1:
        _solution_mismatches.append((key_values, group))

print(f"Solution count agreement: checked groups={_solution_groups_checked}, "
      f"mismatches={len(_solution_mismatches)}")
_solution_mismatches_to_show = _solution_mismatches if _MAX_MISMATCH_SUMMARY is None else _solution_mismatches[:_MAX_MISMATCH_SUMMARY]
for key_values, group in _solution_mismatches_to_show:
    print(f"  {_brief_key(key_values)} :: "
          f"{_summarize_value_configs(group, '_solution_count_tuple', _format_solution_tuple)}")
if _MAX_MISMATCH_SUMMARY is not None and len(_solution_mismatches) > _MAX_MISMATCH_SUMMARY:
    print(f"  ... {len(_solution_mismatches) - _MAX_MISMATCH_SUMMARY} more solution-count mismatch groups")
# Out:
# Classification agreement: checked groups=1366, mismatches=10
#   busybox | KConfigReader | slice | [2010-06-12-13-52-00]1_16_2.model -> [2010-07-06-02-16-50]1_17_0.model :: ArbitraryEdit (1 rows: satisfy-simplified/kissat/dist/neg=True); Generalization (8 rows: count/d4/tseitin/neg=False, count/d4/tseitin/neg=True, ...)
#   toybox | KClause | slice | [2013-07-01-05-10-28]0.4.5.model -> [2013-09-11-17-09-53]0.4.6.model :: ArbitraryEdit (8 rows: count/d4/tseitin/neg=False, count/d4/tseitin/neg=True, ...); Refactoring (1 rows: satisfy-simplified/kissat/dist/neg=True)
#   uclibc | KConfigReader | slice | [2011-06-08-19-35-20]v0.9.32.model -> [2011-12-30-11-11-07]v0.9.32.1.model :: ArbitraryEdit (1 rows: satisfy-simplified/kissat/dist/neg=True); Refactoring (8 rows: count/d4/tseitin/neg=False, count/d4/tseitin/neg=True, ...)
# ...

# %% [markdown]
# ### Classification distribution
#
# This chart counts each completed `kissat` classification once per system version pair and facets the result by source and differencing kind. XML inputs are omitted so the four panels show the two KConfig extraction sources under Closed and Projection semantics.

# %%
# Classification distribution after collapsing algorithm configurations.
# This uses the same representative-row rule as the solution-composition timeline: for each
# system/extractor/differencing-kind/version-pair group, prefer rows with solution composition
# and then rows with classification information. Counts are aggregated across systems; colors
# encode the classification categories.
# Normalize the extractor/source names to the labels used in the paper figures.
def _class_dist_source(formula):
    first = str(formula).split('/')[0]
    if first == 'extract-kconfig-models-with-kconfigreader':
        return 'KConfigReader'
    if first == 'extract-kconfig-models-with-kclause':
        return 'KClause'
    return 'XML'


# Keep only the release-level subject systems. Commit/yearly histories are analysed separately
# elsewhere and would otherwise dominate this summary.
_class_dist = df[~df['system'].isin(['busybox-commits', 'busybox-yearly'])].copy()
# The projected-count + negation combination is not an independent algorithm configuration in
# the experiment output, so exclude it before collapsing configurations.
_class_dist = _class_dist[
    ~((_class_dist['method'] == 'projected-count') & (_class_dist['negate'].astype(str) == 'True'))
].copy()
_class_dist['source'] = _class_dist['left_formula'].apply(_class_dist_source)
_class_dist = _class_dist[_class_dist['source'].isin(['KConfigReader', 'KClause', 'XML'])].copy()
_class_dist['diff_kind'] = _class_dist['left_diff_kind'].astype(str)
# Collapse all algorithm configurations to one representative row per
# system/source/semantics/version pair. Prefer rows with solution fractions because those are
# needed to split ArbitraryEdit into near/generalization/specialization variants; otherwise keep
# any row that at least has a classification.
_class_dist['_collapse_priority'] = (
    _class_dist['removed_solutions'].notna().astype(int) * 2 +
    _class_dist['classification'].notna().astype(int)
)
_class_dist = (
    _class_dist
    .sort_values('_collapse_priority', ascending=False)
    .drop_duplicates(subset=['system', 'source', 'diff_kind', 'left_formula', 'right_formula'])
)
_class_dist = _class_dist[_class_dist['classification'].notna()].copy()

# The x-axis intentionally shows two views at once. Gen/Spec include the quantitative
# near-generalization/specialization cases with lighter colors. AE also includes those same
# near cases, hatched, because a non-quantitative differencer would classify them as arbitrary.
# Thus near cases are intentionally counted once in Gen/Spec and once again inside AE.
_CLASS_STACKS = [
    ('Ref', [('Refactoring', 'Refactoring'), ('Near Refactoring', 'Near Refactoring')]),
    ('Gen', [('Generalization', 'Generalization'), ('Near Generalization', 'Near Generalization')]),
    ('Spec', [('Specialization', 'Specialization'), ('Near Specialization', 'Near Specialization')]),
    ('AE', [('Truly Arbitrary', 'Truly Arbitrary'), ('Near Refactoring', 'Near Refactoring'), ('Near Generalization', 'Near Generalization'), ('Near Specialization', 'Near Specialization')]),
]
_CLASS_COLORS = {
    'Refactoring':         COLOR['bluish_green'],
    'Near Refactoring':    '#8FD6B6',
    'Generalization':      COLOR['blue'],
    'Near Generalization': COLOR['sky_blue'],
    'Specialization':      COLOR['vermillion'],
    'Near Specialization': COLOR['orange'],
    'Truly Arbitrary':     COLOR['gray'],
}
# Compact one-row legend labels for the displayed classification colors.
_CLASS_LEGEND_ITEMS = [
    ('Ref', 'Refactoring', None, 1.0),
    ('Near (1%)', 'Near Refactoring', None, 1.0),
    ('Gen', 'Generalization', None, 1.0),
    ('Near (1%)', 'Near Generalization', None, 1.0),
    ('Spec', 'Specialization', None, 1.0),
    ('Near (1%)', 'Near Specialization', None, 1.0),
    ('Arbitrary Edit', 'Truly Arbitrary', None, 1.0),
]       
_DIFF_KIND_LABELS = {'false': 'Closed', 'slice': 'Proj'}
_SOURCE_LABELS = {'XML': 'FM Benchmark', 'KConfigReader': 'KConfigReader', 'KClause': 'KClause'}
_SOURCE_ORDER = ['KConfigReader', 'KClause', 'XML']
_DIFF_KIND_ORDER = ['false', 'slice']


# Refine ArbitraryEdit using the solution-composition fractions. The threshold is inverted:
# at 1%, a small added/removed fraction is interpreted as a near class.
_NEAR_SHARE_THRESHOLD = 0.01

def _class_dist_detailed_clf(row):
    clf = row['classification']
    if pd.isna(clf):
        return 'Truly Arbitrary'
    if clf != 'ArbitraryEdit':
        return clf
    r = row['removed_solutions']
    c = row['common_solutions']
    a = row['added_solutions']
    if any(pd.isna(v) for v in [r, c, a]):
        return 'Truly Arbitrary'
    if a <= _NEAR_SHARE_THRESHOLD and r <= _NEAR_SHARE_THRESHOLD:
        return 'Near Refactoring'
    if a <= _NEAR_SHARE_THRESHOLD:
        return 'Near Specialization'
    if r <= _NEAR_SHARE_THRESHOLD:
        return 'Near Generalization'
    return 'Truly Arbitrary'


_class_dist['_dclf'] = _class_dist.apply(_class_dist_detailed_clf, axis=1)
# Facet only by source. Closed and projected semantics are shown side by side inside each
# classification group.
_source_facets = [
    source for source in _SOURCE_ORDER
    if not _class_dist[_class_dist['source'] == source].empty
]

fig, axes = plt.subplots(
    1,
    len(_source_facets),
    figsize=(max(7, 1.9 * len(_source_facets)), 3.5),
    sharey=True,
    squeeze=False,
)
# Compact grouped layout: each class has a Closed bar and a Projected bar.
group_x = np.arange(len(_CLASS_STACKS)) * 0.62
bar_width = 0.20
diff_offsets = {'false': -bar_width / 1.8, 'slice': bar_width / 1.8}
_DIFF_SHORT_LABELS = {'false': 'C', 'slice': 'P'}

for ax, source in zip(axes.ravel(), _source_facets):
    for diff_kind in _DIFF_KIND_ORDER:
        facet_data = _class_dist[
            (_class_dist['source'] == source) &
            (_class_dist['diff_kind'] == diff_kind)
        ]
        if facet_data.empty:
            continue

        # Normalize each segment by the source/semantics total. Near cases are intentionally
        # shown twice: in Gen/Spec and again, hatched, inside AE.
        counts = facet_data.groupby('_dclf').size()
        total = counts.sum()
        bottom = np.zeros(len(_CLASS_STACKS), dtype=float)
        x = group_x + diff_offsets[diff_kind]

        for stack_idx, (stack_label, parts) in enumerate(_CLASS_STACKS):
            for clf, color_key in parts:
                value = counts.get(clf, 0) / total * 100 if total else 0
                if value == 0:
                    continue
                # Hatching is used only for the repeated near segments inside AE. The primary
                # Gen/Spec near segments use their lighter colors without hatching.
                is_near_in_arbitrary = stack_label == 'AE' and clf in ['Near Refactoring', 'Near Generalization', 'Near Specialization']
                ax.bar(
                    x[stack_idx],
                    value,
                    bottom=bottom[stack_idx],
                    color=_CLASS_COLORS[color_key],
                    alpha=0.55 if is_near_in_arbitrary else 1.0,
                    hatch='///' if is_near_in_arbitrary else None,
                    width=bar_width,
                    edgecolor='white',
                    linewidth=0.5,
                )
                bottom[stack_idx] += value

    # n counts collapsed rows in this source facet, distinguishing Closed and Projected.
    facet_n = len(_class_dist[_class_dist['source'] == source])
    ax.text(
        0.04,
        0.94,
        f'n={facet_n}',
        transform=ax.transAxes,
        ha='left',
        va='top',
        fontsize=10,
        color=COLOR['gray'],
    )
    ax.set_title(_SOURCE_LABELS[source], fontsize=16)
    # First x-axis line marks the semantics (C/P), second line marks the class group.
    tick_positions = np.ravel([[gx + diff_offsets[d] for d in _DIFF_KIND_ORDER] for gx in group_x])
    tick_labels = [_DIFF_SHORT_LABELS[d] for _ in _CLASS_STACKS for d in _DIFF_KIND_ORDER]
    ax.set_xticks(tick_positions)
    ax.set_xticklabels(tick_labels, fontsize=13)
    for gx, (label, _) in zip(group_x, _CLASS_STACKS):
        ax.text(
            gx,
            -0.20,
            label,
            transform=ax.get_xaxis_transform(),
            ha='center',
            va='top',
            fontsize=15,
        )
    ax.tick_params(axis='x', pad=3)
    ax.set_xlim(group_x[0] - 0.28, group_x[-1] + 0.28)
    ax.set_ylim(0, 100)
    ax.tick_params(axis='y', labelsize=15)
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v:.0f}'))
    ax.grid(axis='y', linestyle='--', alpha=0.35)

for ax in axes[:, 0]:
    ax.set_ylabel('Evolution Steps (%)', fontsize=16)

# The legend sits directly below the two-line x-axis labels and names the classification colors.
_legend_handles = [
    plt.Rectangle(
        (0, 0),
        1,
        1,
        facecolor=_CLASS_COLORS[color_key],
        alpha=alpha,
        hatch=hatch,
        edgecolor='white',
        linewidth=0.5,
    )
    for _, color_key, hatch, alpha in _CLASS_LEGEND_ITEMS
]
fig.legend(
    _legend_handles,
    [label for label, _, _, _ in _CLASS_LEGEND_ITEMS],
    loc='lower center',
    ncol=len(_CLASS_LEGEND_ITEMS),
    fontsize=10,
    frameon=False,
    handlelength=1.2,
    columnspacing=0.65,
    bbox_to_anchor=(0.5, 0.13),
)
fig.tight_layout(rect=[0, 0.145, 1, 0.98], w_pad=0.45)
fig.subplots_adjust(wspace=0.1)
fig.savefig(paper_image_dir / 'classification-distribution.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Classification breakdown per system
#
# Each facet shows one system. Closed and Projection are the main x-axis groups; within each group, separate stacked bars show KClause and KConfigReader where available. The stacked segments split arbitrary edits into near-generalization, near-specialization, and truly arbitrary edits using the solution composition when available.

# %%
import matplotlib.ticker as ticker

# Self-contained version of the classification-breakdown plot. We choose one representative
# row per system/source/semantics/version pair, preferring rows with solution-composition data
# so ArbitraryEdit can be split into near-generalization, near-specialization, and truly
# arbitrary edit.
# Helper functions are local to keep this cell runnable after the source-faceted overview.
def _breakdown_source(formula):
    first = str(formula).split('/')[0]
    if first == 'extract-kconfig-models-with-kconfigreader':
        return 'KConfigReader'
    if first == 'extract-kconfig-models-with-kclause':
        return 'KClause'
    return 'XML'


def _breakdown_strip_source(formula):
    parts = str(formula).split('/')
    if parts[0].startswith('extract-kconfig-models-with-'):
        return '/'.join(parts[1:])
    return str(formula)


_NEAR_SHARE_THRESHOLD = 0.01

# Detailed class order controls both stack order and the legend order in the per-system plot.
_CLF_DETAILED_ORDER = [
    'Refactoring',
    'Near Refactoring',
    'Generalization',
    'Near Generalization',
    'Specialization',
    'Near Specialization',
    'Truly Arbitrary',
]
_CLF_DETAILED_COLORS = {
    'Refactoring':         COLOR['bluish_green'],
    'Near Refactoring':    '#8FD6B6',
    'Generalization':      COLOR['blue'],
    'Specialization':      COLOR['vermillion'],
    'Near Generalization': COLOR['sky_blue'],
    'Near Specialization': COLOR['orange'],
    'Truly Arbitrary':     COLOR['gray'],
}
_BREAKDOWN_DIFF_ORDER = ['false', 'slice']
_BREAKDOWN_DIFF_LABELS = {'false': 'Closed', 'slice': 'Proj'}
# Keep XML first so XML-only systems can be detected and drawn as single-source facets;
# KConfig systems still show KConfigReader and KClause side by side.
_BREAKDOWN_SOURCE_ORDER = ['XML', 'KConfigReader', 'KClause']
_BREAKDOWN_SOURCE_LABELS = {'XML': '', 'KClause': 'KCl', 'KConfigReader': 'KCR'}
_BREAKDOWN_SYSTEM_LABELS = {'FinancialServices01': 'FS01', 'automotive2': 'Auto2'}

# Start from all classified release-level rows. The next block collapses repeated algorithm
# configurations to one row per system/source/semantics/version pair.
_breakdown = df[
    df['classification'].notna() &
    (~df['system'].isin(['busybox-commits', 'busybox-yearly']))
].copy()
_breakdown['source'] = _breakdown['left_formula'].apply(_breakdown_source)
_breakdown = _breakdown[_breakdown['source'].isin(_BREAKDOWN_SOURCE_ORDER)].copy()
# Strip extractor prefixes only for pair identity; source remains a separate key so KClause
# and KConfigReader are not accidentally compared/collapsed together.
_breakdown['left_model'] = _breakdown['left_formula'].apply(_breakdown_strip_source)
_breakdown['right_model'] = _breakdown['right_formula'].apply(_breakdown_strip_source)
_breakdown['diff_kind'] = _breakdown['left_diff_kind'].astype(str)
_breakdown['_has_solution_share'] = _breakdown[['removed_solutions', 'common_solutions', 'added_solutions']].notna().all(axis=1)
# Prefer rows with quantitative solution shares; break ties with the direct SAT/kissat
# classification because it is the representative non-counting classification result.
_breakdown['_classification_priority'] = (
    (_breakdown['method'] == 'satisfy').astype(int) * 2 +
    (_breakdown['engine'] == 'kissat').astype(int)
)
_breakdown['_solution_priority'] = _breakdown['_has_solution_share'].astype(int)
_breakdown = (
    _breakdown
    .sort_values(['_solution_priority', '_classification_priority'], ascending=False)
    .drop_duplicates(subset=['system', 'source', 'diff_kind', 'left_model', 'right_model'])
)

# Same quantitative refinement as above, but here the refined class is the actual stack
# category instead of an overlay inside AE.
def _detailed_clf(row):
    clf = row['classification']
    if pd.isna(clf):
        return 'Truly Arbitrary'
    if clf != 'ArbitraryEdit':
        return clf
    r = row['removed_solutions']
    c = row['common_solutions']
    a = row['added_solutions']
    if any(pd.isna(v) for v in [r, c, a]):
        return 'Truly Arbitrary'
    if a <= _NEAR_SHARE_THRESHOLD and r <= _NEAR_SHARE_THRESHOLD:
        return 'Near Refactoring'
    if a <= _NEAR_SHARE_THRESHOLD:
        return 'Near Specialization'
    if r <= _NEAR_SHARE_THRESHOLD:
        return 'Near Generalization'
    return 'Truly Arbitrary'

_breakdown['_dclf'] = _breakdown.apply(_detailed_clf, axis=1)

# Paper/table order requested for the system facets. Any unexpected systems are appended
# alphabetically below so the plot does not silently drop data.
_SYSTEM_DISPLAY_ORDER = [
    'axtls',
    'buildroot',
    'busybox',
    'embtoolkit',
    'freetz-ng',
    'l4re',
    'linux',
    'toybox',
    'uclibc',
    'uclibc-ng',
    'FinancialServices01',
    'automotive2',
]
_present_systems = set(_breakdown['system'].dropna())
_system_order = [system for system in _SYSTEM_DISPLAY_ORDER if system in _present_systems]
_system_order += sorted(_present_systems - set(_system_order))

_ncols = max(1, len(_system_order))
_nrows = 1
# XML-only systems do not have source pairs, so give them slightly narrower facets while
# preserving equal widths for the KConfig systems.
_width_ratios = []
for system in _system_order:
    sources = set(_breakdown.loc[_breakdown['system'] == system, 'source'].dropna())
    _width_ratios.append(0.82 if sources == {'XML'} else 1.0)
with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, axes = plt.subplots(
        _nrows,
        _ncols,
        figsize=(max(11, 1.28 * sum(_width_ratios)), 3.25),
        sharey=True,
        squeeze=False,
        gridspec_kw={'width_ratios': _width_ratios},
    )
    # Closed/Projected bars are close together; XML-only systems use an even tighter spacing.
    _group_x = np.arange(len(_BREAKDOWN_DIFF_ORDER)) * 0.42
    _xml_group_x = np.arange(len(_BREAKDOWN_DIFF_ORDER)) * 0.22

    for ax, system in zip(axes.ravel(), _system_order):
        system_data = _breakdown[_breakdown['system'] == system]
        # Draw only the sources available for this system. KConfig systems get side-by-side
        # KConfigReader/KClause bars; XML benchmark systems get a single bar per semantics.
        source_order = [
            source for source in _BREAKDOWN_SOURCE_ORDER
            if source in set(system_data['source'].dropna())
        ]
        group_x = _xml_group_x if source_order == ['XML'] else _group_x
        bar_width = min(0.15, 0.30 / max(1, len(source_order)))
        source_offsets = {
            source: (idx - (len(source_order) - 1) / 2) * (bar_width + 0.018)
            for idx, source in enumerate(source_order)
        }

        for source in source_order:
            source_data = system_data[system_data['source'] == source]
            # Normalize within each semantics row so every Closed/Projected bar sums to 100%.
            counts = (
                source_data
                .groupby(['diff_kind', '_dclf'])
                .size()
                .unstack(fill_value=0)
                .reindex(index=_BREAKDOWN_DIFF_ORDER, columns=_CLF_DETAILED_ORDER, fill_value=0)
            )
            pcts = counts.div(counts.sum(axis=1).replace(0, np.nan), axis=0).fillna(0) * 100
            x = group_x + source_offsets[source]
            bottom = np.zeros(len(_BREAKDOWN_DIFF_ORDER), dtype=float)

            for clf in _CLF_DETAILED_ORDER:
                values = pcts[clf].values
                ax.bar(
                    x,
                    values,
                    bottom=bottom,
                    color=_CLF_DETAILED_COLORS[clf],
                    width=bar_width,
                    edgecolor='white',
                    linewidth=0.5,
                )
                bottom += values

        ax.set_title(_BREAKDOWN_SYSTEM_LABELS.get(system, system), fontsize=16)
        ax.set_xticks(group_x)
        # XML-only facets are narrower, so use slightly shorter labels there.
        diff_labels = ['Clos', 'Proj'] if source_order == ['XML'] else [_BREAKDOWN_DIFF_LABELS[d] for d in _BREAKDOWN_DIFF_ORDER]
        ax.set_xticklabels(diff_labels, fontsize=15)
        ax.tick_params(axis='x', pad=8)
        ax.set_xlim(group_x[0] - (0.11 if source_order == ['XML'] else 0.18), group_x[-1] + (0.11 if source_order == ['XML'] else 0.18))
        ax.set_ylim(0, 100)
        ax.tick_params(axis='y', labelsize=15)
        ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v:.0f}'))
        ax.grid(axis='y', linestyle='--', alpha=0.35)

    for ax in axes.ravel()[len(_system_order):]:
        ax.set_visible(False)

    for ax in axes[:, 0]:
        ax.set_ylabel('#Evolution Steps (%)', fontsize=16)

    # Unlike the compact source summary above, this per-system plot keeps the legend because it
    # uses all detailed classes directly as stacks.
    _class_handles = [plt.Rectangle((0, 0), 1, 1, color=_CLF_DETAILED_COLORS[c]) for c in _CLF_DETAILED_ORDER]
    fig.legend(
        _class_handles,
        _CLF_DETAILED_ORDER,
        loc='lower center',
        ncol=len(_CLF_DETAILED_ORDER),
        fontsize=14,
        frameon=False,
        bbox_to_anchor=(0.5, 0.02),
    )
    fig.tight_layout(rect=[0, 0.15, 1, 1], w_pad=0.01)
    fig.subplots_adjust(wspace=0.15)
    fig.savefig(paper_image_dir / 'classification-breakdown-by-system.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# %%
# LaTeX summary table for the classification-comparison scenarios.
# Each class cell divides the absolute class count of the first displayed setting
# by the absolute class count of the second displayed setting on matched rows.
# The rows intentionally mirror the three conceptual comparisons used in the text:
# semantics only, quantification only, and Thüm's closed/classify setting versus our
# projected/quantified setting.

def _cmp_source(formula):
    first = str(formula).split('/')[0]
    if first == 'extract-kconfig-models-with-kconfigreader':
        return 'KConfigReader'
    if first == 'extract-kconfig-models-with-kclause':
        return 'KClause'
    return 'XML'


# Reuse the same collapse rule as the classification-distribution figure: one row per
# system/source/semantics/version pair, preferring rows with solution fractions and then rows
# with a classification. This keeps the table aligned with the plotted data.
_cmp = df[~df['system'].isin(['busybox-commits', 'busybox-yearly'])].copy()
_cmp = _cmp[~((_cmp['method'] == 'projected-count') & (_cmp['negate'].astype(str) == 'True'))].copy()
_cmp['source'] = _cmp['left_formula'].apply(_cmp_source)
_cmp = _cmp[_cmp['source'].isin(['KConfigReader', 'KClause', 'XML'])].copy()
_cmp['diff_kind'] = _cmp['left_diff_kind'].astype(str)
_cmp['_collapse_priority'] = (
    _cmp['removed_solutions'].notna().astype(int) * 2 +
    _cmp['classification'].notna().astype(int)
)
_cmp = (
    _cmp
    .sort_values('_collapse_priority', ascending=False)
    .drop_duplicates(subset=['system', 'source', 'diff_kind', 'left_formula', 'right_formula'])
)
_cmp = _cmp[_cmp['classification'].notna()].copy()

_CMP_KEY = ['system', 'source', 'left_formula', 'right_formula']
_CMP_CLASSES = ['Ref', 'Gen', 'Spec', 'AE']

def _cmp_classify(row):
    return {
        'Refactoring': 'Ref',
        'Generalization': 'Gen',
        'Specialization': 'Spec',
        'ArbitraryEdit': 'AE',
    }.get(row['classification'], 'AE')


def _cmp_quantify(row, nu):
    base = _cmp_classify(row)
    if base != 'AE':
        return base
    r = row['removed_solutions']
    c = row['common_solutions']
    a = row['added_solutions']
    if any(pd.isna(v) for v in [r, c, a]):
        return 'AE'
    if a <= nu and r <= nu:
        return 'Ref'
    if a <= nu:
        return 'Spec'
    if r <= nu:
        return 'Gen'
    return 'AE'


def _cmp_counts(labels):
    counts = labels.value_counts()
    return {cls: int(counts.get(cls, 0)) for cls in _CMP_CLASSES}


def _fmt_count_ratio(numerator, denominator):
    if denominator == 0:
        return '--' if numerator == 0 else r'\infty'
    ratio = numerator / denominator
    return f'{ratio:.2f}'.rstrip('0').rstrip('.')


def _comparison_row(numerator_name, denominator_name, nu_label, numerator_labels, denominator_labels):
    numerator_dist = _cmp_counts(numerator_labels)
    denominator_dist = _cmp_counts(denominator_labels)
    return [
        numerator_name,
        denominator_name,
        nu_label,
        *[_fmt_count_ratio(numerator_dist[cls], denominator_dist[cls]) for cls in _CMP_CLASSES],
    ]


def _paired_labels(left_df, right_df, left_func, right_func):
    left = left_df[_CMP_KEY].copy()
    left['_left_label'] = left_df.apply(left_func, axis=1).values
    right = right_df[_CMP_KEY].copy()
    right['_right_label'] = right_df.apply(right_func, axis=1).values
    paired = left.merge(right, on=_CMP_KEY, how='inner')
    return paired['_left_label'], paired['_right_label']


_rows = []
_midrules_after = []

# Projection vs. closed semantics with the non-quantitative classification only.
_closed = _cmp[_cmp['diff_kind'] == 'false'].copy()
_projected = _cmp[_cmp['diff_kind'] == 'slice'].copy()
_left, _right = _paired_labels(_closed, _projected, _cmp_classify, _cmp_classify)
_rows.append(_comparison_row('Projection', 'Closed', '--', _right, _left))
_midrules_after.append(len(_rows))

# Quantification effect at closed semantics for three nearness thresholds.
for _nu in [0.000001, 0.001, 0.01, 0.05]:
    _rows.append(_comparison_row(
        'quantify$_k$',
        'classify',
        f'{_nu * 100:g}\\%',
        _closed.apply(lambda row, nu=_nu: _cmp_quantify(row, nu), axis=1),
        _closed.apply(_cmp_classify, axis=1),
    ))
_midrules_after.append(len(_rows))

# Thüm's algorithm (closed + classify) versus the projected quantitative variant.
for _nu in [0.000001, 0.001, 0.01, 0.05]:
    _left, _right = _paired_labels(
        _closed,
        _projected,
        _cmp_classify,
        lambda row, nu=_nu: _cmp_quantify(row, nu),
    )
    _rows.append(_comparison_row(
        'Projection + quantify$_k$',
        'Closed + classify',
        f'{_nu * 100:g}\\%',
        _right,
        _left,
    ))

_lines = [
    r'\begin{tabular}{llccccc}',
    r'\toprule',
    r'Compared value 1 & Compared value 2 & $\nu$ & Ref & Gen & Spec & AE \\',
    r'\midrule',
]
for _idx, _row in enumerate(_rows, start=1):
    _lines.append(' & '.join(_row) + r' \\')
    if _idx in _midrules_after:
        _lines.append(r'\midrule')
_lines += [
    r'\bottomrule',
    r'\end{tabular}',
]

_latex_classification_comparison = '\n'.join(_lines)
print(_latex_classification_comparison)
# Out:
# \begin{tabular}{llccccc}
# \toprule
# Compared value 1 & Compared value 2 & $\nu$ & Ref & Gen & Spec & AE \\
# \midrule
# Projection & Closed & -- & 1.52 & 1.38 & 1.78 & 0.67 \\
# \midrule
# quantify$_k$ & classify & 0.0001\% & 1.01 & 2.07 & 1.52 & 0.83 \\
# quantify$_k$ & classify & 0.1\% & 1.01 & 3.1 & 2.04 & 0.67 \\
# quantify$_k$ & classify & 1\% & 1.03 & 3.63 & 2.43 & 0.57 \\
# quantify$_k$ & classify & 5\% & 1.06 & 4.37 & 3.35 & 0.42 \\
# \midrule
# Projection + quantify$_k$ & Closed + classify & 0.0001\% & 1.53 & 1.58 & 2 & 0.63 \\
# Projection + quantify$_k$ & Closed + classify & 0.1\% & 1.54 & 1.68 & 2.57 & 0.58 \\
# Projection + quantify$_k$ & Closed + classify & 1\% & 1.59 & 1.7 & 3 & 0.53 \\
# Projection + quantify$_k$ & Closed + classify & 5\% & 1.66 & 1.83 & 3.52 & 0.45 \\
# \bottomrule
# \end{tabular}

# %%
from matplotlib.patches import Rectangle
import matplotlib.ticker as ticker
import matplotlib.transforms as transforms

# Combined diagram for the near-classification rule used by the threshold table above.
# x is the relative number of removed configurations; y is the relative number of added configurations.
_NEAR_CLASS_THRESHOLDS = [0.000001, 0.001, 0.01, 0.05]
_NEAR_AXIS_MAX = 0.10
_NEAR_MAX_THRESHOLD = max(_NEAR_CLASS_THRESHOLDS)
_NEAR_CLASS_COLORS = {
    'Refactoring': COLOR['bluish_green'],
    'Near Refactoring': '#8FD6B6',
    'Near Generalization': COLOR['sky_blue'],
    'Near Specialization': COLOR['orange'],
    'Truly Arbitrary': COLOR['gray'],
}
_NEAR_CLASS_REGIONS = [
    ('Near Refactoring', 'Near Refactoring', lambda nu, limit: (0, 0, nu, nu)),
    ('Near Generalization', 'Near Generalization', lambda nu, limit: (0, nu, nu, limit - nu)),
    ('Near Specialization', 'Near Specialization', lambda nu, limit: (nu, 0, limit - nu, nu)),
    ('Arbitrary Edit', 'Truly Arbitrary', lambda nu, limit: (nu, nu, limit - nu, limit - nu)),
]

fig, ax = plt.subplots(1, 1, figsize=(4.9, 4.45))

# Fill the large, readable regions induced by the largest threshold in the table.
for label, color_key, rect_func in _NEAR_CLASS_REGIONS:
    x, y, width, height = rect_func(_NEAR_MAX_THRESHOLD, _NEAR_AXIS_MAX)
    ax.add_patch(Rectangle(
        (x, y),
        width,
        height,
        facecolor=_NEAR_CLASS_COLORS[color_key],
        edgecolor='none',
        linewidth=0,
        alpha=1.0,
    ))

# Draw threshold boundaries as neutral guide lines; colors are reserved for classes.
for nu in _NEAR_CLASS_THRESHOLDS:
    ax.axvline(nu, color=COLOR['black'], linestyle='--', linewidth=0.9, alpha=0.7)
    ax.axhline(nu, color=COLOR['black'], linestyle='--', linewidth=0.9, alpha=0.7)

# Emphasize the zero axes without coloring the plot frame.
ax.axvline(0, color=COLOR['blue'], linewidth=4.2, zorder=4)
ax.axhline(0, color=COLOR['vermillion'], linewidth=4.2, zorder=4)

# Label only the large regions. The smaller nested rectangles near the origin stay unlabeled.
_NEAR_REGION_LABELS = [
    ('Near\nRefactoring', _NEAR_MAX_THRESHOLD * 0.55, _NEAR_MAX_THRESHOLD / 2),
    ('Near\nGeneralization', _NEAR_MAX_THRESHOLD * 0.55, (_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2),
    ('Near\nSpecialization', (_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2, _NEAR_MAX_THRESHOLD / 2),
    ('Arbitrary\nEdit', (_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2, (_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2),
]
for text, x, y in _NEAR_REGION_LABELS:
    ax.text(x, y, text, ha='center', va='center', fontsize=11, color=COLOR['black'])

# True refactoring is the exact origin: no added and no removed configurations.
ax.scatter(
    [0],
    [0],
    s=130,
    marker='o',
    facecolor=_NEAR_CLASS_COLORS['Refactoring'],
    edgecolor=COLOR['black'],
    linewidth=1.2,
    zorder=5,
)
_refactoring_leader_start = _NEAR_AXIS_MAX * 0.018
_refactoring_leader_end = _NEAR_AXIS_MAX * 0.034
ax.plot(
    [_refactoring_leader_start, _refactoring_leader_end],
    [_refactoring_leader_start, _refactoring_leader_end],
    color=COLOR['black'],
    linewidth=0.8,
    zorder=6,
)
ax.annotate(
    'Refactoring',
    xy=(0, 0),
    xytext=(9, 9),
    textcoords='offset points',
    ha='left',
    va='bottom',
    fontsize=11,
    color=COLOR['black'],
)
ax.annotate(
    'Generalization',
    xy=(0, (_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2),
    xytext=(9, 0),
    textcoords='offset points',
    ha='left',
    va='center',
    fontsize=11,
    color=COLOR['black'],
    rotation=-90,
    arrowprops=dict(arrowstyle='-', color=COLOR['black'], linewidth=1.1, shrinkA=-18, shrinkB=0),
)
ax.annotate(
    'Specialization',
    xy=((_NEAR_AXIS_MAX + _NEAR_MAX_THRESHOLD) / 2, 0),
    xytext=(0, 9),
    textcoords='offset points',
    ha='center',
    va='bottom',
    fontsize=11,
    color=COLOR['black'],
    arrowprops=dict(arrowstyle='-', color=COLOR['black'], linewidth=1.1, shrinkA=-18, shrinkB=0),
)


ax.set_xlim(0, _NEAR_AXIS_MAX)
ax.set_ylim(0, _NEAR_AXIS_MAX)
ax.set_aspect('equal', adjustable='box')
ax.set_xlabel('Removed Configurations (%)', fontsize=11)
ax.set_ylabel('Added Configurations (%)', fontsize=11)
# Small arrowheads indicate that both axes continue beyond the focused 0-10% window.
ax.annotate(
    '',
    xy=(1.035, 0),
    xytext=(1.0, 0),
    xycoords='axes fraction',
    textcoords='axes fraction',
    arrowprops=dict(arrowstyle='-|>', color=COLOR['black'], linewidth=0.9, mutation_scale=9),
    annotation_clip=False,
)
ax.annotate(
    '',
    xy=(0, 1.035),
    xytext=(0, 1.0),
    xycoords='axes fraction',
    textcoords='axes fraction',
    arrowprops=dict(arrowstyle='-|>', color=COLOR['black'], linewidth=0.9, mutation_scale=9),
    annotation_clip=False,
)
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=9)
_near_ticks = [0, 0.001, 0.01, 0.025, 0.05, 0.075, 0.10]
ax.xaxis.set_major_locator(ticker.FixedLocator(_near_ticks))
ax.yaxis.set_major_locator(ticker.FixedLocator(_near_ticks))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v * 100:g}'))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v * 100:g}'))

# Separate the first two tick labels on both axes, which otherwise sit very close together.
fig.canvas.draw()
for label in ax.get_xticklabels():
    if label.get_text() == '0.1':
        label.set_transform(label.get_transform() + transforms.ScaledTranslation(3 / 72, 0, fig.dpi_scale_trans))
    elif label.get_text() == '0':
        label.set_transform(label.get_transform() + transforms.ScaledTranslation(-5 / 72, 0, fig.dpi_scale_trans))
for label in ax.get_yticklabels():
    if label.get_text() == '0.1':
        label.set_transform(label.get_transform() + transforms.ScaledTranslation(0, 3 / 72, fig.dpi_scale_trans))
    elif label.get_text() == '0':
        label.set_transform(label.get_transform() + transforms.ScaledTranslation(0, -3 / 72, fig.dpi_scale_trans))

fig.tight_layout()
fig.savefig(paper_image_dir / 'near-classification-thresholds.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
_corr
# Out:
#        added_constraints  added_solutions added_solutions_count  \
# 0                  775.0         0.999423                744690
# 1                  775.0              NaN                     1
# 2                  775.0              NaN                     1
# 3                  775.0         0.047354                    17
# 4                  775.0         0.047354                    17
# ...                  ...              ...                   ...
# 11080                4.0              NaN                   NaN
# 11081                3.0              NaN                   NaN
# 11082                2.0              NaN                   NaN
# 11083                3.0              NaN                   NaN
# 11084                6.0              NaN                   NaN
#
#        added_solutions_count_duration  added_vars classification  \
# 0                        3.735751e+08       183.0  ArbitraryEdit
# ...

# %% [markdown]
# ## Source agreement and quantification differences

# %%
import re as _re

# This table asks a different question than the classification-distribution plot above:
# not how often each class occurs, but whether the two KConfig extractors lead to the same
# qualitative and quantitative differencing result. XML benchmark systems are therefore
# excluded because there is no KClause/KConfigReader pair to compare.
#
# Row granularity: one subject system.
# Pair granularity inside each row: one collapsed (system, semantics, version-pair) observed
# by both KClause and KConfigReader. Both closed and projected semantics are retained, so n
# counts paired semantic/version-pair observations, not only raw version pairs.
def _src_extract_extractor(formula):
    parts = str(formula).split('/')
    if parts[0].startswith('extract-kconfig-models-with-'):
        return parts[0].replace('extract-kconfig-models-with-', '')
    return 'xml'


def _src_strip_extractor(formula):
    # Remove only the extractor directory so KClause and KConfigReader paths become joinable
    # while preserving the system/version filename structure.
    parts = str(formula).split('/')
    return '/'.join(parts[1:]) if parts[0].startswith('extract-kconfig-models-with-') else str(formula)


# Use the same analysis universe as the surrounding classification summaries: release-level
# systems only, and no projected-count-with-negation rows because that configuration is not an
# independent algorithm setting in the experiment output.
_src = df[~df['system'].isin(['busybox-commits', 'busybox-yearly'])].copy()
_src = _src[~((_src['method'] == 'projected-count') & (_src['negate'].astype(str) == 'True'))].copy()
_src['extractor'] = _src['left_formula'].apply(_src_extract_extractor)
_src = _src[_src['extractor'].isin(['kclause', 'kconfigreader'])].copy()
_src['diff_kind'] = _src['left_diff_kind'].astype(str)
# The join key deliberately ignores the extractor but keeps the differencing semantics. This
# prevents comparing closed with projected results, while pairing the same version transition
# across the two KConfig extraction frontends.
_src['join_pair'] = (
    _src['left_formula'].apply(_src_strip_extractor) +
    ' -> ' +
    _src['right_formula'].apply(_src_strip_extractor)
)

# Collapse solver/method/negation repetitions to one representative result per extractor and
# semantic/version-pair. Rows with solution fractions are preferred because the quantification
# comparison needs removed/common/added values; if none are available, a classified row is still
# useful for the qualitative agreement column.
_src['_collapse_priority'] = (
    _src['removed_solutions'].notna().astype(int) * 2 +
    _src['classification'].notna().astype(int)
)
_src = (
    _src
    .sort_values('_collapse_priority', ascending=False)
    .drop_duplicates(subset=['system', 'extractor', 'diff_kind', 'join_pair'])
    .copy()
)

# Build a wide paired dataframe with one KClause result and one KConfigReader result per row.
# The inner merge keeps only transitions observed for both extractors; n is derived from this
# paired dataframe, so all reported percentages/differences share the same comparison basis.
_pair_cols = [
    'system', 'diff_kind', 'join_pair', 'classification',
    'removed_solutions', 'common_solutions', 'added_solutions',
]
_kc = _src[_src['extractor'] == 'kclause'][_pair_cols].rename(columns={
    'classification': 'classification_kc',
    'removed_solutions': 'removed_kc',
    'common_solutions': 'common_kc',
    'added_solutions': 'added_kc',
})
_kcr = _src[_src['extractor'] == 'kconfigreader'][_pair_cols].rename(columns={
    'classification': 'classification_kcr',
    'removed_solutions': 'removed_kcr',
    'common_solutions': 'common_kcr',
    'added_solutions': 'added_kcr',
})
_pairs = _kc.merge(_kcr, on=['system', 'diff_kind', 'join_pair'], how='inner')

# Formatting helpers for the LaTeX output. \cap is shown as a rounded percentage, while
# quantification deltas keep one decimal place because they are percentage-point differences.
def _fmt_pct(value):
    return '--' if pd.isna(value) else f'{value:.1f}'


def _fmt_delta(value):
    return '--' if pd.isna(value) else f'{value:.1f}'


_rows = []
for system, group in _pairs.groupby('system', sort=True):
    # n: number of paired extractor observations for this system after collapsing configurations.
    n = len(group)
    # \cap: qualitative agreement between extractors, i.e., the share of paired observations
    # whose classification labels are identical. Missing classifications are ignored here rather
    # than counted as disagreements.
    comparable_classifications = group.dropna(subset=['classification_kc', 'classification_kcr'])
    cap = (
        (comparable_classifications['classification_kc'] == comparable_classifications['classification_kcr']).mean() * 100
        if len(comparable_classifications) else np.nan
    )

    row = {
        'system': system,
        'n': n,
        'cap': cap,
    }
    # Quantification agreement is measured independently for the three solution fractions.
    # Values in df are fractions in [0, 1], so multiplying by 100 yields absolute percentage-point
    # differences. The table reports the median and IQR; the companion box plot shows the full
    # distribution including outliers.
    for label, kc_col, kcr_col in [
        ('removed', 'removed_kc', 'removed_kcr'),
        ('common', 'common_kc', 'common_kcr'),
        ('added', 'added_kc', 'added_kcr'),
    ]:
        diff = (group[kc_col] - group[kcr_col]).abs().dropna() * 100
        if len(diff):
            q1 = diff.quantile(0.25)
            q3 = diff.quantile(0.75)
            row[f'{label}_med'] = diff.median()
            row[f'{label}_iqr'] = q3 - q1
        else:
            row[f'{label}_med'] = np.nan
            row[f'{label}_iqr'] = np.nan
    _rows.append(row)

_summary = pd.DataFrame(_rows)
# Keep the same subject-system order used by the nearby classification figures/tables.
_system_order = [
    'axtls', 'buildroot', 'busybox', 'embtoolkit', 'freetz-ng', 'l4re', 'linux',
    'toybox', 'uclibc', 'uclibc-ng',
]
_summary['system'] = pd.Categorical(_summary['system'], categories=_system_order, ordered=True)
_summary = _summary.sort_values('system').reset_index(drop=True)

# Emit LaTeX directly so the notebook output can be pasted into the paper. The grouped header
# separates the qualitative classification agreement (\cap) from the quantitative solution-share
# comparisons for removed/common/added solutions.
lines = []
lines.append(r'\begin{table}[htbp]')
lines.append(r'\centering\small')
lines.append(
    r'\caption{Agreement between KClause and KConfigReader on consecutive version pairs. '
    r'$\cap$ reports classification agreement. Removed/common/added columns report median and IQR '
    r'of the absolute percentage-point differences in the corresponding quantified solution fractions.}'
)
lines.append(r'\label{tab:source-quantification-differences}')
lines.append(r'\begin{tabular}{lrrrrrrrr}')
lines.append(r'\toprule')
lines.append(r'& & & \multicolumn{2}{c}{Removed} & \multicolumn{2}{c}{Common} & \multicolumn{2}{c}{Added} \\')
lines.append(r'\cmidrule(lr){4-5}\cmidrule(lr){6-7}\cmidrule(lr){8-9}')
lines.append(r'System & $n$ & $\cap$ & med & IQR & med & IQR & med & IQR \\')
lines.append(r'\midrule')

for row in _summary.itertuples(index=False):
    system = str(row.system).replace('_', r'\_')
    lines.append(
        f'{system} & {int(row.n)} & {_fmt_pct(row.cap)}'
        f' & {_fmt_delta(row.removed_med)} & {_fmt_delta(row.removed_iqr)}'
        f' & {_fmt_delta(row.common_med)} & {_fmt_delta(row.common_iqr)}'
        f' & {_fmt_delta(row.added_med)} & {_fmt_delta(row.added_iqr)}'
        r' \\'
    )

lines.append(r'\bottomrule')
lines.append(r'\end{tabular}')
lines.append(r'\end{table}')

_source_quantification_table = '\n'.join(lines)
print(_source_quantification_table)
# Out:
# \begin{table}[htbp]
# \centering\small
# \caption{Agreement between KClause and KConfigReader on consecutive version pairs. $\cap$ reports classification agreement. Removed/common/added columns report median and IQR of the absolute percentage-point differences in the corresponding quantified solution fractions.}
# \label{tab:source-quantification-differences}
# \begin{tabular}{lrrrrrrrr}
# \toprule
# & & & \multicolumn{2}{c}{Removed} & \multicolumn{2}{c}{Common} & \multicolumn{2}{c}{Added} \\
# \cmidrule(lr){4-5}\cmidrule(lr){6-7}\cmidrule(lr){8-9}
# System & $n$ & $\cap$ & med & IQR & med & IQR & med & IQR \\
# \midrule
# axtls & 60 & 96.7 & 0.0 & 0.0 & 0.0 & 0.2 & 0.0 & 0.0 \\
# buildroot & 34 & 100.0 & 1.1 & 12.2 & 0.0 & 1.5 & 0.1 & 16.3 \\
# busybox & 230 & 89.1 & 0.0 & 0.1 & 0.0 & 0.1 & 0.0 & 0.1 \\
# embtoolkit & 20 & 95.0 & 6.8 & 31.6 & 0.0 & 15.6 & 8.5 & 39.1 \\
# freetz-ng & 22 & 94.1 & 9.9 & 24.6 & 0.0 & 0.1 & 9.9 & 21.8 \\
# ...

# %%
# Box plot for the same KClause/KConfigReader quantification differences summarized above.
# Each point behind a box is one paired semantic/version-pair observation. The y-value is the
# absolute percentage-point difference between extractors for one solution fraction.
_quant_diff_rows = []
for label, kc_col, kcr_col in [
    ('Removed', 'removed_kc', 'removed_kcr'),
    ('Common', 'common_kc', 'common_kcr'),
    ('Added', 'added_kc', 'added_kcr'),
]:
    diff = _pairs[['system', kc_col, kcr_col]].copy()
    diff['quantity'] = label
    diff['difference_pp'] = (diff[kc_col] - diff[kcr_col]).abs() * 100
    _quant_diff_rows.append(diff[['system', 'quantity', 'difference_pp']])

_quant_diff_plot = pd.concat(_quant_diff_rows, ignore_index=True).dropna(subset=['difference_pp'])
_quant_diff_plot['system'] = pd.Categorical(_quant_diff_plot['system'], categories=_system_order, ordered=True)
_quant_diff_plot = _quant_diff_plot.sort_values(['system', 'quantity']).copy()

_quantities = ['Removed', 'Common', 'Added']
fig, axes = plt.subplots(1, len(_quantities), figsize=(11, 3.2), sharey=True)

for ax, quantity in zip(axes, _quantities):
    data = _quant_diff_plot[_quant_diff_plot['quantity'] == quantity]
    box_data = [
        data.loc[data['system'] == system, 'difference_pp'].to_numpy()
        for system in _system_order
        if not data.loc[data['system'] == system].empty
    ]
    labels = [
        system
        for system in _system_order
        if not data.loc[data['system'] == system].empty
    ]

    ax.boxplot(
        box_data,
        tick_labels=labels,
        patch_artist=True,
        showfliers=True,
        flierprops={
            'marker': 'o',
            'markerfacecolor': COLOR['gray'],
            'markeredgecolor': COLOR['gray'],
            'markersize': 2.5,
            'alpha': 0.45,
        },
        medianprops={'color': 'black', 'linewidth': 1.2},
        boxprops={'facecolor': COLOR['sky_blue'], 'edgecolor': COLOR['gray'], 'linewidth': 0.9},
        whiskerprops={'color': COLOR['gray'], 'linewidth': 0.9},
        capprops={'color': COLOR['gray'], 'linewidth': 0.9},
    )
    ax.set_title(quantity, fontsize=14)
    ax.tick_params(axis='x', labelrotation=45, labelsize=9)
    ax.tick_params(axis='y', labelsize=11)
    ax.grid(axis='y', linestyle='--', alpha=0.35)

axes[0].set_ylabel('Absolute difference (percentage points)', fontsize=12)
fig.tight_layout(w_pad=0.7)
fig.savefig(paper_image_dir / 'source-quantification-differences-boxplot.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Solution composition timeline

# %%
import re as _re
import matplotlib.lines as _mlines
import matplotlib.dates as _mdates

# ── helpers ───────────────────────────────────────────────────────────────────
def _tl_extract_revision(f):
    fn = f.split('/')[-1]
    m = _re.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', fn)
    if m: return m.group(1)
    m = _re.search(r'-(\d{4}-\d{2}-\d{2})\.xml$', fn)
    if m: return m.group(1)
    m = _re.search(r'-(\d+_\d+)\.xml$', fn)
    if m: return m.group(1)
    return None

def _tl_extract_extractor(formula):
    p = formula.split('/')[0]
    return p.replace('extract-kconfig-models-with-', '') if p.startswith('extract-kconfig-models-with-') else 'xml'

def _tl_extract_xml_date(formula):
    fn = formula.split('/')[-1]
    m = _re.search(r'(\d{4}-\d{2}-\d{2})\.xml$', fn)
    return m.group(1) if m else None

# ── build timeline dataframe ──────────────────────────────────────────────────
# Goal of this figure: show the chronological sequence of quantified Projection
# differences for each subject system.  Each horizontal segment represents one
# consecutive model pair.  Segment color encodes the refined classification, and
# segment width mirrors the visual emphasis used in the classification figures.
#
# The raw experiment table contains many algorithm configurations per model pair.
# This cell first normalizes the source/extractor and revision information, then
# collapses those repeated configurations to one representative row per
# system/extractor/semantics/version-pair before plotting.
_tl = df.copy()
_tl['extractor']         = _tl['left_formula'].apply(_tl_extract_extractor)
_tl['_system_for_stats'] = _tl['system'].str.replace(r'-(commits|yearly)$', '', regex=True)
_tl['_left_rev']  = _tl['left_formula'].apply(_tl_extract_revision)
_tl['_right_rev'] = _tl['right_formula'].apply(_tl_extract_revision)
_tl['_left_xml']  = _tl['left_formula'].apply(_tl_extract_xml_date)
_tl['_right_xml'] = _tl['right_formula'].apply(_tl_extract_xml_date)
_tl['diff_kind']  = _tl['left_diff_kind'].astype(str)

# solution composition columns are already fractions from _load_csv

# projected-count with negate=True is not an independent algorithm variant in the
# experiment output, so exclude it before deduplicating representative rows.
_tl = _tl[~((_tl['method'] == 'projected-count') & (_tl['negate'].astype(str) == 'True'))]

# Prefer rows with quantified solution composition; if none exists for a pair,
# keep a classified row so the gap/stop marker logic can still see the pair.
_tl_dedup = (
    _tl.assign(
        _pri=(
            _tl['removed_solutions'].notna().astype(int) * 2 +
            _tl['classification'].notna().astype(int)
        )
    )
    .sort_values('_pri', ascending=False)
    .drop_duplicates(subset=['system', 'extractor', 'diff_kind', 'left_formula', 'right_formula'])
    .copy()
)

# ── join dates ────────────────────────────────────────────────────────────────
# KConfig systems use read_statistics metadata to map revision ids to committer
# dates. XML benchmark systems encode dates in their filenames, so those are used
# as a fallback whenever no statistics date is available.
_st = _stats_by_exp['main'][['system', 'revision', 'committer_date_readable']].drop_duplicates(['system', 'revision']).rename(
    columns={'system': '_system_for_stats'}
)

_tl_dedup = _tl_dedup.merge(
    _st.rename(columns={'revision': '_left_rev', 'committer_date_readable': '_left_date'}),
    on=['_system_for_stats', '_left_rev'], how='left'
)
_tl_dedup = _tl_dedup.merge(
    _st.rename(columns={'revision': '_right_rev', 'committer_date_readable': '_right_date'}),
    on=['_system_for_stats', '_right_rev'], how='left'
)

for _side in ['left', 'right']:
    _mask = _tl_dedup[f'_{_side}_date'].isna() & _tl_dedup[f'_{_side}_xml'].notna()
    _tl_dedup.loc[_mask, f'_{_side}_date'] = _tl_dedup.loc[_mask, f'_{_side}_xml']

_tl_dedup['left_time']  = pd.to_datetime(_tl_dedup['_left_date'],  errors='coerce')
_tl_dedup['right_time'] = pd.to_datetime(_tl_dedup['_right_date'], errors='coerce')
_tl_ok = _tl_dedup[_tl_dedup['left_time'].notna() & _tl_dedup['right_time'].notna()].copy()
_tl_ok['has_comp'] = _tl_ok['removed_solutions'].notna()
_tl_ok['has_class'] = _tl_ok['classification'].notna()
# Plot only the paper-facing Projection timeline. KConfigReader is excluded to
# keep one KConfig source row per system; the companion source-comparison table
# covers KClause/KConfigReader agreement separately.
_tl_plot = _tl_ok[(_tl_ok['extractor'] != 'kconfigreader') & (_tl_ok['diff_kind'] == 'slice')].copy()

print(f"{len(_tl_plot)} projection timeline rows  ({(~_tl_plot['has_comp']).sum()} without composition; KConfigReader excluded)")

# ── styling ───────────────────────────────────────────────────────────────────
# Reuse the detailed classification language from the per-system classification breakdown:
# arbitrary edits are split into near-refactoring, near-generalization, near-specialization,
# and truly arbitrary edits using the quantified solution composition when available.
try:
    _TL_NEAR_SHARE_THRESHOLD = _NEAR_SHARE_THRESHOLD
except NameError:
    _TL_NEAR_SHARE_THRESHOLD = 0.01

try:
    _TL_DETAILED_ORDER = _CLF_DETAILED_ORDER
    _TL_DETAILED_COLORS = _CLF_DETAILED_COLORS
except NameError:
    _TL_DETAILED_ORDER = [
        'Refactoring',
        'Near Refactoring',
        'Generalization',
        'Near Generalization',
        'Specialization',
        'Near Specialization',
        'Truly Arbitrary',
    ]
    _TL_DETAILED_COLORS = {
        'Refactoring':         COLOR['bluish_green'],
        'Near Refactoring':    '#8FD6B6',
        'Generalization':      COLOR['blue'],
        'Specialization':      COLOR['vermillion'],
        'Near Generalization': COLOR['sky_blue'],
        'Near Specialization': COLOR['orange'],
        'Truly Arbitrary':     COLOR['gray'],
    }

_TL_LINE_WIDTH = {
    'Refactoring': 5.0,
    'Generalization': 5.0,
    'Specialization': 5.0,
    'Near Refactoring': 3,
    'Near Generalization': 3,
    'Near Specialization': 3,
    'Truly Arbitrary': 1.5,
}

def _tl_detailed_class(row):
    # Convert the coarse classification plus solution shares into the same detailed
    # categories used by the classification distribution. Arbitrary edits with at
    # most _TL_NEAR_SHARE_THRESHOLD added/removed solutions become near classes.
    if not row['has_comp']:
        return 'No result'
    clf = row['classification']
    if pd.notna(clf) and clf != 'ArbitraryEdit':
        return clf
    r, c, a = row['removed_solutions'], row['common_solutions'], row['added_solutions']
    if any(pd.isna(v) for v in [r, c, a]):
        return 'Truly Arbitrary'
    if a <= _TL_NEAR_SHARE_THRESHOLD and r <= _TL_NEAR_SHARE_THRESHOLD:
        return 'Near Refactoring'
    if a <= _TL_NEAR_SHARE_THRESHOLD:
        return 'Near Specialization'
    if r <= _TL_NEAR_SHARE_THRESHOLD:
        return 'Near Generalization'
    return 'Truly Arbitrary'

def _seg_style(row):
    # Quantified rows receive semantic colors. Rows without solution-composition data
    # are skipped but still contribute to the stop-marker check below.
    detailed = _tl_detailed_class(row)
    if detailed == 'No result':
        return None, None, None
    return _TL_DETAILED_COLORS.get(detailed, COLOR['gray']), _TL_LINE_WIDTH.get(detailed, 1.5), 'solid'

# ── system order/labels ───────────────────────────────────────────────────────
# Keep the y-axis order identical to the systems overview table: KConfig systems
# first, then the feature-model benchmark systems after the separator. The raw
# labels are kept compact for the plot; FinancialServices01 is abbreviated.
# uclibc-ng is merged into the uclibc row for this compact timeline so the
# combined row covers the full historical period of both related systems.
_SYS_MERGE = {'uclibc-ng': 'uclibc'}
_SYS_LABEL = {
    'uclibc': 'uclibc(-ng)',
    'FinancialServices01': 'FS01',
}

def _canonical(system):
    return _SYS_MERGE.get(system, system)

_TL_SYSTEM_DISPLAY_ORDER = [
    'axtls',
    'buildroot',
    'busybox',
    'embtoolkit',
    'freetz-ng',
    'l4re',
    'linux',
    'toybox',
    'uclibc',
    'uclibc-ng',
    'FinancialServices01',
    'automotive2',
]
_TL_SYSTEM_ORDER_INDEX = {system: i for i, system in enumerate(_TL_SYSTEM_DISPLAY_ORDER)}
_TL_SYSTEM_DISPLAY_SET = set(_TL_SYSTEM_DISPLAY_ORDER)

def _tl_system_sort_key(system):
    canon = _canonical(system)
    return (_TL_SYSTEM_ORDER_INDEX.get(canon, len(_TL_SYSTEM_ORDER_INDEX)), canon, system)

# ── longest one-sided stability periods ───────────────────────────────────────
# Make the monotonic/refactoring stretches behind the timeline explicit: for each
# displayed system, find three separate longest consecutive runs of release pairs:
# (1) generalization-like periods with no removed solutions, (2) specialization-like
# periods with no added solutions, and (3) refactoring-like periods with neither
# removed nor added solutions. Missing quantification and a non-zero exact solution
# count both break a run. uclibc-ng
# is considered under the displayed uclibc(-ng) row, but runs are computed within
# the original raw system/source first so we do not accidentally bridge the gap
# between the historical uclibc and uclibc-ng series.
def _longest_solution_stability_periods(timeline):
    _work = timeline[timeline['system'].isin(_TL_SYSTEM_DISPLAY_SET)].copy()
    _work['_display_system'] = _work['system'].apply(_canonical)
    _work['_source'] = _work['extractor'].map({'kclause': 'KClause', 'xml': 'XML'}).fillna(_work['extractor'])

    def _exact_zero(column):
        return column.notna() & column.astype(str).str.fullmatch(r'0+(?:\.0+)?')

    _conditions = [
        ('generalization', lambda _df: _exact_zero(_df['removed_solutions_count'])),
        ('specialization', lambda _df: _exact_zero(_df['added_solutions_count'])),
        ('refactoring', lambda _df: _exact_zero(_df['removed_solutions_count']) & _exact_zero(_df['added_solutions_count'])),
    ]

    def _release_id(row, revision_col, xml_col):
        return row[revision_col] if pd.notna(row[revision_col]) else row[xml_col]

    _runs = []
    for _period_order, (_period, _condition) in enumerate(_conditions):
        _work['_zero_condition'] = _work['has_comp'] & _condition(_work)
        for (_display_system, _raw_system, _source), _sdf in _work.groupby(['_display_system', 'system', '_source']):
            _sdf = _sdf.sort_values(['left_time', 'right_time']).reset_index(drop=True)
            _run_id = _sdf['_zero_condition'].ne(_sdf['_zero_condition'].shift(fill_value=False)).cumsum()
            for _, _run in _sdf[_sdf['_zero_condition']].groupby(_run_id):
                _first = _run.iloc[0]
                _last = _run.iloc[-1]
                _start = _first['left_time']
                _end = _last['right_time']
                _runs.append({
                    'system': _SYS_LABEL.get(_display_system, _display_system),
                    '_display_system': _display_system,
                    '_period_order': _period_order,
                    'period': _period,
                    'raw_system': _raw_system,
                    'source': _source,
                    'start': _start.date(),
                    'end': _end.date(),
                    'duration_days': (_end - _start).days,
                    'duration_years': round((_end - _start).days / 365.25, 2),
                    'release_pairs': len(_run),
                    'start_release': _release_id(_first, '_left_rev', '_left_xml'),
                    'end_release': _release_id(_last, '_right_rev', '_right_xml'),
                })

    _present = sorted({_canonical(s) for s in _work['system'].unique()}, key=_tl_system_sort_key)
    _base = pd.DataFrame([
        {
            '_display_system': _system,
            '_system_order': _system_order,
            '_period_order': _period_order,
            'system': _SYS_LABEL.get(_system, _system),
            'period': _period,
        }
        for _system_order, _system in enumerate(_present)
        for _period_order, (_period, _) in enumerate(_conditions)
    ])
    if not _runs:
        return _base.assign(duration_days=0, duration_years=0.0, release_pairs=0).drop(columns=['_display_system', '_system_order', '_period_order'])

    _best = (
        pd.DataFrame(_runs)
        .sort_values(['_display_system', '_period_order', 'duration_days', 'release_pairs'], ascending=[True, True, False, False])
        .drop_duplicates(['_display_system', '_period_order'])
    )
    _result = (
        _base.merge(_best.drop(columns=['system', 'period']), on=['_display_system', '_period_order'], how='left')
        .sort_values(['_system_order', '_period_order'])
        .drop(columns=['_display_system', '_system_order', '_period_order'])
        .fillna({'duration_days': 0, 'duration_years': 0.0, 'release_pairs': 0})
    )
    _result['has_period'] = _result['raw_system'].notna()
    _result[['raw_system', 'source', 'start', 'end', 'start_release', 'end_release']] = _result[
        ['raw_system', 'source', 'start', 'end', 'start_release', 'end_release']
    ].fillna('none')
    _result['duration_days'] = _result['duration_days'].astype('Int64')
    _result['release_pairs'] = _result['release_pairs'].astype('Int64')
    _result = _result[[
        'system', 'period', 'has_period', 'raw_system', 'source', 'start', 'end',
        'duration_days', 'duration_years', 'release_pairs', 'start_release', 'end_release',
    ]]
    return _result

_solution_stability_periods = _longest_solution_stability_periods(_tl_plot)
display(_solution_stability_periods)

# Also expose the three busiest change years per displayed system. A release-pair
# change is assigned to the year of its right-hand release, i.e., the point where
# the change appears on the timeline. Busiest is measured by yearly accumulated
# solution churn: added solution share plus removed solution share.
def _top_busiest_solution_change_years(timeline, top_n=3):
    _work = timeline[timeline['system'].isin(_TL_SYSTEM_DISPLAY_SET) & timeline['has_comp']].copy()
    _work['_display_system'] = _work['system'].apply(_canonical)
    _work['_year'] = _work['right_time'].dt.year
    _work['_solution_churn'] = _work['removed_solutions'].fillna(0) + _work['added_solutions'].fillna(0)
    _work['_changed_pair'] = _work['_solution_churn'] > 0

    _yearly = (
        _work.groupby(['_display_system', '_year'], as_index=False)
        .agg(
            total_solution_churn=('_solution_churn', 'sum'),
            max_pair_churn=('_solution_churn', 'max'),
            changed_pairs=('_changed_pair', 'sum'),
            release_pairs=('_solution_churn', 'size'),
        )
    )
    _yearly = _yearly[_yearly['total_solution_churn'] > 0].copy()
    if _yearly.empty:
        return pd.DataFrame(columns=[
            'system', 'rank', 'year', 'total_solution_churn',
            'max_pair_churn', 'changed_pairs', 'release_pairs',
        ])

    _yearly['rank'] = (
        _yearly.sort_values(['_display_system', 'total_solution_churn', 'changed_pairs', '_year'], ascending=[True, False, False, True])
        .groupby('_display_system')
        .cumcount() + 1
    )
    _yearly = _yearly[_yearly['rank'] <= top_n].copy()
    _yearly['system'] = _yearly['_display_system'].map(lambda s: _SYS_LABEL.get(s, s))
    _yearly['total_solution_churn'] = _yearly['total_solution_churn'].round(3)
    _yearly['max_pair_churn'] = _yearly['max_pair_churn'].round(3)
    _yearly['changed_pairs'] = _yearly['changed_pairs'].astype('Int64')
    _yearly['release_pairs'] = _yearly['release_pairs'].astype('Int64')

    _system_order = {}
    for _i, _system in enumerate(_TL_SYSTEM_DISPLAY_ORDER):
        _system_order.setdefault(_canonical(_system), _i)
    _yearly['_order'] = _yearly['_display_system'].map(_system_order).fillna(len(_system_order))
    return (
        _yearly.sort_values(['_order', 'rank'])
        .rename(columns={'_year': 'year'})
        [['system', 'rank', 'year', 'total_solution_churn', 'max_pair_churn', 'changed_pairs', 'release_pairs']]
    )

_busiest_solution_change_years = _top_busiest_solution_change_years(_tl_plot)
display(_busiest_solution_change_years)

# First/last release bounds reuse the same date sources as the system overview
# table. They are retained here for consistency with earlier timeline variants and
# for possible future annotations, even though this compact figure does not draw
# release-bound markers explicitly.
_release_bounds_parts = []
for _system in sorted(_tl_plot['system'].unique()):
    _exp = 'commits' if _system.endswith('-commits') else 'yearly' if _system.endswith('-yearly') else 'main'
    _base = _re.sub(r'-(commits|yearly)$', '', _system)
    _stats_sub = _stats_by_exp[_exp][_stats_by_exp[_exp]['system'] == _base]
    if _stats_sub.empty:
        _forms = pd.concat([
            _tl_plot.loc[_tl_plot['system'] == _system, 'left_formula'],
            _tl_plot.loc[_tl_plot['system'] == _system, 'right_formula'],
        ])
        _dates = pd.to_datetime(_forms.apply(_tl_extract_xml_date), errors='coerce').dropna()
    else:
        _dates = pd.to_datetime(_stats_sub['committer_date_readable'], errors='coerce').dropna()
    if not _dates.empty:
        _release_bounds_parts.append({
            'system': _canonical(_system),
            'first_release': _dates.min(),
            'last_release': _dates.max(),
        })

_release_bounds = {}
if _release_bounds_parts:
    _release_bounds_df = pd.DataFrame(_release_bounds_parts)
    for _system, _bounds in _release_bounds_df.groupby('system'):
        _release_bounds[_system] = (_bounds['first_release'].min(), _bounds['last_release'].max())

# ── y-axis layout ─────────────────────────────────────────────────────────────
# Build one y-position per displayed source row. KClause rows use the overview
# order above; XML benchmark rows follow directly after the KConfig systems. The timeline is
# Projection-only, so there is no Closed/Projection vertical offset anymore.
_kfg_sys_raw = sorted(set(_tl_plot.loc[_tl_plot['extractor'] != 'xml', 'system']) & _TL_SYSTEM_DISPLAY_SET, key=_tl_system_sort_key)
_xml_sys     = sorted(set(_tl_plot.loc[_tl_plot['extractor'] == 'xml', 'system']) & _TL_SYSTEM_DISPLAY_SET, key=_tl_system_sort_key)
_kfg_sys     = [s for s in _kfg_sys_raw if s not in _SYS_MERGE]

_PAIR_GAP  = 0.65
_SYS_STEP  = 1.00
_XML_EXTRA = 0.0

_y_map2     = {}
_ytick_pos  = []
_ytick_lbl  = []
_band_spans = []

y = 0.0
for i, s in enumerate(_kfg_sys):
    y_kc = y
    _y_map2[(s, 'kclause')] = y_kc
    _ytick_pos.append(y_kc)
    _ytick_lbl.append(_SYS_LABEL.get(s, s))
    _band_spans.append((y_kc - 0.34, y_kc + 0.34))
    y += _SYS_STEP

y += _XML_EXTRA
# Feature-Model Benchmark rows: XML source only, following the overview order.
for s in _xml_sys:
    _y_map2[(s, 'xml')] = y
    _ytick_pos.append(y)
    _ytick_lbl.append(_SYS_LABEL.get(s, s))
    y += _SYS_STEP / 2

_y_total = y - _SYS_STEP / 2 + 0.5

_DIFF_OFFSET = {'slice': 0.0}
_diff_kinds  = ['slice']
# Small visual gap between adjacent release segments. This prevents two consecutive
# segments with the same classification from visually merging into one long bar.
_SEG_GAP_FRACTION = 0.025
_SEG_GAP_MAX_DAYS = 12
_SEG_GAP_MIN_VISIBLE_DAYS = 7

# ── single combined panel ─────────────────────────────────────────────────────
# The figure is deliberately narrow and tall: time runs left-to-right, while the
# main comparison is the vertical stack of systems. The legend is kept below the
# axes so it does not widen the exported PDF.
_per_row_h = 0.195 * len(_ytick_pos) + 0.95

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, ax = plt.subplots(1, 1, figsize=(5.4, _per_row_h))

    for bi, (ylo, yhi) in enumerate(_band_spans):
        ax.axhspan(ylo, yhi, color=COLOR['gray'], alpha=0.06 if bi % 2 == 0 else 0.0, zorder=0)

    for diff_kind in _diff_kinds:
        # One colored segment per consecutive version pair. Zero-duration pairs are
        # expanded to a small 30-day segment so they remain visible on the time axis.
        sub    = _tl_plot[_tl_plot['diff_kind'] == diff_kind]
        offset = _DIFF_OFFSET[diff_kind]

        for _, row in sub.iterrows():
            key = (_canonical(row['system']), row['extractor'])
            if key not in _y_map2:
                continue
            y_pos       = _y_map2[key] + offset
            col, lw, ls = _seg_style(row)
            if col is None:
                # No-result rows correspond to attempted evolution-step analyses that
                # produced no drawable classification/solution composition, typically
                # because all relevant configurations timed out. Keep the step visible
                # as a dotted black interval instead of a colored classification bar.
                col, lw, ls = COLOR['black'], 1.0, ':'
            t0, t1      = row['left_time'], row['right_time']
            if t0 == t1:
                t1 = t0 + pd.Timedelta(days=30)
            seg_days = max((t1 - t0).days, 1)
            gap_days = min(seg_days * _SEG_GAP_FRACTION, _SEG_GAP_MAX_DAYS)
            if seg_days - 2 * gap_days >= _SEG_GAP_MIN_VISIBLE_DAYS:
                t0 = t0 + pd.Timedelta(days=gap_days)
                t1 = t1 - pd.Timedelta(days=gap_days)
            ax.plot([t0, t1], [y_pos, y_pos], color=col, linewidth=lw,
                    linestyle=ls, solid_capstyle='butt')

        # For each source/system series, mark the endpoint of the latest no-result/timeout
        # evolution step with an x. The dotted intervals already show every such step;
        # the marker makes the final timeout position easy to spot.
        sub2 = sub.copy()
        sub2['_sys_canon'] = sub2['system'].apply(_canonical)
        for (sys_canon, extractor), sdf in sub2.groupby(['_sys_canon', 'extractor']):
            key = (sys_canon, extractor)
            if key not in _y_map2:
                continue
            y_pos = _y_map2[key] + offset
            to = sdf[~sdf['has_comp']]
            if to.empty:
                continue
            last_timeout = to['right_time'].max()
            ax.scatter([last_timeout], [y_pos], color=COLOR['black'], marker='x',
                       s=38, linewidths=1.1, zorder=10)

    ax.set_yticks(_ytick_pos)
    ax.set_yticklabels(_ytick_lbl, fontsize=12)
    ax.set_ylim(-0.5, _y_total)
    ax.invert_yaxis()
    ax.set_xlabel('')
    ax.grid(axis='x', linestyle='--', alpha=0.3)
    ax.xaxis.set_major_locator(_mdates.YearLocator(5))
    ax.xaxis.set_major_formatter(_mdates.DateFormatter('%Y'))
    ax.tick_params(axis='x', rotation=0, labelsize=12)

    # ── legend ────────────────────────────────────────────────────────────────────
    # Projection is implicit in the figure. The final-timeout marker remains in the
    # plot, but is omitted from the legend to keep the legend compact.
    _TL_LEGEND_LABELS = {
        'Refactoring': 'Ref',
        'Near Refactoring': 'Near (1%)',
        'Generalization': 'Gen',
        'Near Generalization': 'Near (1%)',
        'Specialization': 'Spec',
        'Near Specialization': 'Near (1%)',
        'Truly Arbitrary': 'Arbitrary Edit',
    }
    _legend_handles = [
        _mlines.Line2D([], [], color=_TL_DETAILED_COLORS[c], lw=_TL_LINE_WIDTH.get(c, 1.5), ls='-', label=_TL_LEGEND_LABELS.get(c, c))
        for c in _TL_DETAILED_ORDER
    ]
    fig.legend(
        _legend_handles,
        [h.get_label() for h in _legend_handles],
        loc='lower center',
        ncol=len(_legend_handles),
        fontsize=8.5,
        frameon=False,
        handlelength=1.0,
        columnspacing=0.75,
        bbox_to_anchor=(0.5, 0.035),
    )

    fig.tight_layout(rect=[0, 0.09, 1, 1])
    fig.savefig(paper_image_dir / 'solution-composition-timeline.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()
# Out:
# 378 projection timeline rows  (18 without composition; KConfigReader excluded)
#          system          period  has_period  raw_system   source       start  \
# 0         axtls  generalization        True       axtls  KClause  2007-12-04
# 1         axtls  specialization        True       axtls  KClause  2006-07-01
# 2         axtls     refactoring        True       axtls  KClause  2014-10-31
# 3     buildroot  generalization       False        none     none        none
# 4     buildroot  specialization       False        none     none        none
# 5     buildroot     refactoring       False        none     none        none
# 6       busybox  generalization        True     busybox  KClause  2012-04-22
# 7       busybox  specialization        True     busybox  KClause  2023-01-03
# 8       busybox     refactoring        True     busybox  KClause  2014-12-24
# 9    embtoolkit  generalization        True  embtoolkit  KClause  2012-12-23
# ...

# %% [markdown]
# ### Projection-only classification breakdown per system
#
# This duplicates the classification breakdown per system for the solution-composition timeline context, but keeps only Projection semantics and excludes KConfigReader. KClause and XML results are aggregated into one horizontal stacked bar per system, and the stack colors/classes follow the same near-classification refinement as the main breakdown.

# %%
# Projection-only duplicate of the classification breakdown per system.
# This keeps the same representative-row rule and detailed class colors as the main
# breakdown, but removes Closed semantics and excludes KConfigReader.

# Keep this cell runnable from the timeline section alone. If the earlier classification
# breakdown cell has already been run, these definitions simply reuse its names.
try:
    _breakdown_source
except NameError:
    def _breakdown_source(formula):
        first = str(formula).split('/')[0]
        if first == 'extract-kconfig-models-with-kconfigreader':
            return 'KConfigReader'
        if first == 'extract-kconfig-models-with-kclause':
            return 'KClause'
        return 'XML'

try:
    _breakdown_strip_source
except NameError:
    def _breakdown_strip_source(formula):
        parts = str(formula).split('/')
        if parts[0].startswith('extract-kconfig-models-with-'):
            return '/'.join(parts[1:])
        return str(formula)

try:
    _NEAR_SHARE_THRESHOLD
except NameError:
    _NEAR_SHARE_THRESHOLD = 0.01

try:
    _CLF_DETAILED_ORDER
    _CLF_DETAILED_COLORS
except NameError:
    _CLF_DETAILED_ORDER = [
        'Refactoring',
        'Near Refactoring',
        'Generalization',
        'Near Generalization',
        'Specialization',
        'Near Specialization',
        'Truly Arbitrary',
    ]
    _CLF_DETAILED_COLORS = {
        'Refactoring':         COLOR['bluish_green'],
        'Near Refactoring':    '#8FD6B6',
        'Generalization':      COLOR['blue'],
        'Specialization':      COLOR['vermillion'],
        'Near Generalization': COLOR['sky_blue'],
        'Near Specialization': COLOR['orange'],
        'Truly Arbitrary':     COLOR['gray'],
    }

try:
    _BREAKDOWN_SYSTEM_LABELS
except NameError:
    _BREAKDOWN_SYSTEM_LABELS = {'FinancialServices01': 'FS01', 'automotive2': 'Auto2'}

try:
    _SYSTEM_DISPLAY_ORDER
except NameError:
    _SYSTEM_DISPLAY_ORDER = [
        'axtls', 'buildroot', 'busybox', 'embtoolkit', 'freetz-ng', 'l4re',
        'linux', 'toybox', 'uclibc', 'uclibc-ng', 'FinancialServices01', 'automotive2',
    ]

try:
    _detailed_clf
except NameError:
    def _detailed_clf(row):
        clf = row['classification']
        if pd.isna(clf):
            return 'Truly Arbitrary'
        if clf != 'ArbitraryEdit':
            return clf
        r = row['removed_solutions']
        c = row['common_solutions']
        a = row['added_solutions']
        if any(pd.isna(v) for v in [r, c, a]):
            return 'Truly Arbitrary'
        if a <= _NEAR_SHARE_THRESHOLD and r <= _NEAR_SHARE_THRESHOLD:
            return 'Near Refactoring'
        if a <= _NEAR_SHARE_THRESHOLD:
            return 'Near Specialization'
        if r <= _NEAR_SHARE_THRESHOLD:
            return 'Near Generalization'
        return 'Truly Arbitrary'

_proj_breakdown = df[
    df['classification'].notna() &
    (~df['system'].isin(['busybox-commits', 'busybox-yearly']))
].copy()
_proj_breakdown['source'] = _proj_breakdown['left_formula'].apply(_breakdown_source)
_proj_breakdown = _proj_breakdown[
    (_proj_breakdown['left_diff_kind'].astype(str) == 'slice') &
    (_proj_breakdown['source'] != 'KConfigReader') &
    (_proj_breakdown['source'].isin(['KClause', 'XML']))
].copy()
_proj_breakdown['left_model'] = _proj_breakdown['left_formula'].apply(_breakdown_strip_source)
_proj_breakdown['right_model'] = _proj_breakdown['right_formula'].apply(_breakdown_strip_source)
_proj_breakdown['diff_kind'] = _proj_breakdown['left_diff_kind'].astype(str)
_proj_breakdown['_has_solution_share'] = _proj_breakdown[
    ['removed_solutions', 'common_solutions', 'added_solutions']
].notna().all(axis=1)
_proj_breakdown['_classification_priority'] = (
    (_proj_breakdown['method'] == 'satisfy').astype(int) * 2 +
    (_proj_breakdown['engine'] == 'kissat').astype(int)
)
_proj_breakdown['_solution_priority'] = _proj_breakdown['_has_solution_share'].astype(int)
_proj_breakdown = (
    _proj_breakdown
    .sort_values(['_solution_priority', '_classification_priority'], ascending=False)
    .drop_duplicates(subset=['system', 'source', 'diff_kind', 'left_model', 'right_model'])
)
_proj_breakdown['_dclf'] = _proj_breakdown.apply(_detailed_clf, axis=1)

# Merge uclibc/uclibc-ng and use the same displayed system rows for both facets.
_PROJ_SYS_MERGE = {'uclibc-ng': 'uclibc'}

def _proj_display_system(system):
    return _PROJ_SYS_MERGE.get(system, system)

_proj_breakdown['_display_system'] = _proj_breakdown['system'].apply(_proj_display_system)
_PROJ_SYSTEM_ORDER_INDEX = {}
for system in _SYSTEM_DISPLAY_ORDER:
    _PROJ_SYSTEM_ORDER_INDEX.setdefault(_proj_display_system(system), len(_PROJ_SYSTEM_ORDER_INDEX))
_present_systems = set(_proj_breakdown['_display_system'].dropna())
_proj_system_order = [
    system for system, _ in sorted(_PROJ_SYSTEM_ORDER_INDEX.items(), key=lambda kv: kv[1])
    if system in _present_systems
]
_proj_system_order += sorted(_present_systems - set(_proj_system_order))
_PROJ_BREAKDOWN_LABELS = {
    **_BREAKDOWN_SYSTEM_LABELS,
    'uclibc': 'uclibc(-ng)',
    'FinancialServices01': 'FS01',
    'automotive2': 'auto2',
}

# Facet 1: ordinary step-count percentages.
_proj_counts = (
    _proj_breakdown
    .groupby(['_display_system', '_dclf'])
    .size()
    .unstack(fill_value=0)
    .reindex(index=_proj_system_order, columns=_CLF_DETAILED_ORDER, fill_value=0)
)
_proj_step_pcts = _proj_counts.div(_proj_counts.sum(axis=1).replace(0, np.nan), axis=0).fillna(0) * 100

# Facet 2: elapsed-day percentages. This uses the exact same projection-only rows,
# but each row contributes the release gap in days instead of one evolution step.
try:
    _mv_get_date
    _mv_rev
except NameError:
    import re as _re_mv
    _mv_stats = pd.concat([
        pd.read_csv(stage_root / 'main/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'commits/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv'),
    ], ignore_index=True).drop_duplicates(['system', 'revision'])

    def _mv_rev(formula):
        m = _re_mv.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', str(formula).split('/')[-1])
        return m.group(1) if m else None

    def _mv_xml_date(formula):
        m = _re_mv.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
        return m.group(1) if m else None

    _mv_date_lut = (_mv_stats[['system', 'revision', 'committer_date_readable']]
                    .set_index(['system', 'revision'])['committer_date_readable'].to_dict())

    def _mv_get_date(row, side):
        base = _re_mv.sub(r'-(commits|yearly)$', '', row['system'])
        date = _mv_date_lut.get((base, row[f'_{side}_rev']))
        return date if date is not None else _mv_xml_date(row[f'{side}_formula'])

_weighted_proj_breakdown = _proj_breakdown.copy()
_weighted_proj_breakdown['_left_rev'] = _weighted_proj_breakdown['left_formula'].apply(_mv_rev)
_weighted_proj_breakdown['_right_rev'] = _weighted_proj_breakdown['right_formula'].apply(_mv_rev)
_weighted_proj_breakdown['_left_time'] = pd.to_datetime(
    _weighted_proj_breakdown.apply(lambda r: _mv_get_date(r, 'left'), axis=1), errors='coerce'
)
_weighted_proj_breakdown['_right_time'] = pd.to_datetime(
    _weighted_proj_breakdown.apply(lambda r: _mv_get_date(r, 'right'), axis=1), errors='coerce'
)
_weighted_proj_breakdown['gap_days'] = (
    _weighted_proj_breakdown['_right_time'] - _weighted_proj_breakdown['_left_time']
).dt.total_seconds() / 86400
_weighted_proj_breakdown = _weighted_proj_breakdown[
    _weighted_proj_breakdown['gap_days'].notna() & (_weighted_proj_breakdown['gap_days'] >= 0)
].copy()
_weighted_proj_counts = (
    _weighted_proj_breakdown
    .groupby(['_display_system', '_dclf'])['gap_days']
    .sum()
    .unstack(fill_value=0)
    .reindex(index=_proj_system_order, columns=_CLF_DETAILED_ORDER, fill_value=0)
)
_proj_day_pcts = _weighted_proj_counts.div(
    _weighted_proj_counts.sum(axis=1).replace(0, np.nan), axis=0
).fillna(0) * 100

_row_step = 0.48
_bar_height = 0.30
_y = np.arange(len(_proj_system_order), dtype=float) * _row_step
with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, axes = plt.subplots(1, 2, figsize=(5.3, 0.175 * len(_proj_system_order) + 1.15), sharey=True)

    for ax, title, pcts in zip(axes, ['Evolution Steps (%)', 'Elapsed Days (%)'], [_proj_step_pcts, _proj_day_pcts]):
        left = np.zeros(len(_proj_system_order), dtype=float)
        for clf in _CLF_DETAILED_ORDER:
            values = pcts[clf].values
            ax.barh(
                _y,
                values,
                left=left,
                height=_bar_height,
                color=_CLF_DETAILED_COLORS[clf],
                edgecolor='white',
                linewidth=0.45,
            )
            left += values

        ax.set_title(title, fontsize=12)
        ax.set_xlim(0, 100)
        ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
        ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda v, _: f'{v:.0f}'))
        ax.tick_params(axis='x', labelsize=12)
        for label in ax.get_xticklabels():
            if label.get_text() == '100':
                label.set_horizontalalignment('right')
        ax.grid(axis='x', linestyle='--', alpha=0.35)

    axes[0].set_yticks(_y)
    axes[0].set_yticklabels([_PROJ_BREAKDOWN_LABELS.get(s, s) for s in _proj_system_order], fontsize=12)
    axes[0].set_ylim(_y[-1] + _row_step / 2, -_row_step / 2)
    axes[1].tick_params(axis='y', left=False, labelleft=False)

    _timeline_legend_labels = {
        'Refactoring': 'Ref',
        'Near Refactoring': 'Near (1%)',
        'Generalization': 'Gen',
        'Near Generalization': 'Near (1%)',
        'Specialization': 'Spec',
        'Near Specialization': 'Near (1%)',
        'Truly Arbitrary': 'Arbitrary Edit',
    }
    _legend_handle_style = dict(edgecolor='white', linewidth=0.45)
    _legend_handles = [
        plt.Rectangle((0, 0), 1, 1, facecolor=_CLF_DETAILED_COLORS[c], **_legend_handle_style)
        for c in _CLF_DETAILED_ORDER
    ]
    fig.legend(
        _legend_handles,
        [_timeline_legend_labels[c] for c in _CLF_DETAILED_ORDER],
        loc='lower center',
        ncol=len(_CLF_DETAILED_ORDER),
        fontsize=8.5,
        frameon=False,
        handlelength=1.0,
        columnspacing=0.65,
        bbox_to_anchor=(0.5, 0.035),
    )
    fig.tight_layout(rect=[0, 0.105, 1, 1], w_pad=0.25)
    fig.savefig(paper_image_dir / 'classification-breakdown.pdf', bbox_inches='tight', pad_inches=0)
    plt.show()

# %% [markdown]
# ## BusyBox runtime by granularity

# %%
import re as _re_bb

try:
    _bb_stats = _stats
except NameError:
    _bb_stats = pd.concat([
        pd.read_csv(stage_root / 'main/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'commits/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv'),
    ], ignore_index=True).drop_duplicates(['system', 'revision'])

def _bb_rev(formula):
    m = _re_bb.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', formula.split('/')[-1])
    return m.group(1) if m else None

def _xml_date(formula):
    m = _re_bb.search(r'(\d{4}-\d{2}-\d{2})\.xml$', formula.split('/')[-1])
    return m.group(1) if m else None

_sc = df.copy()
_sc['duration_s'] = np.where(_sc['total_duration'].notna(), _sc['total_duration_shell'] / 1e9, np.nan)
_sc['_base_sys']  = _sc['system'].str.replace(r'-(commits|yearly)$', '', regex=True)
_sc['_left_rev']  = _sc['left_formula'].apply(_bb_rev)
_sc['_right_rev'] = _sc['right_formula'].apply(_bb_rev)

_date_lut = (_bb_stats[['system', 'revision', 'committer_date_readable']]
             .set_index(['system', 'revision'])['committer_date_readable'].to_dict())

def _get_date(row, side):
    date = _date_lut.get((row['_base_sys'], row[f'_{side}_rev']))
    return date if date is not None else _xml_date(row[f'{side}_formula'])

_sc['_left_time']  = pd.to_datetime(
    _sc.apply(lambda r: _get_date(r, 'left'),  axis=1), errors='coerce')
_sc['_right_time'] = pd.to_datetime(
    _sc.apply(lambda r: _get_date(r, 'right'), axis=1), errors='coerce')
_sc['_gap_days'] = (_sc['_right_time'] - _sc['_left_time']).dt.total_seconds() / 86400
_sc = _sc.dropna(subset=['_gap_days', 'duration_s'])

_all_sys    = sorted(_sc['system'].unique())
_sys_colors = dict(zip(_all_sys, color_cycle(len(_all_sys))))

fig, ax = plt.subplots(figsize=(9, 5))

for sys in _all_sys:
    s = _sc[_sc['system'] == sys]
    ax.scatter(s['_gap_days'], s['duration_s'],
               color=_sys_colors[sys], label=sys,
               s=12, alpha=0.5, linewidths=0)

ax.set_xlabel('Days between versions')
ax.set_ylabel('Duration (s)')
ax.grid(linestyle='--', alpha=0.4)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.1f}'))
ax.legend(fontsize=8, bbox_to_anchor=(1.01, 1), loc='upper left')
fig.suptitle('Runtime vs. time between versions', fontsize=12)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Solution composition distributions per system

# %%
_frac_cols   = ['removed_solutions', 'common_solutions', 'added_solutions']
_frac_titles = {'removed_solutions': 'Removed',
                'common_solutions':  'Common',
                'added_solutions':   'Added'}
_diff_kinds_cnt  = ['false', 'slice']
_ext_colors      = {'kclause': COLOR['blue'], 'kconfigreader': COLOR['orange'], 'xml': COLOR['bluish_green']}
_ext_order       = ['kclause', 'kconfigreader', 'xml']

# reuse _tl_ok; only quantified rows, keep extractor separate
_cdf = _tl_ok[_tl_ok['has_comp']].copy()
_cdf_dedup = (
    _cdf.sort_values('removed_solutions', na_position='last')
        .drop_duplicates(subset=['system', 'extractor', 'diff_kind', 'left_formula', 'right_formula'])
)

_sys_sorted = sorted(_cdf_dedup['system'].unique())
_n_sys      = len(_sys_sorted)
_grp_w      = 0.7

with plt.rc_context({'font.family': 'Helvetica', 'font.size': 12}):
    fig, axes = plt.subplots(len(_diff_kinds_cnt), len(_frac_cols),
                             figsize=(max(10, 1.5 * _n_sys), 4 * len(_diff_kinds_cnt)),
                             squeeze=False, sharey='row')
    fig.suptitle('Solution composition distributions per system / extractor', fontsize=13)

    for ri, diff_kind in enumerate(_diff_kinds_cnt):
        sub = _cdf_dedup[_cdf_dedup['diff_kind'] == diff_kind]
        for ci, frac_col in enumerate(_frac_cols):
            ax = axes[ri][ci]

            for xi, system in enumerate(_sys_sorted):
                ssub     = sub[sub['system'] == system]
                exts     = [e for e in _ext_order if e in ssub['extractor'].values]
                n_exts   = len(exts)
                bw       = _grp_w / max(n_exts, 1) * 0.85
                offsets  = np.linspace(-_grp_w/2 + bw/2, _grp_w/2 - bw/2, n_exts) if n_exts > 1 else [0.0]

                for ext, off in zip(exts, offsets):
                    vals = ssub.loc[ssub['extractor'] == ext, frac_col].dropna().values * 100
                    if len(vals) == 0:
                        continue
                    pos = xi + 1 + off
                    bp  = ax.boxplot([vals], positions=[pos], widths=bw,
                                     patch_artist=True,
                                     flierprops=dict(marker='o', markersize=2, alpha=0.4),
                                     medianprops=dict(color=COLOR['black'], linewidth=1.2))
                    bp['boxes'][0].set_facecolor(_ext_colors[ext])
                    bp['boxes'][0].set_alpha(0.78)

            ax.set_ylim(0, 100)
            ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%g %%'))
            ax.set_xticks(range(1, _n_sys + 1))
            ax.set_xticklabels(_sys_sorted, rotation=30, ha='right', fontsize=8)
            ax.grid(axis='y', linestyle='--', alpha=0.4)
            ax.set_xlim(0.5, _n_sys + 0.5)
            if ri == 0:
                ax.set_title(_frac_titles[frac_col], fontsize=11)
            if ci == 0:
                ax.set_ylabel(f'{diff_kind}\n% of configurations', fontsize=8)

    _legend_ext = [
        plt.matplotlib.patches.Patch(facecolor=_ext_colors[e], alpha=0.78, label=e)
        for e in _ext_order
    ]
    axes[0][-1].legend(handles=_legend_ext, fontsize=10, loc='upper right')
    plt.tight_layout()
    plt.show()

# ── 5-number summary table ────────────────────────────────────────────────────
_pcts      = [0, 25, 50, 75, 100]
_stat_names = ['min', 'Q1', 'med', 'Q3', 'max']

for diff_kind in _diff_kinds_cnt:
    sub = _cdf_dedup[_cdf_dedup['diff_kind'] == diff_kind]
    rows = []
    for system in _sys_sorted:
        for ext in _ext_order:
            ssub = sub[(sub['system'] == system) & (sub['extractor'] == ext)]
            if ssub.empty:
                continue
            row = {'system': system, 'extractor': ext}
            for frac_col in _frac_cols:
                vals = ssub[frac_col].dropna().values * 100
                if len(vals) == 0:
                    for s in _stat_names:
                        row[(_frac_titles[frac_col], s)] = float('nan')
                else:
                    for s, p in zip(_stat_names, np.percentile(vals, _pcts)):
                        row[(_frac_titles[frac_col], s)] = round(p, 1)
            rows.append(row)

    _tbl = pd.DataFrame(rows).set_index(['system', 'extractor'])
    _tbl.columns = pd.MultiIndex.from_tuples(_tbl.columns)
    print(f'\n── {diff_kind} ──')
    display(_tbl.style
            .format('{:.1f}', na_rep='—')
            .set_caption(f'5-number summary (%) — {diff_kind}'))
# Out:
# ── false ──
# <style type="text/css">
# </style>
# <table id="T_d5a0c">
#   <caption>5-number summary (%) — false</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5a0c_level0_col0" class="col_heading level0 col0" colspan="5">Removed</th>
#       <th id="T_d5a0c_level0_col5" class="col_heading level0 col5" colspan="5">Common</th>
#       <th id="T_d5a0c_level0_col10" class="col_heading level0 col10" colspan="5">Added</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_d5a0c_level1_col0" class="col_heading level1 col0" >min</th>
#       <th id="T_d5a0c_level1_col1" class="col_heading level1 col1" >Q1</th>
#       <th id="T_d5a0c_level1_col2" class="col_heading level1 col2" >med</th>
#       <th id="T_d5a0c_level1_col3" class="col_heading level1 col3" >Q3</th>
# ...

# %% [markdown]
# ## Solution composition distributions across systems

# %%
_frac_cols   = ['removed_solutions', 'common_solutions', 'added_solutions']
_frac_titles = {'removed_solutions': 'Removed',
                'common_solutions':  'Common',
                'added_solutions':   'Added'}
_diff_kinds_cnt = ['false', 'slice']
_ext_colors     = {'kclause': COLOR['blue'], 'kconfigreader': COLOR['orange'], 'xml': COLOR['bluish_green']}
_ext_order      = ['kclause', 'kconfigreader', 'xml']

# Reuse _cdf_dedup from the per-system distribution above.
_n_exts  = len(_ext_order)
_grp_w   = 0.7
_bw      = _grp_w / _n_exts * 0.85
_offsets = np.linspace(-_grp_w/2 + _bw/2, _grp_w/2 - _bw/2, _n_exts)

fig, axes = plt.subplots(len(_diff_kinds_cnt), len(_frac_cols),
                         figsize=(6, 4 * len(_diff_kinds_cnt)),
                         squeeze=False, sharey='row')
fig.suptitle('Solution composition distributions — all systems combined', fontsize=13)

for ri, diff_kind in enumerate(_diff_kinds_cnt):
    sub = _cdf_dedup[_cdf_dedup['diff_kind'] == diff_kind]
    for ci, frac_col in enumerate(_frac_cols):
        ax = axes[ri][ci]

        for ext, off in zip(_ext_order, _offsets):
            vals = sub.loc[sub['extractor'] == ext, frac_col].dropna().values * 100
            if len(vals) == 0:
                continue
            bp = ax.boxplot([vals], positions=[1 + off], widths=_bw,
                            patch_artist=True,
                            flierprops=dict(marker='o', markersize=2, alpha=0.4),
                            medianprops=dict(color=COLOR['black'], linewidth=1.2))
            bp['boxes'][0].set_facecolor(_ext_colors[ext])
            bp['boxes'][0].set_alpha(0.78)

        ax.set_ylim(0, 100)
        ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%g %%'))
        ax.set_xticks([])
        ax.grid(axis='y', linestyle='--', alpha=0.4)
        ax.set_xlim(0.5, 1.5)
        if ri == 0:
            ax.set_title(_frac_titles[frac_col], fontsize=11)
        if ci == 0:
            ax.set_ylabel(f'{diff_kind}\n% of configurations', fontsize=8)

_legend_ext = [
    plt.matplotlib.patches.Patch(facecolor=_ext_colors[e], alpha=0.78, label=e)
    for e in _ext_order
]
axes[0][-1].legend(handles=_legend_ext, fontsize=9, loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Meaningfulness of slicing

# %%
# Meaningfulness = common_vars / (common_vars + added_vars + removed_vars)
# Independent of diff_kind and method, so we deduplicate per version pair × extractor.

_mdf = df.copy()
_mdf['extractor'] = _mdf['left_formula'].apply(_tl_extract_extractor)
_mdf['meaningfulness'] = (
    _mdf['common_vars'] /
    (_mdf['common_vars'] + _mdf['added_vars'] + _mdf['removed_vars'])
)
_mdf_dedup = (
    _mdf.drop_duplicates(subset=['system', 'extractor', 'left_formula', 'right_formula'])
        .dropna(subset=['meaningfulness'])
)

_mdf_systems  = sorted(_mdf_dedup['system'].unique())
_ext_order_m  = ['kclause', 'kconfigreader', 'xml']
_ext_colors_m = {'kclause': COLOR['blue'], 'kconfigreader': COLOR['orange'], 'xml': COLOR['bluish_green']}
_grp_w        = 0.7

fig, ax = plt.subplots(figsize=(max(10, 1.5 * len(_mdf_systems)), 4))
fig.suptitle('Meaningfulness of slicing per system / extractor\n'
             '(common vars / total vars between consecutive versions)', fontsize=12)

for xi, system in enumerate(_mdf_systems):
    ssub  = _mdf_dedup[_mdf_dedup['system'] == system]
    exts  = [e for e in _ext_order_m if e in ssub['extractor'].values]
    n_ext = len(exts)
    bw    = _grp_w / max(n_ext, 1) * 0.85
    offsets = np.linspace(-_grp_w/2 + bw/2, _grp_w/2 - bw/2, n_ext) if n_ext > 1 else [0.0]

    for ext, off in zip(exts, offsets):
        vals = ssub.loc[ssub['extractor'] == ext, 'meaningfulness'].dropna().values
        if len(vals) == 0:
            continue
        pos = xi + 1 + off
        bp  = ax.boxplot([vals], positions=[pos], widths=bw, patch_artist=True,
                         medianprops=dict(color=COLOR['black'], linewidth=1.5),
                         boxprops=dict(linewidth=0.8),
                         whiskerprops=dict(linewidth=0.8),
                         capprops=dict(linewidth=0.8),
                         flierprops=dict(marker='.', markersize=2, alpha=0.5))
        bp['boxes'][0].set_facecolor(_ext_colors_m[ext])
        bp['boxes'][0].set_alpha(0.7)

ax.set_xticks(range(1, len(_mdf_systems) + 1))
ax.set_xticklabels(_mdf_systems, rotation=20, ha='right', fontsize=8)
ax.set_ylim(-0.05, 1.05)
ax.set_yticks([0, 0.25, 0.5, 0.75, 1.0])
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0))
ax.axhline(1.0, color=COLOR['light_gray'], linewidth=0.7, zorder=0)
ax.grid(axis='y', linestyle='--', alpha=0.4)

handles = [plt.matplotlib.patches.Patch(facecolor=_ext_colors_m[e], alpha=0.7, label=e)
           for e in _ext_order_m]
ax.legend(handles=handles, fontsize=8)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Meaningfulness vs. days between releases

# %%
import re as _re_mv

# Load stats for all three experiments to cover yearly systems too
try:
    _mv_stats = _stats
except NameError:
    _mv_stats = pd.concat([
        pd.read_csv(stage_root / 'main/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'commits/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv'),
    ], ignore_index=True).drop_duplicates(['system', 'revision'])
_mv_stats_yearly = pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv')
_mv_all_stats = pd.concat([_mv_stats, _mv_stats_yearly], ignore_index=True).drop_duplicates(['system', 'revision'])

def _mv_rev(formula):
    m = _re_mv.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', formula.split('/')[-1])
    return m.group(1) if m else None

def _mv_xml_date(formula):
    m = _re_mv.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
    return m.group(1) if m else None

_mv_date_lut = (_mv_all_stats[['system', 'revision', 'committer_date_readable']]
                .set_index(['system', 'revision'])['committer_date_readable'].to_dict())

def _mv_get_date(row, side):
    base = _re_mv.sub(r'-(commits|yearly)$', '', row['system'])
    date = _mv_date_lut.get((base, row[f'_{side}_rev']))
    return date if date is not None else _mv_xml_date(row[f'{side}_formula'])

# Build working dataframe from df (includes yearly)
_mv = df.copy()
_mv['meaningfulness'] = (_mv['common_vars'] /
    (_mv['common_vars'] + _mv['added_vars'] + _mv['removed_vars']))
_mv['_left_rev']  = _mv['left_formula'].apply(_mv_rev)
_mv['_right_rev'] = _mv['right_formula'].apply(_mv_rev)
_mv = _mv.drop_duplicates(['system', 'left_formula', 'right_formula'])
_mv['_left_time']  = pd.to_datetime(
    _mv.apply(lambda r: _mv_get_date(r, 'left'),  axis=1), errors='coerce')
_mv['_right_time'] = pd.to_datetime(
    _mv.apply(lambda r: _mv_get_date(r, 'right'), axis=1), errors='coerce')
_mv['_gap_days'] = (_mv['_right_time'] - _mv['_left_time']).dt.total_seconds() / 86400
_mv = _mv.dropna(subset=['_gap_days', 'meaningfulness'])

_mv_systems = sorted(_mv['system'].unique())
_mv_colors  = dict(zip(_mv_systems, color_cycle(len(_mv_systems))))

fig, ax = plt.subplots(figsize=(9, 5))
for sys in _mv_systems:
    s = _mv[_mv['system'] == sys]
    ax.scatter(s['_gap_days'], s['meaningfulness'],
               color=_mv_colors[sys], label=sys, s=12, alpha=0.5, linewidths=0)

ax.set_xlabel('Days between releases')
ax.set_ylabel('Meaningfulness')
ax.set_ylim(0, 1)
ax.grid(linestyle='--', alpha=0.4)
ax.legend(fontsize=8, bbox_to_anchor=(1.01, 1), loc='upper left')
fig.suptitle('Meaningfulness vs. days between releases', fontsize=12)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Common solutions: slice vs. false

# %%
import matplotlib.cm as _cm
import matplotlib.colors as _mcolors

# Pivot _cdf_dedup so each version pair has one row with both diff_kinds
_scat = (
    _cdf_dedup[['system', 'extractor', 'left_formula', 'right_formula',
                'diff_kind', 'common_solutions']]
    .pivot_table(index=['system', 'extractor', 'left_formula', 'right_formula'],
                 columns='diff_kind', values='common_solutions')
    .reset_index()
)
_scat.columns.name = None
_scat = _scat.rename(columns={'false': 'common_false', 'slice': 'common_slice'})
_scat = _scat.dropna(subset=['common_false', 'common_slice'])

# Attach meaningfulness
_scat = _scat.merge(
    _mdf_dedup[['system', 'extractor', 'left_formula', 'right_formula', 'meaningfulness']],
    on=['system', 'extractor', 'left_formula', 'right_formula'], how='left'
)

_ext_markers  = {'kclause': 'o', 'kconfigreader': 's', 'xml': '^'}
_scat_systems = sorted(_scat['system'].unique())
_sys_palette  = dict(zip(_scat_systems, color_cycle(len(_scat_systems))))

fig, ax = plt.subplots(figsize=(6, 6))
fig.suptitle('Common solutions: slice (x) vs false (y)\n'
             'Color = system, shape = extractor', fontsize=12)

for (system, ext), grp in _scat.groupby(['system', 'extractor']):
    ax.scatter(
        grp['common_slice'], grp['common_false'],
        color=_sys_palette[system],
        marker=_ext_markers.get(ext, 'o'), s=18, alpha=0.6,
        linewidths=0.3, edgecolors='none',
        label=system if ext == 'kclause' else '_'
    )

ax.plot([0, 1], [0, 1], color=COLOR['light_gray'], linewidth=0.8, zorder=0)
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_aspect('equal')
ax.xaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0))
ax.set_xlabel('slice', fontsize=10)
ax.set_ylabel('false', fontsize=10)

sys_handles = [plt.matplotlib.patches.Patch(facecolor=_sys_palette[s], label=s)
               for s in _scat_systems]
ext_handles = [plt.Line2D([0],[0], marker=m, color=COLOR['gray'], linestyle='None',
                           markersize=6, label=e)
               for e, m in _ext_markers.items()]
ax.legend(handles=sys_handles + ext_handles, fontsize=7,
          loc='upper left', ncol=2, handletextpad=0.3, columnspacing=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Common solutions without BusyBox commits

# %%
_scat_no_bc   = _scat[_scat['system'] != 'busybox-commits']
_sys_no_bc    = sorted(_scat_no_bc['system'].unique())
_sys_pal_no_bc = dict(zip(_sys_no_bc, color_cycle(len(_sys_no_bc))))

fig, ax = plt.subplots(figsize=(6, 6))
fig.suptitle('Common solutions: slice (x) vs false (y)\n'
             'Color = system, shape = extractor  (excl. busybox-commits)', fontsize=12)

for (system, ext), grp in _scat_no_bc.groupby(['system', 'extractor']):
    ax.scatter(
        grp['common_slice'], grp['common_false'],
        color=_sys_pal_no_bc[system],
        marker=_ext_markers.get(ext, 'o'), s=18, alpha=0.6,
        linewidths=0.3, edgecolors='none',
        label=system if ext == 'kclause' else '_'
    )

ax.plot([0, 1], [0, 1], color=COLOR['light_gray'], linewidth=0.8, zorder=0)
ax.set_xlim(-0.02, 1.02)
ax.set_ylim(-0.02, 1.02)
ax.set_aspect('equal')
ax.xaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=0))
ax.set_xlabel('slice', fontsize=10)
ax.set_ylabel('false', fontsize=10)

sys_handles = [plt.matplotlib.patches.Patch(facecolor=_sys_pal_no_bc[s], label=s)
               for s in _sys_no_bc]
ext_handles = [plt.Line2D([0],[0], marker=m, color=COLOR['gray'], linestyle='None',
                           markersize=6, label=e)
               for e, m in _ext_markers.items()]
ax.legend(handles=sys_handles + ext_handles, fontsize=7,
          loc='upper left', ncol=2, handletextpad=0.3, columnspacing=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature changes vs. solution changes

# %%
import numpy as _np2

_sc_diff_kinds = ['false', 'slice']
_add_color = COLOR['bluish_green']
_rem_color = COLOR['vermillion']

_sc = _cdf_dedup.copy()
_sc['fa'] = _sc['added_vars']
_sc['fr'] = _sc['removed_vars']
_sc['pa'] = _sc['added_solutions'] * 100
_sc['pr'] = _sc['removed_solutions'] * 100
_sc = _sc.dropna(subset=['fa', 'fr', 'pa', 'pr'])

_dm_markers = {'false': 'o', 'slice': 's'}

fig, axes = plt.subplots(1, len(_sc_diff_kinds), figsize=(12, 4.5), sharey=True)
fig.suptitle('Added / removed features vs. share of added / removed products', fontsize=12)

for ax, diff_kind in zip(axes, _sc_diff_kinds):
    sub = _sc[_sc['diff_kind'] == diff_kind]
    m = _dm_markers[diff_kind]
    kw = dict(marker=m, alpha=0.35, s=10, linewidths=0)

    # green: (fa, pa) and (-fr, pa)
    ax.scatter( sub['fa'],  sub['pa'], color=_add_color, **kw)
    ax.scatter(-sub['fr'],  sub['pa'], color=_add_color, **kw)

    # red: (fa, pr) and (-fr, pr)
    ax.scatter( sub['fa'],  sub['pr'], color=_rem_color, **kw)
    ax.scatter(-sub['fr'],  sub['pr'], color=_rem_color, **kw)

    ax.axvline(0, color=COLOR['gray'], linewidth=0.8, linestyle='--')
    ax.set_xlabel('# features  (positive = added,  negative = removed)', fontsize=10)
    ax.set_title(diff_kind, fontsize=10)
    ax.set_ylim(-2, 102)
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%g%%'))
    ax.grid(linestyle='--', alpha=0.3)

axes[0].set_ylabel('share of products', fontsize=10)

_legend_handles = [
    plt.matplotlib.patches.Patch(facecolor=_add_color, label='added product share (pa)'),
    plt.matplotlib.patches.Patch(facecolor=_rem_color, label='removed product share (pr)'),
]
axes[-1].legend(handles=_legend_handles, fontsize=9, loc='upper right',
                handletextpad=0.4, labelspacing=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Projection-only common solutions vs. evolution distance

# %%
# Projection-only: compare solution overlap to temporal and feature overlap.
# Reuse the date helpers from the meaningfulness section when available.
try:
    _mv_get_date
    _mv_rev
except NameError:
    import re as _re_mv
    _mv_stats = pd.concat([
        pd.read_csv(stage_root / 'main/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'commits/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv'),
    ], ignore_index=True).drop_duplicates(['system', 'revision'])

    def _mv_rev(formula):
        m = _re_mv.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', str(formula).split('/')[-1])
        return m.group(1) if m else None

    def _mv_xml_date(formula):
        m = _re_mv.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
        return m.group(1) if m else None

    _mv_date_lut = (_mv_stats[['system', 'revision', 'committer_date_readable']]
                    .set_index(['system', 'revision'])['committer_date_readable'].to_dict())

    def _mv_get_date(row, side):
        base = _re_mv.sub(r'-(commits|yearly)$', '', row['system'])
        date = _mv_date_lut.get((base, row[f'_{side}_rev']))
        return date if date is not None else _mv_xml_date(row[f'{side}_formula'])

_proj_common = _cdf_dedup[_cdf_dedup['diff_kind'].astype(str) == 'slice'].copy()
_proj_common['_left_rev'] = _proj_common['left_formula'].apply(_mv_rev)
_proj_common['_right_rev'] = _proj_common['right_formula'].apply(_mv_rev)
_proj_common['_left_time'] = pd.to_datetime(_proj_common.apply(lambda r: _mv_get_date(r, 'left'), axis=1), errors='coerce')
_proj_common['_right_time'] = pd.to_datetime(_proj_common.apply(lambda r: _mv_get_date(r, 'right'), axis=1), errors='coerce')
_proj_common['gap_days'] = (_proj_common['_right_time'] - _proj_common['_left_time']).dt.total_seconds() / 86400
_proj_common['shared_features'] = _proj_common['common_vars']
_solution_count_col = 'common_solutions_count' if 'common_solutions_count' in _proj_common.columns and _proj_common['common_solutions_count'].notna().any() else 'common_solutions'
_proj_common['shared_solutions'] = _proj_common[_solution_count_col]

def _solution_count_log10_plus_one(value):
    if pd.isna(value):
        return np.nan
    try:
        return np.log10(int(str(value)) + 1)
    except (TypeError, ValueError):
        return np.nan

if _solution_count_col == 'common_solutions_count':
    _proj_common['shared_solutions_plot'] = _proj_common['shared_solutions'].apply(_solution_count_log10_plus_one)
    _shared_solution_ylabel = 'log10(shared solutions + 1)'
else:
    _proj_common['shared_solutions_plot'] = pd.to_numeric(_proj_common['shared_solutions'], errors='coerce')
    _shared_solution_ylabel = 'Shared solution fraction'
_proj_common = _proj_common.dropna(subset=['shared_solutions_plot', 'shared_features'])

_proj_common_systems = sorted(_proj_common['system'].dropna().unique())
_proj_common_colors = dict(zip(_proj_common_systems, color_cycle(len(_proj_common_systems))))
_proj_common_labels = {
    'FinancialServices01': 'FS01',
    'automotive2': 'Auto2',
    'busybox-commits': 'busybox commits',
    'busybox-yearly': 'busybox yearly',
    'freetz-ng': 'freetz',
}

fig, axes = plt.subplots(1, 2, figsize=(12, 5.2))
for system in _proj_common_systems:
    s = _proj_common[_proj_common['system'] == system]
    axes[0].scatter(s['gap_days'], s['shared_solutions_plot'], color=_proj_common_colors[system], s=16, alpha=0.55, linewidths=0, label=_proj_common_labels.get(system, system))
    axes[1].scatter(s['shared_features'], s['shared_solutions_plot'], color=_proj_common_colors[system], s=16, alpha=0.55, linewidths=0, label=_proj_common_labels.get(system, system))

axes[0].set_xlabel('Days between models')
axes[0].set_ylabel(_shared_solution_ylabel)
axes[0].grid(linestyle='--', alpha=0.35)

axes[1].set_xlabel('Shared features')
axes[1].set_ylabel(_shared_solution_ylabel)
axes[1].set_xscale('log')
axes[1].grid(linestyle='--', alpha=0.35, which='both')

fig.suptitle('Projection-only shared solutions vs. evolution distance and shared features', fontsize=12)
handles = [plt.matplotlib.patches.Patch(facecolor=_proj_common_colors[s], label=_proj_common_labels.get(s, s)) for s in _proj_common_systems]
fig.legend(handles=handles, loc='lower center', bbox_to_anchor=(0.5, -0.03), ncol=4, fontsize=8, frameon=False)
fig.subplots_adjust(left=0.08, right=0.98, bottom=0.22, top=0.88, wspace=0.28)
fig.savefig(paper_image_dir / 'projection-common-solutions-vs-distance-and-features.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Feature counts vs. configuration counts
#
# For Projection semantics, compare the number of shared, added, and removed features with the corresponding number of shared, added, and removed configurations.

# %%
# Projection-only: compare feature-count changes against exact configuration counts.
# Both axes use log10(count + 1), which keeps zero-count changes plottable.
_feature_cfg = _cdf_dedup[_cdf_dedup['diff_kind'].astype(str) == 'slice'].copy()

_feature_cfg_pairs = [
    ('Shared',  'common_vars',   'common_solutions_count',   'common_solutions'),
    ('Added',   'added_vars',    'added_solutions_count',    'added_solutions'),
    ('Removed', 'removed_vars',  'removed_solutions_count',  'removed_solutions'),
]

def _count_log10_plus_one(value):
    if pd.isna(value):
        return np.nan
    try:
        return np.log10(int(str(value)) + 1)
    except (TypeError, ValueError):
        numeric = pd.to_numeric(value, errors='coerce')
        if pd.isna(numeric) or numeric < 0:
            return np.nan
        return np.log10(float(numeric) + 1)

_feature_cfg_systems = sorted(_feature_cfg['system'].dropna().unique())
_feature_cfg_colors = dict(zip(_feature_cfg_systems, color_cycle(len(_feature_cfg_systems))))
_feature_cfg_labels = {
    'FinancialServices01': 'FS01',
    'automotive2': 'Auto2',
    'busybox-commits': 'busybox commits',
    'busybox-yearly': 'busybox yearly',
    'freetz-ng': 'freetz',
}

fig, axes = plt.subplots(1, 3, figsize=(13.2, 4.6), sharey=False)
for ax, (title, feature_col, count_col, share_col) in zip(axes, _feature_cfg_pairs):
    plot_df = _feature_cfg.copy()
    plot_df['feature_count'] = pd.to_numeric(plot_df[feature_col], errors='coerce')
    plot_df['feature_count_plot'] = plot_df['feature_count'].apply(_count_log10_plus_one)
    if count_col in plot_df.columns and plot_df[count_col].notna().any():
        plot_df['cfg_count_plot'] = plot_df[count_col].apply(_count_log10_plus_one)
        y_label = f'log10({title.lower()} cfgs + 1)'
    else:
        plot_df['cfg_count_plot'] = pd.to_numeric(plot_df[share_col], errors='coerce')
        y_label = f'{title} cfg fraction'
    plot_df = plot_df.dropna(subset=['feature_count_plot', 'cfg_count_plot'])
    print(f'{title}: plotting {len(plot_df)} points')

    for system in _feature_cfg_systems:
        system_df = plot_df[plot_df['system'] == system]
        if system_df.empty:
            continue
        ax.scatter(
            system_df['feature_count_plot'],
            system_df['cfg_count_plot'],
            color=_feature_cfg_colors[system],
            s=16,
            alpha=0.55,
            linewidths=0,
            label=_feature_cfg_labels.get(system, system),
        )

    ax.set_title(title, fontsize=11)
    ax.set_xlabel(f'log10({title.lower()} features + 1)')
    ax.set_ylabel(y_label)
    ax.grid(linestyle='--', alpha=0.35)

handles = [
    plt.matplotlib.patches.Patch(facecolor=_feature_cfg_colors[s], label=_feature_cfg_labels.get(s, s))
    for s in _feature_cfg_systems
]
fig.legend(handles=handles, loc='lower center', bbox_to_anchor=(0.5, -0.04), ncol=4, fontsize=8, frameon=False)
fig.subplots_adjust(left=0.07, right=0.99, bottom=0.25, top=0.88, wspace=0.32)
fig.savefig(paper_image_dir / 'projection-feature-vs-config-counts.pdf', bbox_inches='tight', pad_inches=0)
plt.show()
# Out:
# Shared: plotting 606 points
# Added: plotting 591 points
# Removed: plotting 593 points

# %% [markdown]
# ## Days Between Releases
#
# This plot summarizes the elapsed time between consecutive model pairs for each release-level system.

# %%
# Deduplicate experimental rows down to one consecutive model pair per system, then
# plot the elapsed days between the two model dates for each release-level system.
try:
    _mv_get_date
    _mv_rev
except NameError:
    import re as _re_mv
    _mv_stats = pd.concat([
        pd.read_csv(stage_root / 'main/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'commits/3_read_statistics/output.csv'),
        pd.read_csv(stage_root / 'yearly/3_read_statistics/output.csv'),
    ], ignore_index=True).drop_duplicates(['system', 'revision'])

    def _mv_rev(formula):
        m = _re_mv.match(r'\[[\d-]+\](.+?)(?:\[.*?\])?\.model$', str(formula).split('/')[-1])
        return m.group(1) if m else None

    def _mv_xml_date(formula):
        m = _re_mv.search(r'(\d{4}-\d{2}-\d{2})\.xml$', str(formula))
        return m.group(1) if m else None

    _mv_date_lut = (_mv_stats[['system', 'revision', 'committer_date_readable']]
                    .set_index(['system', 'revision'])['committer_date_readable'].to_dict())

    def _mv_get_date(row, side):
        base = _re_mv.sub(r'-(commits|yearly)$', '', row['system'])
        date = _mv_date_lut.get((base, row[f'_{side}_rev']))
        return date if date is not None else _mv_xml_date(row[f'{side}_formula'])

try:
    _breakdown_strip_source
except NameError:
    def _breakdown_strip_source(formula):
        parts = str(formula).split('/')
        if parts[0].startswith('extract-kconfig-models-with-'):
            return '/'.join(parts[1:])
        return str(formula)

_release_gap_order = [
    'axtls', 'buildroot', 'busybox', 'embtoolkit', 'freetz-ng', 'l4re',
    'linux', 'toybox', 'uclibc', 'uclibc-ng', 'FinancialServices01', 'automotive2',
]
_release_gap_labels = {'FinancialServices01': 'FS01'}

_release_gap = _cdf_dedup[
    ~_cdf_dedup['system'].isin(['busybox-commits', 'busybox-yearly'])
].copy()
_release_gap['left_model'] = _release_gap['left_formula'].apply(_breakdown_strip_source)
_release_gap['right_model'] = _release_gap['right_formula'].apply(_breakdown_strip_source)
_release_gap = _release_gap.drop_duplicates(subset=['system', 'left_model', 'right_model'])
_release_gap['_left_rev'] = _release_gap['left_formula'].apply(_mv_rev)
_release_gap['_right_rev'] = _release_gap['right_formula'].apply(_mv_rev)
_release_gap['_left_time'] = pd.to_datetime(_release_gap.apply(lambda r: _mv_get_date(r, 'left'), axis=1), errors='coerce')
_release_gap['_right_time'] = pd.to_datetime(_release_gap.apply(lambda r: _mv_get_date(r, 'right'), axis=1), errors='coerce')
_release_gap['gap_days'] = (_release_gap['_right_time'] - _release_gap['_left_time']).dt.total_seconds() / 86400
_release_gap = _release_gap[_release_gap['gap_days'].notna() & (_release_gap['gap_days'] >= 0)].copy()

_present_release_gap_systems = set(_release_gap['system'].dropna())
_release_gap_systems = [s for s in _release_gap_order if s in _present_release_gap_systems]
_release_gap_systems += sorted(_present_release_gap_systems - set(_release_gap_systems))
_release_gap_series = [
    _release_gap.loc[_release_gap['system'] == system, 'gap_days'].values
    for system in _release_gap_systems
]

fig, ax = plt.subplots(figsize=(5.4, 0.28 * len(_release_gap_systems) + 1.1))
bp = ax.boxplot(
    _release_gap_series,
    vert=False,
    labels=[_release_gap_labels.get(s, s) for s in _release_gap_systems],
    patch_artist=True,
    showfliers=True,
    widths=0.55,
)
for box in bp['boxes']:
    box.set(facecolor=COLOR['light_gray'], edgecolor=COLOR['gray'], linewidth=0.8)
for median in bp['medians']:
    median.set(color=COLOR['black'], linewidth=1.0)
for whisker in bp['whiskers']:
    whisker.set(color=COLOR['gray'], linewidth=0.8)
for cap in bp['caps']:
    cap.set(color=COLOR['gray'], linewidth=0.8)
for flier in bp['fliers']:
    flier.set(marker='o', markersize=2.5, markerfacecolor=COLOR['gray'], markeredgecolor='none', alpha=0.45)

ax.invert_yaxis()
ax.set_xlabel('Days between releases')
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='x', labelsize=10)
ax.grid(axis='x', linestyle='--', alpha=0.35)
fig.tight_layout()
fig.savefig(paper_image_dir / 'release-gap-days-by-system.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

_release_gap_summary = (
    _release_gap.groupby('system')['gap_days']
    .agg(n='count', median='median', mean='mean', min='min', max='max')
    .reindex(_release_gap_systems)
)
_release_gap_summary
# Out:
# /var/folders/jm/jx4yspgn667320j0_ybbry480000gn/T/ipykernel_10971/4045702536.py:67: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(
#                        n  median        mean    min     max
# system
# axtls                 30    50.5  154.633333    0.0  1398.0
# buildroot             12    91.0   92.666667   87.0   109.0
# busybox              115    37.0   68.539130    0.0   644.0
# embtoolkit            10   120.0  168.100000   34.0   675.0
# freetz-ng              6   365.0  364.666667  363.0   365.0
# l4re                   8   364.5  365.000000  358.0   372.0
# linux                 48    13.0   27.625000    1.0   161.0
# toybox                50   111.5  156.240000   12.0  1119.0
# uclibc                22    33.5  144.136364    0.0   746.0
# uclibc-ng             56    53.0   72.232143    5.0   335.0
# ...
